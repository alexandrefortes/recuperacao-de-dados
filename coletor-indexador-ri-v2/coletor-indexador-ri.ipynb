# %% [markdown]
# ## Especialização em Inteligência Artificial – IFMG
# ### Recuperação da Informação: Atividade 3: Coletor + Indexador + Buscador
#
# **Aluno**: Alexandre Fortes Santana
#
# **Professor**: Moisés Ramos
#
# [Notebook: https://github.com/alexandrefortes/recuperacao-de-dados/blob/main/coletor-indexador-ri-v2/coletor-indexador-ri.ipynb](https://github.com/alexandrefortes/recuperacao-de-dados/blob/main/coletor-indexador-ri/coletor-indexador-ri.ipynb)

# %% [markdown]
# #### Escopo
# - Coletar o conteúdo do portal da Efí Bank (https://sejaefi.com.br);
# - Utilizar Scrapy;
# - Para fins didáticos, ignorar contepudos da '/central-de-ajuda' e do /blog;
# - Armazenar os dados em .json;
# - Mecanismo para minimizar a sobrecarga no portal;
# - A partir de todo o conteúdo coletado, implementar o indexador sob a abordagem de uma lista invertida (também chamada de índice invertido).
# - Implementar uma forma de avaliar a força da palavra ao indexá-la na base de dados, ou seja, o quanto ela é rara na base, ou frequente em cada página, ou a relevância dela no conjunto de palavras de cada página, etc.
# - Implementar alguma forma para detectar a codificação das palavras e tratar isso durante a indexação (lembrando que essa forma de tratamento deve aparecer depois ao tratar as palavras de pesquisa).
# - Modelagem e Processamento de Consultas
#     - Modelos de Correspondência de Consultas: Implemente modelos como Booleano, Vetorial, BM25 ou probabilístico clássico (BM1) para avaliar a similaridade entre uma consulta e os documentos no índice. Esses modelos ajudam a determinar quais documentos são mais relevantes para uma consulta fornecida.
#     - PageRank: Utilize o algoritmo de PageRank para avaliar a importância de uma página baseada na estrutura de links da Web. O PageRank considera uma página mais importante se ela for referenciada por muitas outras páginas, especialmente aquelas que são, por si só, consideradas importantes.
#     - HITS (Hubs and Authorities): Implemente o algoritmo HITS para identificar hubs e autoridades dentro do conjunto de documentos. Hubs são páginas que referenciam muitas autoridades (páginas consideradas importantes sobre um assunto específico), e autoridades são as páginas referenciadas pelos hubs.

# %% [markdown]
# # Coletor e Indexador

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# %%
import subprocess
import sys

def run_spider(spider_file):
    # Executa em um processo separado.
    
    cmd = [sys.executable, spider_file]
    
    # Executa o comando e espera até que o processo seja concluído
    process = subprocess.run(cmd, capture_output=True, text=True)
    
    # Imprime o output do processo
    print(process.stdout)
    
    # Verifica se ocorreu algum erro
    if process.stderr:
        print("Erros encontrados:")
        print(process.stderr)

run_spider('efi_crawl_spider.py')
# Out:
# Errores encontrados:
# 2024-04-07 19:13:37 [scrapy.utils.log] INFO: Scrapy 2.11.1 started (bot: scrapybot)
# 2024-04-07 19:13:37 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.10.4, cssselect 1.2.0, parsel 1.9.0, w3lib 2.1.2, Twisted 24.3.0, Python 3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 24.0.0 (OpenSSL 3.2.1 30 Jan 2024), cryptography 42.0.5, Platform Windows-10-10.0.22621-SP0
# 2024-04-07 19:13:37 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-04-07 19:13:37 [py.warnings] WARNING: c:\Users\alexa\anaconda3\envs\efi_spider\lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024-04-07 19:13:38 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2024-04-07 19:13:38 [scrapy.extensions.telnet] INFO: Telnet Password: 47cef3adeede1e97
# 2024-04-07 19:13:38 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2024-04-07 19:13:38 [scrapy.crawler] INFO: Overridden settings:
# {'CONCURRENT_REQUESTS_PER_DOMAIN': 2,
#  'DOWNLOAD_DELAY': 1,
#  'ROBOTSTXT_OBEY': True,
#  'USER_AGENT': 'EfiContentTrainer'}
# 2024-04-07 19:13:39 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-04-07 19:13:39 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-04-07 19:13:39 [scrapy.middleware] INFO: Enabled item pipelines:
# ['__main__.DuplicatesPipeline',
#  '__main__.ValidationPipeline',
#  '__main__.DataCleaningPipeline',
#  '__main__.JsonWriterPipeline',
#  '__main__.TfidfCalculationPipeline']
# 2024-04-07 19:13:39 [scrapy.core.engine] INFO: Spider opened
# 2024-04-07 19:13:39 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-04-07 19:13:39 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2024-04-07 19:13:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br/robots.txt> (referer: None)
# 2024-04-07 19:13:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br/pages-sitemap.xml> (referer: None)
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-pay
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/tarifas
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-bank
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/whatsapp
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/materiais
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/renegocie
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/abrir-conta
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/sobre-a-efi
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/confirmacoes
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/fale-conosco
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-pay/api-pix
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-pay/boletos
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/lp/efi-e-w3soft
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/cotacao-do-dolar
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/desenrola-brasil
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-bank/efi-pro
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/lp/efi-e-cerbrum
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/termos-e-contratos
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/programa-de-parceria
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-bank/efi-empresas
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/webinars/lp-ixc-e-efi
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-bank/efi-para-voce
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-pay/pix-automatico
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/governanca-corporativa
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/webinars/live-ixc-e-efi
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-pay/api-open-finance
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/lp/formulario-efi-empresas
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-pay/gestao-de-cobrancas
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/lp/blackfriday-efibank-2023
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/solicitar-cartao-de-credito
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/webinars/lp-ixc-e-efi-success
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/lp/open-finance-para-ecommerce
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/lp/iniciador-de-pagamentos-open-finance
# 2024-04-07 19:13:40 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/lp/sistema-de-pagamento-para-provedores
# 2024-04-07 19:13:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br/formularios-sitemap.xml> (referer: None)
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/sophia
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/sortee
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/comercial
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/seja-parceiro
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-atlaz
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-ispfy
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-quaza
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-clicksi
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-beesweb
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-macsoft
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-ixc-soft
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-altarede
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-kingsoft
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-odvix-efi
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-radiusnet
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/solicitar-maquininha
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-cosmos-wide
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/ecommerce-brasil-2023
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/expo-empreendedor-2023
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-mapp-sistemas
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/payment-revolution-2023
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/educacional-w3soft-e-efi
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/educacional-cerbrum-e-efi
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/contate-nosso-especialista
# 2024-04-07 19:13:41 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/emissao-de-boletos-provedores
# 2024-04-07 19:13:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br/lp/open-finance-para-ecommerce> (referer: https://sejaefi.com.br/pages-sitemap.xml)
# 2024-04-07 19:13:43 [efi_crawl] INFO: Processing page: https://sejaefi.com.br/lp/open-finance-para-ecommerce
# 2024-04-07 19:13:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sejaefi.com.br/lp/open-finance-para-ecommerce>
#
# {'content': ['A Gerencianet agora se chama Efí.',
#              'Saiba mais!',
#              'Abrir menu',
#              'Soluções',
#              'Pelo site ou aplicativo',
#              'Boletos e Carnês',
#              'Conta Digital',
#              'Gestão de Cobranças',
#              'Link de Pagamento',
#              'Pagamento Recorrente',
#              'Por API',
#              'API Boletos e Carnês',
#              'API Pix',
#              'API Pix via Open Finance',
#              'Checkout Transparente',
#              'Split de Pagamento',
#              'Pix Automático',
#              'Novo',
#              'Segmentos',
#              'Provedor de Internet',
#              'Bet - Apostas Esportivas',
#              'Parcerias',
#              'Desenvolvedores',
#              'Efí Pay — Plataforma de pagamentos',
#              'Documentação API',
#              'Módulos e Plugins',
#              'Comunidade no Discord',
#              'Curso API 2.0 grátis',
#              'Tarifas',
#              'Blog',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Dê adeus ao abandono de carrinho e',
#              'venda muuuito mais no seu e-commerce',
#              'Revolucione a jornada de compra com um checkout mais simples, '
#              'rápido e transparente, feche mais vendas e receba na hora com o '
#              'Pix via Open Finance.',
#              'Quero conhecer o Pix via Open Finance',
#              'Relatório e-commerce',
#              '0',
#              '%',
#              'crescimento anual do e-commerce brasileiro até 2026,',
#              'chegando a US$ 432 bilhões.*',
#              '0',
#              '%',
#              'estimativa de representação do',
#              'Pix no total de transações no e-commerce',
#              'até 2025.*',
#              '0',
#              '%',
#              'da população adulta do Brasil usa o Pix',
#              ', enquanto apenas 37% têm cartão de crédito.*',
#              '0',
#              '%',
#              'dos consumidores desistem de concluir pedidos, sobretudo por',
#              'frete alto e checkout burocrático.**',
#              '*fonte: Relatório Americas Market Intelligence (AMI)',
#              '**fonte: Pesquisa Abandono de Carrinho 2022 da Opinion Box',
#              'Carrinho perdido?',
#              'Não com o Pix via Open Finance da Efí Pay',
#              'A nossa tecnologia te ajuda a oferecer uma melhor experiência de '
#              'compra, reduzir o abandono de carrinho e realizar uma',
#              'gestão de recebimentos muito mais eficiente.',
#              'Checkout rápido, fluido e',
#              'com apenas 3 passos',
#              'Sua jornada de pagamento tão simples que o cliente',
#              'não vai mais precisar mudar de app manualmente.',
#              'A gente conecta seu e-commerce aos bancos e o seu cliente só '
#              'precisar dar um “confirma” para transferir direto da conta '
#              'bancária. Simples assim!',
#              'Tenho interesse',
#              'Seu navegador não suporta a tag de "video"',
#              'Até então, para pagar por um produto no seu e-commerce, o '
#              'consumidor precisa emitir e pagar o boleto bancário, digitar os '
#              'dados do cartão de crédito ou copiar o código do Pix para '
#              'colá-lo na plataforma do banco ou conta digital. Esses '
#              'intervalos podem influenciar na',
#              'desistência da compra',
#              '.',
#              'Agora, imagine o seu cliente precisar apenas escolher, ainda na '
#              'tela de pagamento do seu e-commerce, por qual banco vai pagar e '
#              'autorizar a transação? Isso é a',
#              'Iniciação de Pagamento do Open Finance!🧡',
#              'Eleve o nível - e as métricas -',
#              'das vendas no seu site',
#              'Aproveite a mais alta tecnologia da Efí Pay a favor do seu '
#              'negócio!',
#              'Regulado pelo Banco Central',
#              'Seguro, regulado pelo Bacen e em conformidade com a LGPD, como '
#              'deve ser.',
#              'Conexão com vários bancos',
#              'Conexão automática com todas as instituições participantes do '
#              'Open Finance.',
#              'Implementação em 1 sprint',
#              'Documentação aberta, SDKs em todas as linguagens e suporte '
#              'técnico disponível.',
#              'Aumento da conversão e das vendas',
#              'Jornada de compra com apenas 3 etapas para parar de perder '
#              'vendas importantes.',
#              'Recebimento em tempo real',
#              'Pix + Open Finance = venda mais rápida e saldo disponível em até '
#              '10 segundos.',
#              'Vai participar do',
#              'Fórum E-commerce Brasil 2023',
#              'Encontre-se com a gente para conhecer e experimentar o Pix via '
#              'Open Finance da Efí Pay.',
#              'Palestra inédita',
#              'Conheça o case de sucesso da API Pix, cocriada com a maior '
#              'comunidade de integração de meios de pagamento do Brasil no '
#              'Discord, apresentada pelo nosso Diretor de Produtos, Danilo '
#              'Oliveira.',
#              '27 de Julho às 10h10',
#              'Palco Soluções - Fórum E-commerce Brasil 23',
#              'Imersão Open Finance',
#              'Experimente o Pix via Open Finance, na prática, em um totem '
#              'interativo no nosso estande e conheça todo seu potencial na '
#              'redução de abandono de carrinho.',
#              'Você é nosso convidado!',
#              'Use o cupom para aproveitar o maior evento de e-commerce da '
#              'América Latina com valor promocional.',
#              'F23EFI',
#              'Depoimentos',
#              'A gente facilita',
#              'a vida de quem',
#              'faz acontecer',
#              'A principal solução que o Open Finance nos trouxe foi a '
#              'facilidade na finalização do pagamento, pois 80% dos nossos '
#              'clientes compram via mobile hoje em dia e isso acaba facilitando '
#              'muito a vida do cliente, vira praticamente “um clique” e fim, '
#              'pagamento realizado. Creio que o maior beneficio que tenho com a '
#              'Efí, seja o suporte ágil e o atendimento totalmente '
#              'personalizado. Esse diferencial faz total diferença!',
#              'Fabricio de Matos',
#              'CEO do Rei dos Coins',
#              'Simule agora uma compra',
#              'no ambiente Open Finance!',
#              'Não vai participar do Fórum E-commerce Brasil? Nós pensamos em '
#              'você também!',
#              'Criamos um app que simula a iniciação de pagamento por Pix via '
#              'Open Finance para você experimentar. Baixe o app e simule — é '
#              'simples e gratuito.',
#              '1. adicione o produto no carrinho e vá para tela de checkout;',
#              '2. selecione seu banco ou fintech;',
#              '3. clique em “Pagar com o Pix via Open Finance”;',
#              '4. autorize a transação e conclua o pagamento no próprio app!',
#              'passo anterior',
#              'próximo passo',
#              'Abra sua Conta Grátis'],
#  'description': 'Dê adeus ao abandono de carrinho! Otimize o checkout do seu '
#                 'e-commerce, feche mais vendas e receba na hora. Experimente o '
#                 'Pix via Open Finance da Efí Pay.',
#  'keywords': 'open finance ecommerce',
#  'main_title': 'Dê adeus ao abandono de carrinho e  venda muuuito mais no seu '
#                'e-commerce',
#  'title': 'Pagamentos via Open Finance para e-commerce | Efí Pay',
#  'url': 'https://sejaefi.com.br/lp/open-finance-para-ecommerce'}
# 2024-04-07 19:13:43 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://sejaefi.com.br/webinars/lp-ixc-e-efi> from <GET https://sejaefi.com.br/webinars/lp-ixc-e-efi-success>
# 2024-04-07 19:13:43 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://sejaefi.com.br/webinars/lp-ixc-e-efi> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2024-04-07 19:13:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br/solicitar-cartao-de-credito> (referer: https://sejaefi.com.br/pages-sitemap.xml)
# 2024-04-07 19:13:45 [efi_crawl] INFO: Processing page: https://sejaefi.com.br/solicitar-cartao-de-credito
# 2024-04-07 19:13:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sejaefi.com.br/solicitar-cartao-de-credito>
#
# {'content': ['A Gerencianet agora se chama Efí.',
#              'Saiba mais!',
#              'Abrir menu',
#              'Soluções',
#              'Pelo site ou aplicativo',
#              'Boletos e Carnês',
#              'Conta Digital',
#              'Gestão de Cobranças',
#              'Link de Pagamento',
#              'Pagamento Recorrente',
#              'Por API',
#              'API Boletos e Carnês',
#              'API Pix',
#              'API Pix via Open Finance',
#              'Checkout Transparente',
#              'Split de Pagamento',
#              'Pix Automático',
#              'Novo',
#              'Segmentos',
#              'Provedor de Internet',
#              'Bet - Apostas Esportivas',
#              'Parcerias',
#              'Desenvolvedores',
#              'Efí Pay — Plataforma de pagamentos',
#              'Documentação API',
#              'Módulos e Plugins',
#              'Comunidade no Discord',
#              'Curso API 2.0 grátis',
#              'Tarifas',
#              'Blog',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Entre na lista de espera do',
#              'Cartão de Crédito Efí',
#              'Estamos liberando aos poucos a função crédito* para nossos '
#              'clientes e daremos prioridade, no próximo lote, para quem '
#              'estiver na lista de espera. Inscreva-se abaixo e fique mais '
#              'perto de ter o seu novo cartão de crédito preferido.',
#              'Nome completo:',
#              'E-mail:',
#              'Telefone:',
#              'CPF/CNPJ:',
#              'Declaro que autorizo a consulta ao Sistema de Informações de '
#              'Crédito (SCR) e Serasa e estou de acordo com a',
#              'Política de Privacidade Efí.',
#              '*Sujeito à análise de crédito',
#              'Enviar',
#              'Abra sua Conta Grátis'],
#  'description': '',
#  'keywords': '',
#  'main_title': 'Entre na lista de espera do  Cartão de Crédito Efí',
#  'title': 'Efí',
#  'url': 'https://sejaefi.com.br/solicitar-cartao-de-credito'}
# 2024-04-07 19:13:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br/lp/blackfriday-efibank-2023> (referer: https://sejaefi.com.br/pages-sitemap.xml)
# 2024-04-07 19:13:46 [efi_crawl] INFO: Processing page: https://sejaefi.com.br/lp/blackfriday-efibank-2023
# 2024-04-07 19:13:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sejaefi.com.br/lp/blackfriday-efibank-2023>
#
# {'content': ['A Gerencianet agora se chama Efí.',
#              'Saiba mais!',
#              'Abrir menu',
#              'Soluções',
#              'Pelo site ou aplicativo',
#              'Boletos e Carnês',
#              'Conta Digital',
#              'Gestão de Cobranças',
#              'Link de Pagamento',
#              'Pagamento Recorrente',
#              'Por API',
#              'API Boletos e Carnês',
#              'API Pix',
#              'API Pix via Open Finance',
#              'Checkout Transparente',
#              'Split de Pagamento',
#              'Pix Automático',
#              'Novo',
#              'Segmentos',
#              'Provedor de Internet',
#              'Bet - Apostas Esportivas',
#              'Parcerias',
#              'Desenvolvedores',
#              'Efí Pay — Plataforma de pagamentos',
#              'Documentação API',
#              'Módulos e Plugins',
#              'Comunidade no Discord',
#              'Curso API 2.0 grátis',
#              'Tarifas',
#              'Blog',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Dê adeus ao abandono de carrinho e',
#              'venda muuuito mais nesta Black Friday',
#              'As melhores ofertas merecem os melhores meios de pagamento. '
#              'Inove as opções do seu e-commerce e transforme cada transação em '
#              'uma oportunidade de encantar seus clientes!',
#              'Fale com nosso time comercial',
#              'Black Friday Efí',
#              'Efí Pay',
#              '67% dos brasileiros',
#              'querem comprar nesta Black Friday',
#              'Diversificar as formas de pagamento no seu e-commerce aumenta as '
#              'chances de conversão em vendas. Na Efí Pay, você encontra várias '
#              'opções em um só lugar!',
#              'Pix',
#              'Receba por Pix e',
#              'otimize todo o processo de venda',
#              'e entrega dos seus produtos.',
#              'Bolix® (boleto + Pix)',
#              'Emita boletos e carnês com',
#              'código de barras e QR Code Pix',
#              '. Pelo Pix, você recebe na hora.',
#              'Carnês',
#              'Faça vendas de alto valor no boleto parcelado e gere',
#              'várias lâminas de carnê',
#              'de uma só vez.',
#              'Links de pagamento',
#              'Gere links de pagamento para enviar ao seu cliente e receber à '
#              'vista no boleto ou em até 12 vezes no cartão de crédito,',
#              'sem precisar de site ou maquininha',
#              '.',
#              'Assinaturas',
#              'Crie planos de assinatura e receba por boleto e cartão de forma',
#              'automática e periódica',
#              '.',
#              'Botão de pagamento',
#              'Gere um botão de pagamento e',
#              'adicione ao seu site',
#              'para receber por boleto ou cartão de crédito.',
#              'Checkout transparente',
#              'Ofereça uma experiência de pagamento mais agradável,',
#              'sem redirecionamentos',
#              'para outro site.',
#              'As melhores tarifas para você vender com a Efí',
#              'Cobrada apenas quando seu cliente pagar você 🧡',
#              'Conheça nossas tarifas',
#              'Experimente a Efí Pay',
#              'Experimente a Efí Pay',
#              'Carrinho perdido?',
#              'Não com o Pix via Open Finance da Efí Pay',
#              'A nossa tecnologia te ajuda a oferecer uma melhor experiência de '
#              'compra, reduzir o abandono de carrinho e realizar uma',
#              'gestão de recebimentos muito mais eficiente.',
#              'Checkout rápido, fluido e',
#              'com apenas 3 passos',
#              'Sua jornada de pagamento tão simples que o cliente',
#              'não vai mais precisar mudar de app manualmente.',
#              'A gente conecta seu e-commerce aos bancos e o seu cliente só '
#              'precisar dar um “confirma” para transferir direto da conta '
#              'bancária. Simples assim!',
#              'Tenho interesse',
#              'Split de pagamentos',
#              'para dividir os recebimentos de forma automatizada',
#              'Faça o repasse automático de pagamentos por boleto, cartão e Pix '
#              'entre dois ou mais recebedores.',
#              'Regras de divisão por percentual, comissão ou valor fixo.',
#              'Repasses em tempo real, sem passar pela conta mestre.',
#              'Visualização dos repasses pela Conta Digital.',
#              'Mais transparência na distribuição dos pagamentos.',
#              'Módulos e plugins',
#              'para plataformas de e-commerce',
#              'Instale em poucos passos e automatize os recebimentos no seu '
#              'e-commerce com uma tecnologia que suporta um alto volume de '
#              'transações por segundo.',
#              'Disponível para Wordpress (WooCommerce), Magento (OpenMage e '
#              'Magento 2), OpenCart, PrestaShop, WHMCS e outros.',
#              'Solicite uma demonstração',
#              'Por que escolher a Efí?',
#              'Simplificando os recebimentos online há mais de 16 anos',
#              'Aproveite a',
#              'mais alta tecnologia da Efí Pay',
#              'a favor do seu e-commerce. Nascemos em 2007, somos',
#              'autorizados pelo Banco Central',
#              'e estamos prontos para revolucionar os pagamentos',
#              'online junto com você!',
#              '🧡',
#              'Temos mais de',
#              '480',
#              'mil',
#              'clientes',
#              'Mais de',
#              '6',
#              'bilhões',
#              'de transações',
#              'nas APIs em 2023',
#              'Processamos',
#              '283',
#              'milhões',
#              'de emissões anuais',
#              'de cobrança',
#              'Mais de',
#              'R$',
#              '27',
#              'bilhões',
#              'movimentados',
#              'em 2023',
#              'Pare de perder',
#              'vendas importantes',
#              'Dê aos clientes o que eles realmente querem. Use a Efí Pay e '
#              'lucre mais nesta Black Friday!',
#              'Solicite um contato',
#              'Abra sua Conta Grátis'],
#  'description': '',
#  'keywords': '',
#  'main_title': 'Dê adeus ao abandono de carrinho e  venda muuuito mais nesta '
#                'Black Friday',
#  'title': 'Efí',
#  'url': 'https://sejaefi.com.br/lp/blackfriday-efibank-2023'}
# 2024-04-07 19:13:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br/efi-pay/gestao-de-cobrancas> (referer: https://sejaefi.com.br/pages-sitemap.xml)
# 2024-04-07 19:13:47 [efi_crawl] INFO: Processing page: https://sejaefi.com.br/efi-pay/gestao-de-cobrancas
# 2024-04-07 19:13:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sejaefi.com.br/efi-pay/gestao-de-cobrancas>
#
# {'content': ['A Gerencianet agora se chama Efí.',
#              'Saiba mais!',
#              'Abrir menu',
#              'Soluções',
#              'Pelo site ou aplicativo',
#              'Boletos e Carnês',
#              'Conta Digital',
#              'Gestão de Cobranças',
#              'Link de Pagamento',
#              'Pagamento Recorrente',
#              'Por API',
#              'API Boletos e Carnês',
#              'API Pix',
#              'API Pix via Open Finance',
#              'Checkout Transparente',
#              'Split de Pagamento',
#              'Pix Automático',
#              'Novo',
#              'Segmentos',
#              'Provedor de Internet',
#              'Bet - Apostas Esportivas',
#              'Parcerias',
#              'Desenvolvedores',
#              'Efí Pay — Plataforma de pagamentos',
#              'Documentação API',
#              'Módulos e Plugins',
#              'Comunidade no Discord',
#              'Curso API 2.0 grátis',
#              'Tarifas',
#              'Blog',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Gestão de Cobranças',
#              'Para cobrar, receber e gerir com',
#              'praticidade',
#              'Inove os',
#              'meios de pagamento',
#              'do seu negócio e transforme cada transação em uma oportunidade '
#              'de',
#              'encantar seus clientes.',
#              'Quero emitir cobranças grátis',
#              'Seu negócio é único.',
#              'A forma que você vende também!',
#              'Emita suas cobranças',
#              'grátis',
#              ', receba por',
#              'boleto',
#              'e',
#              'cartão, gerencie tudo em um painel completo de pagamentos e só '
#              'pague tarifas se seu cliente pagar você.',
#              'Todas opções de pagamento estão integradas nas contas',
#              'Efí Pro',
#              'e',
#              'Efí Empresas.',
#              'Bolix (boleto + Pix)',
#              'Emita boletos e carnês com',
#              'código de barras e QR Code Pix',
#              'e deixe que seu cliente escolha como quer pagar.',
#              'Recebimento em tempo real via QR Code Pix.',
#              'Solução 2 em 1 com tarifa única.',
#              'Cancelamento automático de um código quando o outro é utilizado.',
#              'Ativação em apenas um clique, sem qualquer integração.',
#              'Carnês',
#              'Faça vendas de alto valor no boleto parcelado e gere lâminas de '
#              'carnê para até 24 parcelas de uma só vez.',
#              'Sem tarifas de emissão, baixa ou cancelamento.',
#              'Configuração de juros, multas e descontos.',
#              'Carnês registrados e aceitos mesmo após o vencimento.',
#              'Uma opção de parcelamento sem a necessidade de cartão de '
#              'crédito.',
#              'Links de pagamento',
#              'Gere links de pagamento para cobrar pela internet e receber à '
#              'vista no boleto ou em até 12 vezes no cartão.',
#              'Elimina a necessidade de site ou maquininha.',
#              'Fácil de compartilhar por WhatsApp ou redes sociais.',
#              'Tela de pagamento personalizável com cores e logo da marca.',
#              'Cadastro de produtos, serviços e preços na plataforma para maior '
#              'conveniência.',
#              'Botão de pagamento',
#              'Gere um botão de pagamento e adicione ao seu site para receber '
#              'por boleto ou cartão de crédito.',
#              'Botões personalizáveis.',
#              'Recebimento disponível para pagamentos únicos ou recorrentes.',
#              'Opção de solicitar o endereço de entrega e adicionar uma taxa de '
#              'frete.',
#              'Ideal para usuários sem conhecimentos avançados em programação.',
#              'Pagamento recorrente',
#              'Crie planos de assinaturas mensais, semestrais e até anuais para '
#              'receber pagamentos via boleto ou cartão.',
#              'Cobrança automática no boleto e na fatura do cartão.',
#              'Cadastro de clientes e planos de assinatura ilimitados.',
#              'Periodicidade personalizável.',
#              'Mais previsibilidade financeira.',
#              'Checkout transparente',
#              'Ofereça uma experiência de pagamento mais agradável e protegida, '
#              'sem redirecionamentos para outro site.',
#              'Compatível com as principais plataformas de e-commerce.',
#              'Design responsivo para todos os tamanhos de tela.',
#              'Dados transacionais criptografados.',
#              'Agilidade na confirmação do pedido.',
#              'Split de pagamento',
#              'Faça o repasse automático de pagamentos por boleto, cartão e Pix '
#              'entre dois ou mais recebedores.',
#              'Regras de divisão por percentual, comissão ou valor fixo.',
#              'Repasses em tempo real, sem passar pela conta mestre.',
#              'Visualização dos repasses pela Conta Digital.',
#              'Mais transparência na distribuição dos pagamentos.',
#              'Quero vender com a Efí Pay',
#              'Descubra as tarifas Efí',
#              'API Cobranças',
#              'Suas cobranças no',
#              'automático',
#              'Mais tempo para focar no seu core business é o que você precisa? '
#              'Integre, automatize e escale suas vendas com a mais avançada '
#              'tecnologia de pagamentos do mercado.',
#              'APIs robustas, no padrão do Banco Central.',
#              'SDKs disponíveis em todas as linguagens de programação.',
#              'Integração simples e customizável de acordo com seu modelo de '
#              'negócio.',
#              'Emissão de cobranças automatizada.',
#              'Suporte técnico de alto nível para apoiar seu integrador em '
#              'todas as etapas.',
#              'Faça uma demonstração gratuita',
#              'Fale com nosso time comercial',
#              'Começar é fácil!',
#              'Abra sua conta em poucos minutos!',
#              'Com a Efí, seu banco está a um clique de distância.',
#              'Você abre sua conta PJ de forma simples,',
#              '100% online e sem custo',
#              '.',
#              '1. Faça seu cadastro',
#              'Informe dados básicos para iniciar o processo de abertura de '
#              'conta.',
#              '2. Baixe o aplicativo',
#              'Baixe grátis o app da Efí para celular na sua loja de '
#              'aplicativos.',
#              '3. Abra sua conta Efí Pro ou Efí Empresas',
#              'Escolha a Efí Pro se ainda não tiver CNPJ ou Efí Empresas se já '
#              'tiver CNPJ.',
#              '4. Aproveite',
#              'Agora é só aproveitar todas as vantagens de ser Efí!',
#              'Quero abrir minha conta grátis',
#              'Torne simples o que parece complexo:',
#              'configure suas cobranças com apenas um clique',
#              'Seu negócio, sua regras!',
#              'Tenha o controle total sobre prazos, valores e métodos de '
#              'pagamento.',
#              'Configure os dados de exibição da cobrança.',
#              'Personalize seus boletos e telas de pagamento com a cor e logo '
#              'da sua marca.',
#              'Escolha como você deseja receber os pagamentos via cartão — à '
#              'vista ou parcelado.',
#              'Adicione juros a partir de uma certa quantidade de parcelas via '
#              'cartão.',
#              'Configure juros, multas e descontos para pagamentos via boletos '
#              'e carnês.',
#              'Você no controle',
#              'Reduza a inadimplência',
#              'com uma régua de cobranças que trabalha por você',
#              'Programe uma',
#              'sequência de lembretes',
#              'sobre o vencimento das cobranças. Você ativa o disparo e a gente '
#              'cuida de tudo!',
#              'Cobrança emitida e enviada',
#              '5 dias antes do vencimento',
#              '5 dias antes do vencimento',
#              'Inadimplência identificada',
#              'Confirmação de pagamento manual',
#              'Confirmação de pagamento manual',
#              'Cancelamento de cobrança, assinatura e carnê',
#              'Relatórios completos',
#              'para insights mais profundos',
#              'Mantenha um',
#              'controle detalhado',
#              'de todas as movimentações financeiras e monitore de perto os '
#              'clientes que estão inadimplentes em seu negócio.',
#              'Consolidado',
#              'Receba, todos os dias, na linha do tempo da Conta Digital, um '
#              'resumo otimizado de suas cobranças do dia anterior.',
#              'Visão geral',
#              'Visualize gráficos didáticos com o panorama das suas cobranças. '
#              'Os valores são divididos entre confirmados, a receber e '
#              'inadimplentes.',
#              'Gráfico “Sua evolução”',
#              'Acompanhe um consolidado de entradas e saídas de dinheiro dos '
#              'últimos 12 meses já finalizados.',
#              'Relatórios personalizados',
#              'Gere relatórios de acordo com as suas necessidades de busca. '
#              'Você tem o poder de escolher as informações que serão exibidas.',
#              'Da palma da mão à tela do computador:',
#              'faça sua gestão de qualquer lugar',
#              'Acompanhe o status de todas as suas cobranças em um dashboard '
#              'simples e de onde estiver,',
#              'pelo app',
#              'ou',
#              'plataforma web.',
#              'anterior',
#              'próximo',
#              'Depoimentos',
#              'Inspire-se nos',
#              '+480 mil',
#              'empreendedores',
#              'que',
#              'contam com',
#              'a gente!',
#              'Abra sua conta em minutos',
#              'A principal solução que o Open Finance nos trouxe foi a '
#              'facilidade na finalização do pagamento, pois 80% dos nossos '
#              'clientes compram via mobile hoje em dia e isso acaba facilitando '
#              "muito a vida do cliente, vira praticamente 'um clique' e fim, "
#              'pagamento realizado. Creio que o maior beneficio que tenho com a '
#              'Efí, seja o suporte ágil e o atendimento totalmente '
#              'personalizado. Esse diferencial faz total diferença!',
#              'Fabricio de Matos',
#              'CEO do Rei dos Coins',
#              'A priori, [a Efí] foi a única empresa, que encontramos no nosso '
#              'espectro de busca, que fazia a integração fiel às normas do '
#              'Banco Central. Integramos o Pix com o PDV, funcionou certinho, e '
#              'conseguimos atingir o nosso objetivo.',
#              'Robson Benedito',
#              'CEO da RedeSoft',
#              'Temos a Efí integrada ao nosso ERP onde nossos clientes aceitam '
#              'o orçamento e já pagam online por Pix, cartão de crédito e '
#              'boleto. É demais!',
#              'Valério Ricardo Budke',
#              'Systhesys Tecnologia',
#              'Sou cliente da Efí e gosto muito! Tenho controle total [de '
#              'recebimento] dos meus clientes em uma plataforma fácil e bem '
#              'estruturada. O time de atendimento é ótimo, sempre à disposição '
#              'para resolver qualquer dúvida ou situação. Estou indicando a Efí '
#              'para novos clientes de e-commerce da DDR.',
#              'Daniel Braun',
#              'CEO da DDR Web Studio',
#              'anterior',
#              'próximo',
#              'Atendimento 360º',
#              'para transformar problemas em soluções',
#              'Atendimento humanizado',
#              'Nossos especialistas de atendimento e de suporte técnico estão '
#              'aqui para ajudar você, seja por ticket, chat, telefone ou '
#              'WhatsApp, de segunda a segunda, das 7h às 22h, inclusive em '
#              'feriados.',
#              'Implementação rápida',
#              'Com apoio dos nossos consultores técnicos durante todo o '
#              'processo, é possível integrar as APIs e começar a usar já na '
#              'primeira semana.',
#              'Comunidade no Discord',
#              'Você ainda pode se conectar com a nossa comunidade no Discord '
#              'que reúne +5000 devs e especialistas em integração, para te '
#              'ajudar no dia a dia e trocar insights.',
#              'Faça parte do Discord',
#              'Conheça nossas',
#              'Contas Digitais',
#              'Conta Digital para receber os valores das suas vendas e '
#              'concentrar a vida financeira do seu negócio,',
#              'mesmo que não tenha CNPJ.',
#              'Conheça a Conta Efí Pro',
#              'Conheça a Conta Efí Pro',
#              'Conta Digital completa para receber dos seus clientes e '
#              'administrar',
#              'todas as operações financeiras da sua empresa.',
#              'Conheça a Conta Efí Empresas',
#              'Conheça a Conta Efí Empresas',
#              'Abra sua Conta Grátis'],
#  'description': 'Emita cobranças grátis, receba por boleto ou cartão de '
#                 'crédito e conte com a régua de cobranças automática para '
#                 'reduzir a inadimplência. Experimente agora!',
#  'keywords': 'Gestão de cobranças',
#  'main_title': 'Para cobrar, receber e gerir com  praticidade',
#  'title': 'Gestão de cobranças • Cobre e receba sem complicações | Efí',
#  'url': 'https://sejaefi.com.br/efi-pay/gestao-de-cobrancas'}
# 2024-04-07 19:13:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br/lp/formulario-efi-empresas> (referer: https://sejaefi.com.br/pages-sitemap.xml)
# 2024-04-07 19:13:48 [efi_crawl] INFO: Processing page: https://sejaefi.com.br/lp/formulario-efi-empresas
# 2024-04-07 19:13:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sejaefi.com.br/lp/formulario-efi-empresas>
#
# {'content': ['A Gerencianet agora se chama Efí.',
#              'Saiba mais!',
#              'Abrir menu',
#              'Soluções',
#              'Pelo site ou aplicativo',
#              'Boletos e Carnês',
#              'Conta Digital',
#              'Gestão de Cobranças',
#              'Link de Pagamento',
#              'Pagamento Recorrente',
#              'Por API',
#              'API Boletos e Carnês',
#              'API Pix',
#              'API Pix via Open Finance',
#              'Checkout Transparente',
#              'Split de Pagamento',
#              'Pix Automático',
#              'Novo',
#              'Segmentos',
#              'Provedor de Internet',
#              'Bet - Apostas Esportivas',
#              'Parcerias',
#              'Desenvolvedores',
#              'Efí Pay — Plataforma de pagamentos',
#              'Documentação API',
#              'Módulos e Plugins',
#              'Comunidade no Discord',
#              'Curso API 2.0 grátis',
#              'Tarifas',
#              'Blog',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Efí Empresas',
#              'Conta PJ',
#              'para automatizar a emissão e gestão de cobranças',
#              'Conta Digital PJ grátis equipada com meios de pagamento, APIs de '
#              'alta performance, cartão PJ Visa® Platinum e ferramentas para '
#              'uma gestão 360º da sua empresa.',
#              'O sucesso financeiro da sua empresa começa aqui',
#              'Nome',
#              'E-mail',
#              'Telefone',
#              'CNPJ',
#              'Número de cobranças por mês',
#              'Estou de acordo com a',
#              'Política de Privacidade Efí',
#              'Solicitar contato comercial',
#              'Uma empresa de sucesso',
#              'começa com uma conta PJ completa',
#              'Tenha acesso ilimitado à',
#              'Efí Pay',
#              '—',
#              'ecossistema de meios de pagamento.',
#              'Emita cobranças grátis pelo app ou APIs',
#              'e só pague pelos recebimentos.',
#              'Programe uma régua de cobranças',
#              'que reduz a inadimplência de clientes.',
#              'Adicione usuários secundários',
#              'com diferentes níveis de acesso.',
#              'Solicite um',
#              'cartão PJ Visa® Platinum',
#              'personalizado com a sua marca.',
#              'Solicite cartões corporativos',
#              'na modalidade pré-pago.',
#              'Faça parte do Programa de',
#              'Parcerias da Efí',
#              'e aumente seus ganhos com comissões.',
#              'Pague contas, envie dinheiro, faça recargas e saque',
#              'em qualquer caixa Banco24Horas.',
#              'Fale com nosso time comercial',
#              'Tecnologia integrada na conta',
#              'Mais praticidade para receber,',
#              'menos burocracia para empreender',
#              'API',
#              'Conta Digital',
#              'Pix',
#              'Receba por Pix',
#              'e otimize todo o processo de venda e entrega dos seus produtos.',
#              'API',
#              'Pix via Open Finance',
#              'Conecte-se aos bancos e',
#              'inicie pagamentos',
#              'dentro da sua própria plataforma.',
#              'API',
#              'Conta Digital',
#              'Bolix®',
#              'Emita boletos e carnês com',
#              'código de barras e QR Code Pix.',
#              'Pelo Pix, você recebe na hora.',
#              'API',
#              'Conta Digital',
#              'Carnês',
#              'Faça vendas de alto valor no boleto parcelado e gere',
#              'várias lâminas de carnê',
#              'de uma só vez.',
#              'API',
#              'Conta Digital',
#              'Links de pagamento',
#              'Receba pagamentos por',
#              'aplicativos de mensagem ou redes sociais',
#              'via boleto ou cartão de crédito.',
#              'API',
#              'Conta Digital',
#              'Assinaturas',
#              'Crie planos de assinatura e receba por boleto e cartão de forma',
#              'automática e periódica.',
#              'Conta Digital',
#              'Botão de pagamento',
#              'Gere um botão de pagamento e',
#              'adicione ao seu site',
#              'para receber por boleto ou cartão de crédito.',
#              'API',
#              'Checkout transparente',
#              'Ofereça uma experiência de pagamento mais agradável,',
#              'sem redirecionamentos',
#              'para outro site.',
#              'API',
#              'Split de pagamento',
#              'Faça o',
#              'repasse automático',
#              'de pagamentos por boleto, cartão e Pix entre os recebedores.',
#              'Explore mais',
#              'Quero emitir cobranças grátis',
#              'Suas cobranças no automático:',
#              'integre, automatize e escale suas vendas',
#              'APIs robustas, no',
#              'padrão do Banco Central.',
#              'SDKs disponíveis em',
#              'todas as linguagens de programação.',
#              'Integração',
#              'simples e customizável',
# ...
#              'Ah, e não! Não existe um app dedicado. Com a Efí, você tem tudo '
#              'no mesmo lugar, para facilitar a sua vida!',
#              'Quais APIs estão disponíveis no ecossistema de meios de '
#              'pagamentos da Efí?',
#              'Atualmente, são 6 APIs prontas para integração com e-commerces, '
#              'plataformas e sistemas de gestão:',
#              'API Pix',
#              '— automatiza o envio e recebimento de Pix, com todos os recursos '
#              'disponibilizados pelo Banco Central.',
#              'API Cobranças',
#              '— automatiza a emissão de boletos (Bolix), carnês, links de '
#              'pagamento, botão de pagamento, assinaturas, checkout '
#              'transparente e split de pagamento.',
#              'API Open Finance',
#              ': inicia pagamentos via Pix dentro de sites, apps e plataformas.',
#              'API Abertura de contas',
#              ': possibilita a abertura de contas em lote.',
#              'API Pagamento de contas',
#              ': permite a automação dos pagamentos de contas.',
#              'API Extrato',
#              ': automatiza a conciliação das movimentações da conta.',
#              'É possível usar a Efí Pay em plataformas de e-commerce?',
#              'Sim! A gente pensou em tudo. Além da integração via API, nós '
#              'disponibilizamos também módulos e plugins para plataformas de '
#              'e-commerce, que podem ser instalados em poucos passos — ideal '
#              'também para não desenvolvedores.',
#              'Disponível para Wordpress (WooCommerce), Magento (OpenMage e '
#              'Magento 2), OpenCart, PrestaShop, WHMCS, Box Billing, Joomla '
#              '(VirtueMart) e outros.',
#              'Eu tenho suporte do time de desenvolvedores para fazer a '
#              'integração?',
#              'Sim. Pode contar, que a gente ajuda você em todo o processo! '
#              'Nosso time de Consultoria Técnica está disponível, de segunda a '
#              'segunda, no Discord, para ajudar você com o que for necessário.',
#              'Quais são as tarifas para usar o ecossistema de pagamentos Efí '
#              'Pay?',
#              'Você não paga nada para abrir uma conta nem para começar a usar '
#              'a Efí Pay. A emissão, baixa e cancelamento dos meios de '
#              'pagamento também são gratuitas. A tarifa é apenas por '
#              'recebimento dos produtos que você usar — e isso varia de produto '
#              'para produto.',
#              'Confira todas as tarifas da Efí aqui',
#              'Preciso ter CNPJ para vender com a Efí Pay?',
#              'Na verdade, não! O ecossistema de pagamentos da Efí Pay está '
#              'disponível para as modalidades de conta Efí Pro (empreendedor '
#              'sem CNPJ) e Efí Empresas (conta PJ).',
#              'Portanto,',
#              'se você não tem CNPJ',
#              'mas quer vender com a Efí, basta',
#              'abrir a conta Efí Pro',
#              'e aproveitar todas as vantagens de ser Efí.',
#              'Para onde vai o saldo das vendas realizadas?',
#              'Vem para a sua',
#              'Conta Digital gratuita na Efí',
#              '! É que para usar o ecossistema de pagamentos da Efí Pay, é '
#              'necessário abrir uma conta Efí Pro (empreendedor sem CNPJ) ou '
#              'Efí Empresas (conta PJ). Dessa forma, assim que você receber dos '
#              'seus clientes, o saldo cai direto na conta — já com os descontos '
#              'das tarifas de recebimento e pronto para você usar como '
#              'preferir.',
#              'Ainda tem dúvidas? Visite nossa',
#              'Central de Ajuda.',
#              'minimizar janela',
#              'Tem muitos recebimentos por mês?',
#              'Converse com nosso time comercial e veja todas as vantagens que '
#              'podemos oferecer para sua empresa.',
#              'Sim, quero contato!',
#              'Abra sua Conta Grátis'],
#  'description': 'Melhore a experiência de compra dos seus clientes no ambiente '
#                 'digital com Efí Pay! Garanta a eficiência e segurança que seu '
#                 'negócio precisa.',
#  'keywords': 'Efí Pay, meios de pagamento, receber pagamentos',
#  'main_title': 'Um ecossistema para receber  pagamentos online  desenhado para '
#                'devs e feito para sua empresa  vender mais',
#  'title': 'Plataforma para receber pagamentos online | Efí Pay',
#  'url': 'https://sejaefi.com.br/efi-pay'}
# 2024-04-07 19:14:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br> (referer: https://sejaefi.com.br/pages-sitemap.xml)
# 2024-04-07 19:14:54 [efi_crawl] INFO: Processing page: https://sejaefi.com.br
# 2024-04-07 19:14:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sejaefi.com.br>
#
# {'content': ['A Gerencianet agora se chama Efí.',
#              'Saiba mais!',
#              'Abrir menu',
#              'Soluções',
#              'Pelo site ou aplicativo',
#              'Boletos e Carnês',
#              'Conta Digital',
#              'Gestão de Cobranças',
#              'Link de Pagamento',
#              'Pagamento Recorrente',
#              'Por API',
#              'API Boletos e Carnês',
#              'API Pix',
#              'API Pix via Open Finance',
#              'Checkout Transparente',
#              'Split de Pagamento',
#              'Pix Automático',
#              'Novo',
#              'Segmentos',
#              'Provedor de Internet',
#              'Bet - Apostas Esportivas',
#              'Parcerias',
#              'Desenvolvedores',
#              'Efí Pay — Plataforma de pagamentos',
#              'Documentação API',
#              'Módulos e Plugins',
#              'Comunidade no Discord',
#              'Curso API 2.0 grátis',
#              'Tarifas',
#              'Blog',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Efí Bank',
#              'Especialista em',
#              'automatizar',
#              'e',
#              'simplificar recebimentos',
#              'Abra sua conta grátis',
#              'Fale com o time Comercial',
#              'Plataforma de pagamentos',
#              'Meios de pagamentos modernos, eficientes e seguros sob medida',
#              'para o seu negócio',
#              'Ofereça uma experiência de pagamentos completa com a Efí! Aceite '
#              'diferentes formas de pagamento, como',
#              'Pix, boletos',
#              'e as',
#              'principais bandeiras de cartões de crédito,',
#              'com proteção antifraude e tarifas transparentes. Tudo em um só '
#              'lugar.',
#              'Boleto',
#              'Boleto com QR Code Pix: o jeito mais moderno e rápido de receber '
#              'por boletos.',
#              'Saiba mais',
#              'Pix',
#              'Recebimentos em tempo real com o meio de pagamento mais usado '
#              'pelos brasileiros.',
#              'Saiba mais',
#              'Cartão de crédito',
#              'Pagamentos seguros via cartão de crédito, à vista ou parcelado.',
#              'Pix via Open Finance',
#              'Conecte seu app ou site a todos os bancos e acelere a jornada de '
#              'pagamento do seu cliente.',
#              'Saiba mais',
#              'Como você deseja potencializar seus recebimentos?',
#              'Integrando com as APIs',
#              'da Efí Pay',
#              'Centralize,',
#              'automatize',
#              'e escale a',
#              'emissão de cobranças',
#              'e',
#              'recebimentos',
#              'no seu site ou sistema.',
#              'Explore todas as integrações',
#              'Explore todas as integrações',
#              'Gerenciando pela plataforma ou app da Efí Bank',
#              'Controle toda a',
#              'gestão de cobranças',
#              'na palma da mão e receba pagamentos com',
#              'menos esforço.',
#              'Conheça as possibilidades',
#              'Conheça as possibilidades',
#              'Conta Digital PJ',
#              'Eficiência para impulsionar o sucesso da sua empresa.',
#              'Conte com a Efí!',
#              'A',
#              'Conta Digital PJ',
#              'que é muito mais que conta, é a parceira que descomplica as',
#              'finanças do seu negócio.',
#              'Movimente seu saldo com segurança',
#              'Pague fornecedores de forma fácil',
#              'Simplifique a conciliação bancária',
#              'Financie suas compras com o cartão PJ Visa® Platinum',
#              'Abra sua conta gratuita',
#              'Conheça a Conta Efí Empresas',
#              'Programa de parcerias',
#              'Seja um parceiro Efí Bank',
#              'e cresça junto com a gente!',
#              'Integre nossas',
#              'soluções de pagamento',
#              'ao seu sistema, indique clientes e obtenha uma série de',
#              'benefícios exclusivos.',
#              'Conheça o Programa de Parcerias',
#              'Developer First',
#              'Aqui, o dev é de casa',
#              'Só um',
#              'bank',
#              'que já nasceu',
#              'tech',
#              'ajuda a superar os desafios',
#              'dos desenvolvedores na área financeira. Criamos',
#              'APIs',
#              'com',
#              'arquitetura limpa e moderna,',
#              'SDKs nas principais linguagens de programação e',
#              'garantia de 99,9% de disponibilidade.',
#              '#1 em documentação',
#              'técnica',
#              'Integre as APIs mais bem avaliadas do mercado em',
#              'apenas 3 dias.',
#              'Acesse a documentação',
#              'Maior comunidade',
#              'do Brasil',
#              'Junte-se aos',
#              '+8000 integradores',
#              'apaixonados pelas APIs da Efí no Discord.',
#              'Faça parte',
#              'Curso API 2.0',
#              'com certificado',
#              'Alcance o seu potencial máximo com as videoaulas',
#              'objetivas',
#              'e',
#              'gratuitas',
#              'da Efí.',
#              'Comece agora',
#              'Atendimento',
#              'Pode contar,',
#              'que a gente está junto!',
#              'Parceria de verdade é',
#              'não te deixar na mão.',
#              'Por isso, nosso time de atendimento está pronto para dar todo o '
#              'suporte que você precisa, de',
#              'segunda a segunda',
#              '— por',
#              'chat, telefone',
#              'ou',
#              'WhatsApp.',
#              'Veja como falar com a Efí',
#              'Ir para a Central de Ajuda',
#              'Eficiência,',
#              'isso conta muito',
#              'Somos a',
#              'Efí Bank,',
#              'a evolução da Gerencianet. Temos a solidez dos bancos '
#              'tradicionais e a inovação de uma Conta Digital equipada com um '
#              'ecossistema completo de meios de pagamento.',
#              'Mais modernos do que nunca, queremos somar ainda mais tecnologia '
#              'e atendimento humanizado para te ajudar a crescer.',
#              'Conte com a gente!',
#              'Conheça a Efí',
#              'Por que',
#              '+480 mil clientes',
#              'confiam na Efí para cuidar dos recebimentos?',
#              'Temos mais de',
#              '16',
#              'anos',
#              'de experiência',
#              'Mais de',
#              'R$',
#              '27',
#              'bilhões',
#              'movimentados',
#              'em 2023',
#              'Mais de',
#              '6',
#              'bilhões',
#              'de transações',
#              'nas APIs',
#              '364',
#              'é o nosso',
#              'código bancário',
#              'Reclame Aqui',
#              '9.0',
#              '/ 10',
#              'Google play',
#              '4.6',
#              '/ 5',
#              'App Store',
#              '4.5',
#              '/ 5',
#              'Excelente aplicativo, muita solução pra quem quer mexer com '
#              'clientes por meio de boletos, pix... PF ou PJ! O atendimento do '
#              'pessoal do app é rápido e eficiente! Recomendo!',
#              'Google Play',
#              'Excelente atendimento, rápido e eficiente, conta personalizada e '
#              'sempre com novidades pra melhorar sua gestão financeira na '
#              'empresa. Só parabenizar e agradecer aos colaboradores.',
#              'Google Play',
#              'Muito bom App fora a empresa que fornece api e ainda melhor que '
#              'tem quase tudo pronto só basta integrar ao seu sistema hoje '
#              'deixei de usar outras devido a facilidade de integração',
#              'App Store',
#              'Sou cliente desde que emitia somente boletos. Muitas '
#              'possibilidades e ferramentas fáceis de uso. Sempre com novs '
#              'funcionalidades e soluções. Top 10!',
#              'App Store',
#              'Efí é um banco que tem me ajudado bastante com meu negócio como '
#              'pessoa física... Só tenho a agradecer, resolveu os problemas que '
#              'eu tinha, com a Efí sou maisorganizada, e meus clientes estão '
#              'satisfeitos com as soluções que possibilito a eles.',
#              'Google Play',
#              'Fiquei muito agradecido pela compreensão do banco efí. Isso '
#              'demonstra que o banco está em perfeita sintonia com quem de fato '
#              'trabalha e usam seus produtos com sinceridade e compromisso '
#              'sério. Nota mil!',
#              'Reclame Aqui',
#              'Após a reclamação a empresa se dedicou e resolveu o problema. '
#              'Ofereceu um ótimo atendimento. Com certeza vou manter a '
#              'parceria.',
#              'Reclame Aqui',
#              'Quero estender meu agradecimento ao banco EFÍ, pois deram todo o '
#              'suporte e a atenção para o problema, e conseguimos resolver. E '
#              'todos os boletos que estavam indevidamente no meu nome e CPF '
#              'foram retirados.',
#              'Reclame Aqui',
#              'anterior',
#              'próximo',
#              'Efí na mídia',
#              'minimizar janela',
#              'Tem muitos recebimentos por mês?',
#              'Converse com nosso time comercial e veja todas as vantagens que '
#              'podemos oferecer para sua empresa.',
#              'Sim, quero contato!',
#              'Abra sua Conta Grátis'],
#  'description': 'Uma soma de bank e tech para facilitar sua vida financeira. '
#                 'Conta Digital PF e PJ gratuita, investimentos, gestão de '
#                 'cobranças, APIs e muito +.',
#  'keywords': 'Efí, Gerencianet',
#  'main_title': 'Efí Bank',
#  'title': 'Efí • Conta Digital + soluções de pagamentos online',
#  'url': 'https://sejaefi.com.br'}
# 2024-04-07 19:14:54 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-04-07 19:14:54 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 17306,
#  'downloader/request_count': 63,
#  'downloader/request_method_count/GET': 63,
#  'downloader/response_bytes': 3555281,
#  'downloader/response_count': 63,
#  'downloader/response_status_count/200': 62,
#  'downloader/response_status_count/302': 1,
#  'dupefilter/filtered': 1,
#  'elapsed_time_seconds': 75.725058,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 4, 7, 22, 14, 54, 812975, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 34050209,
#  'httpcompression/response_count': 62,
#  'item_scraped_count': 59,
#  'log_count/DEBUG': 124,
#  'log_count/INFO': 130,
#  'log_count/WARNING': 1,
#  'request_depth_max': 1,
#  'response_received_count': 62,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 62,
#  'scheduler/dequeued/memory': 62,
#  'scheduler/enqueued': 62,
#  'scheduler/enqueued/memory': 62,
#  'start_time': datetime.datetime(2024, 4, 7, 22, 13, 39, 87917, tzinfo=datetime.timezone.utc)}
# 2024-04-07 19:14:54 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# # Buscador (processamento de consultas do usuário)
#
# - Carregamento do Índice Invertido e TF-IDFa partir do arquivo JSON gerado pela pipeline TfidfCalculationPipeline.
# - Função para processar a consulta do usuário, seguindo os mesmos passos de pré-processamento realizados pela pipeline TfidfCalculationPipeline.
#     - Tokenizar a consulta, remover as stopwords, lematizar as palavras restantes usando o spaCy e obter uma lista de termos da consulta.
# - Função para calcular a pontuação de relevância dos documentos em relação à consulta. Calcular a soma das pontuações TF-IDF dos termos da consulta presentes em cada documento.
#
# Se der tempo: implementar algoritmos de ranking, como o BM25 ou o algoritmo de pesquisa vetorial.
# - Ordenar os documentos por ordem decrescente de pontuação de relevância.
# - Apresentação dos Resultados: Exibir os títulos e URLs.

# %%
import json
import spacy

# Carregar o modelo do spaCy
nlp = spacy.load('pt_core_news_sm')

def load_tfidf_index(file_path='tfidf_index.json'):
    """Carrega o índice TF-IDF do arquivo JSON especificado."""
    with open(file_path, 'r', encoding='utf-8') as file:
        tfidf_index = json.load(file)
    return tfidf_index

def process_query(query):
    """Processa a consulta do usuário usando o spaCy."""
    doc = nlp(query.lower())
    filtered_tokens = [token.lemma_ for token in doc if not token.is_stop and token.is_alpha]
    return filtered_tokens

def calculate_relevance_scores(processed_query, tfidf_index):
    """Calcula as pontuações de relevância para cada documento."""
    scores = {}
    for term in processed_query:
        for doc_url, terms_scores in tfidf_index.items():
            if term in terms_scores:
                if doc_url not in scores:
                    scores[doc_url] = 0
                scores[doc_url] += terms_scores[term]
    
    sorted_scores = sorted(scores.items(), key=lambda item: item[1], reverse=True)
    return sorted_scores

def load_collected_data(file_path='output-pipeline-completo.json'):
    """Carrega os dados coletados do arquivo JSON especificado."""
    with open(file_path, 'r', encoding='utf-8') as file:
        data = [json.loads(line) for line in file]
    return data

def display_results(sorted_scores, collected_data):
    """Exibe os resultados, mostrando os títulos e URLs dos documentos com score maior que zero."""
    url_to_data = {item['url']: item for item in collected_data}
    filtered_scores = [score for score in sorted_scores if score[1] > 0]  # Filtra scores maiores que zero

    if not filtered_scores:  # Verifica se há resultados para mostrar
        print("Nenhum resultado encontrado.")
        return

    for url, score in filtered_scores: 
        data = url_to_data.get(url, {})
        title = data.get('main_title', 'No title available')
        print(f"Title: {title}\nURL: {url}\nScore: {score:.2f}\n")


# Exemplo de uso completo
# Carregar o índice TF-IDF e os dados coletados
tfidf_index = load_tfidf_index()
collected_data = load_collected_data()

# Processar uma consulta do usuário
query = "birôs de crédito"
processed_query = process_query(query)

# Calcular e exibir as pontuações de relevância
sorted_scores = calculate_relevance_scores(processed_query, tfidf_index)
display_results(sorted_scores, collected_data)
# Out:
# Title: Desenrola com a  Efí Bank:
# URL: https://sejaefi.com.br/desenrola-brasil
# Score: 0.03
#
# Title: Entre na lista de espera do  Cartão de Crédito Efí
# URL: https://sejaefi.com.br/solicitar-cartao-de-credito
# Score: 0.02
#
# Title: Cotação  do dólar
# URL: https://sejaefi.com.br/cotacao-do-dolar
# Score: 0.02
#
# Title: Parceria: SophiA & Efí (antiga Gerencianet)
# URL: https://sejaefi.com.br/formularios/sophia
# Score: 0.02
#
# Title: Termos e  contratos
# URL: https://sejaefi.com.br/termos-e-contratos
# Score: 0.02
#
# Title: Efí Bank: uma Conta Digital completa para o seu negócio
# URL: https://sejaefi.com.br/formularios/contate-nosso-especialista
# Score: 0.01
#
# Title: Efí Bank + IXC Soft = desconto especial para você receber por Pix, Bolix (boletos + Pix) e cartão de crédito
# URL: https://sejaefi.com.br/formularios/parceria-ixc-soft
# Score: 0.01
#
# Title: Peça já sua Maquininha de Cartão da Efí
# URL: https://sejaefi.com.br/formularios/solicitar-maquininha
# Score: 0.01
#
# Title: A Conta PJ com soluções de recebimento que seu negócio precisa
# URL: https://sejaefi.com.br/formularios/expo-empreendedor-2023
# Score: 0.01
#
# Title: Tarifas
# URL: https://sejaefi.com.br/tarifas
# Score: 0.01
#
# Title: Dê adeus ao abandono de carrinho e  venda muuuito mais nesta Black Friday
# URL: https://sejaefi.com.br/lp/blackfriday-efibank-2023
# Score: 0.01
#
# Title: Efí Empresas:
# URL: https://sejaefi.com.br/lp/sistema-de-pagamento-para-provedores
# Score: 0.01
#
# Title: Governança  corporativa
# URL: https://sejaefi.com.br/governanca-corporativa
# Score: 0.01
#
# Title: Negocie os débitos  do seu Cartão de Crédito Efí
# URL: https://sejaefi.com.br/renegocie
# Score: 0.01
#
# Title: Dê adeus ao abandono de carrinho e  venda muuuito mais no seu e-commerce
# URL: https://sejaefi.com.br/lp/open-finance-para-ecommerce
# Score: 0.01
#
# Title: Pix Automático  A evolução do pagamento recorrente
# URL: https://sejaefi.com.br/efi-pay/pix-automatico
# Score: 0.01
#
# Title: Efí Bank
# URL: https://sejaefi.com.br
# Score: 0.01
#
# Title: Efí Empresas
# URL: https://sejaefi.com.br/lp/formulario-efi-empresas
# Score: 0.00
#
# Title: Vem com a gente  transformar a gestão de recebimentos dos seus clientes
# URL: https://sejaefi.com.br/programa-de-parceria
# Score: 0.00
#
# Title: O controle das suas finanças na sua mão,  no celular e onde você estiver
# URL: https://sejaefi.com.br/efi-bank/efi-para-voce
# Score: 0.00
#
# Title: Emita boletos, cobre seus clientes e  receba em tempo real  — fácil assim!
# URL: https://sejaefi.com.br/efi-pay/boletos
# Score: 0.00
#
# Title: Para cobrar, receber e gerir com  praticidade
# URL: https://sejaefi.com.br/efi-pay/gestao-de-cobrancas
# Score: 0.00
#
# Title: Feitos para transformar sonhos em realidade,  simplificando a gestão financeira de pessoas e empresas
# URL: https://sejaefi.com.br/sobre-a-efi
# Score: 0.00
#
# Title: Seja parte do futuro  dos pagamentos online com o Open Finance
# URL: https://sejaefi.com.br/efi-pay/api-open-finance
# Score: 0.00
#
# Title: Mais que empreender,  transformar todo seu potencial em negócio
# URL: https://sejaefi.com.br/efi-bank/efi-pro
# Score: 0.00
#
# Title: Efí Bank
# URL: https://sejaefi.com.br/efi-bank
# Score: 0.00
#
# Title: Efí Empresas  Conta Digital PJ com  meios de pagamento  sob medida para o seu negócio
# URL: https://sejaefi.com.br/efi-bank/efi-empresas
# Score: 0.00
#
# Title: Um ecossistema para receber  pagamentos online  desenhado para devs e feito para sua empresa  vender mais
# URL: https://sejaefi.com.br/efi-pay
# Score: 0.00
