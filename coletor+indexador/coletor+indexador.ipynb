# %% [markdown]
# ## Especialização em Inteligência Artificial – IFMG
# ### Recuperação da Informação: Atividade 2: Coletor + Indexador
#
# **Aluno**: Alexandre Fortes Santana
#
# **Professor**: Moisés Ramos
#
# [Notebook: https://github.com/alexandrefortes/recuperacao-de-dados/blob/main/coletor.ipynb](https://github.com/alexandrefortes/recuperacao-de-dados/blob/main/coletor.ipynb)

# %% [markdown]
# #### Escopo
# - Coletar o conteúdo do portal da Efí Bank (https://sejaefi.com.br);
# - Utilizar Scrapy;
# - Para fins didáticos, ignorar contepudos da '/central-de-ajuda' e do /blog;
# - Armazenar os dados em .json;
# - Mecanismo para minimizar a sobrecarga no portal;
# - A partir de todo o conteúdo coletado, implementar o indexador sob a abordagem de uma lista invertida (também chamada de índice invertido).
# - Implementar uma forma de avaliar a força da palavra ao indexá-la na base de dados, ou seja, o quanto ela é rara na base, ou frequente em cada página, ou a relevância dela no conjunto de palavras de cada página, etc.
# - Implementar alguma forma para detectar a codificação das palavras e tratar isso durante a indexação (lembrando que essa forma de tratamento deve aparecer depois ao tratar as palavras de pesquisa).

# %% [markdown]
# #### Código
#
# **Coletor para entrega do trabalho**: https://github.com/alexandrefortes/recuperacao-de-dados/tree/main/scrapy

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# %%
import subprocess
import sys

def run_spider(spider_file):
    # Executa em um processo separado.
    
    cmd = [sys.executable, spider_file]
    
    # Executa o comando e espera até que o processo seja concluído
    process = subprocess.run(cmd, capture_output=True, text=True)
    
    # Imprime o output do processo
    print(process.stdout)
    
    # Verifica se ocorreu algum erro
    if process.stderr:
        print("Errores encontrados:")
        print(process.stderr)

run_spider('efi_crawl_spider.py')
# Out:
# Errores encontrados:
# 2024-04-02 20:36:03 [scrapy.utils.log] INFO: Scrapy 2.11.1 started (bot: scrapybot)
# 2024-04-02 20:36:03 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.10.4, cssselect 1.2.0, parsel 1.9.0, w3lib 2.1.2, Twisted 24.3.0, Python 3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 24.0.0 (OpenSSL 3.2.1 30 Jan 2024), cryptography 42.0.5, Platform Windows-10-10.0.22621-SP0
# 2024-04-02 20:36:03 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-04-02 20:36:03 [py.warnings] WARNING: c:\Users\alexa\anaconda3\envs\efi_spider\lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024-04-02 20:36:03 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2024-04-02 20:36:03 [scrapy.extensions.telnet] INFO: Telnet Password: a8e0470550a54434
# 2024-04-02 20:36:03 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2024-04-02 20:36:03 [scrapy.crawler] INFO: Overridden settings:
# {'CONCURRENT_REQUESTS_PER_DOMAIN': 2,
#  'DOWNLOAD_DELAY': 1,
#  'ROBOTSTXT_OBEY': True,
#  'USER_AGENT': 'EfiContentTrainer'}
# 2024-04-02 20:36:03 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-04-02 20:36:03 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-04-02 20:36:03 [scrapy.middleware] INFO: Enabled item pipelines:
# ['__main__.DuplicatesPipeline',
#  '__main__.ValidationPipeline',
#  '__main__.DataCleaningPipeline',
#  '__main__.JsonWriterPipeline',
#  '__main__.TfidfCalculationPipeline']
# 2024-04-02 20:36:03 [scrapy.core.engine] INFO: Spider opened
# 2024-04-02 20:36:03 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-04-02 20:36:03 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2024-04-02 20:36:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br/robots.txt> (referer: None)
# 2024-04-02 20:36:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br/pages-sitemap.xml> (referer: None)
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-pay
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/tarifas
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-bank
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/whatsapp
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/materiais
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/renegocie
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/abrir-conta
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/sobre-a-efi
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/confirmacoes
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/fale-conosco
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-pay/api-pix
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-pay/boletos
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/lp/efi-e-w3soft
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/cotacao-do-dolar
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/desenrola-brasil
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-bank/efi-pro
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/lp/efi-e-cerbrum
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/termos-e-contratos
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/programa-de-parceria
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-bank/efi-empresas
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/webinars/lp-ixc-e-efi
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-bank/efi-para-voce
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-pay/pix-automatico
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/governanca-corporativa
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/webinars/live-ixc-e-efi
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-pay/api-open-finance
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/lp/formulario-efi-empresas
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/efi-pay/gestao-de-cobrancas
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/lp/blackfriday-efibank-2023
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/solicitar-cartao-de-credito
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/webinars/lp-ixc-e-efi-success
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/lp/open-finance-para-ecommerce
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/lp/iniciador-de-pagamentos-open-finance
# 2024-04-02 20:36:06 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/lp/sistema-de-pagamento-para-provedores
# 2024-04-02 20:36:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br/formularios-sitemap.xml> (referer: None)
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/sophia
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/sortee
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/comercial
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/seja-parceiro
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-atlaz
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-ispfy
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-quaza
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-clicksi
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-beesweb
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-macsoft
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-ixc-soft
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-altarede
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-kingsoft
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-odvix-efi
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-radiusnet
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/solicitar-maquininha
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-cosmos-wide
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/ecommerce-brasil-2023
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/expo-empreendedor-2023
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/parceria-mapp-sistemas
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/payment-revolution-2023
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/educacional-w3soft-e-efi
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/educacional-cerbrum-e-efi
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/contate-nosso-especialista
# 2024-04-02 20:36:07 [efi_crawl] INFO: Enqueueing URL from sitemap: https://sejaefi.com.br/formularios/emissao-de-boletos-provedores
# 2024-04-02 20:36:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br/lp/sistema-de-pagamento-para-provedores> (referer: https://sejaefi.com.br/pages-sitemap.xml)
# 2024-04-02 20:36:08 [efi_crawl] INFO: Processing page: https://sejaefi.com.br/lp/sistema-de-pagamento-para-provedores
# 2024-04-02 20:36:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sejaefi.com.br/lp/sistema-de-pagamento-para-provedores>
#
# {'content': ['A Gerencianet agora se chama Efí.',
#              'Saiba mais!',
#              'Abra sua conta grátis',
#              'Efí Empresas:',
#              'a',
#              'conta PJ',
#              'com',
#              'sistema de pagamento',
#              'favorito de',
#              '+60% dos provedores de internet',
#              'do Brasil',
#              'Aproveite os',
#              'meios de pagamento',
#              'do mais alto nível,',
#              'automatize a emissão de cobranças em massa',
#              'e conte com ferramentas poderosas para uma',
#              'gestão financeira',
#              'descomplicada — da emissão ao recebimento.',
#              'Quero começar agora',
#              'Provedores',
#              'Cobranças em massa',
#              'Otimize o operacional emitindo',
#              'cobranças em massa',
#              ', sem complicações e de forma',
#              'automatizada',
#              '.',
#              'Pagamento identificado',
#              'Saiba que o seu',
#              'assinante pagou',
#              'antes mesmo do dinheiro cair e agilize o',
#              'religamento da internet',
#              '.',
#              'Régua de cobrança',
#              'Reduza a',
#              'inadimplência',
#              'com uma régua de cobrança automática que',
#              'cobra seus assinantes',
#              'por você.',
#              'Sistema de pagamento',
#              'Os',
#              'meios de pagamento',
#              'que seus assinantes querem e',
#              'seu provedor precisa',
#              'Otimize a',
#              'experiência do seu cliente,',
#              'conte com',
#              'soluções modernas e automatizadas para cobrar e receber e '
#              'aumente a eficiência operacional',
#              'do seu provedor— tudo isso integrado ao seu ERP.',
#              'Saber mais',
#              'Carnês: mensalidades descomplicadas',
#              'Gere e envie 1 carnê com até 24 mensalidades',
#              'de uma só vez.',
#              'Emita boletos híbridos:',
#              'código de barras + QR Code Pix.',
#              'Personalize com a cor e',
#              'logo da sua marca.',
#              'Bolix: boletos híbridos',
#              'Gere boletos com',
#              'código de barras + QR Code Pix.',
#              'Receba',
#              'na hora',
#              'com o Pix e em',
#              'até 1 dia útil',
#              'pelo código de barras.',
#              'Deixe que seu cliente',
#              'escolha como quer pagar.',
#              'Pagamentos recorrentes: fidelização de clientes',
#              'Cadastre clientes e crie',
#              'planos de assinatura ilimitados.',
#              'Gere 1 vez e deixe que a gente envie',
#              'cobranças automáticas todo mês.',
#              'Receba por',
#              'boletos ou cartão de crédito.',
#              'Pix: pagamento instantâneo',
#              'Receba',
#              '24h/7',
#              'dias por semana, incluindo',
#              'feriados.',
#              'Emita cobranças',
#              'imediatas',
#              'e com',
#              'data de vencimento.',
#              'Configure uma',
#              'página de cobrança',
#              'para seus clientes.',
#              'Link de pagamento: via cartão de crédito sem site',
#              'Receba pagamentos',
#              'sem site ou maquininha.',
#              'Facilite o modo de pagar do seu assinante, via',
#              'boleto',
#              'ou',
#              'cartão de crédito.',
#              'Envie as',
#              'cobranças de forma automatizada',
#              'por e-mail.',
#              'Falar com um especialista',
#              'Integre com facilidade',
#              'Implementação simples',
#              'para uma jornada otimizada',
#              'Para simplificar a sua vida,',
#              'a Efí já está conectada com os ERPs de provedores.',
#              'Você não precisa se preocupar com integrações manuais ou '
#              'burocracias para deixar toda sua gestão integrada.',
#              'Integração automática em ERPs parceiros',
#              'Basta configurar e começar a usar.',
#              'Tarifa exclusiva do parceiro para recebimento com desconto.',
#              'Troca de informações de forma automatizada.',
#              'Todo o financeiro conectado ao sistema de gestão sem gargalos.',
#              'Nós estamos onde você está: encontre o seu ERP de Provedores '
#              'aqui',
#              'Provedor, comece agora a emitir cobranças em massa com a Efí',
#              'Receber pagamentos com a Efí',
#              'O combo perfeito',
#              'Sistema de pagamento eficiente e turbinado com uma',
#              'conta PJ completa',
#              'Otimize a rotina de',
#              'pagamentos recebidos',
#              'do seu provedor com',
#              'alta tecnologia',
#              'e',
#              'recursos personalizados.',
#              'Facilite as cobranças e controle o financeiro com inteligência e '
#              'praticidade.',
#              'Efí Empresas',
#              'Efí Empresas',
#              'Conta PJ que facilita a gestão do seu provedor',
#              'Desvie da burocracia dos bancos tradicionais:',
#              'administre todo o financeiro',
#              'do seu provedor com facilidade.',
#              'Adicione',
#              'usuários secundários',
#              'em sua conta e',
#              'personalize',
#              'o que cada um pode fazer.',
#              'Pague contas',
#              'e',
#              'faça transferências TED e Pix',
#              'em poucos cliques e com segurança.',
#              'Acesse a sua conta e',
#              'acompanhe suas cobranças',
#              'pela',
#              'plataforma web',
#              'ou',
#              'aplicativo de celular.',
#              'Solicite um cartão de',
#              'crédito e débito sem anuidade Visa Platinum',
#              'e ganhe pontos com a Livelo.',
#              'Gestão de cobranças',
#              'Ferramentas inteligentes que potencializam a sua gestão',
#              'Com o',
#              'Pagamento Identificado',
#              ', você não precisa mais esperar o dinheiro cair para religar a '
#              'internet do seu assinante.',
#              'Conte com a',
#              'emissão',
#              ',',
#              'baixa',
#              'e o',
#              'cancelamento',
#              'de cobranças',
#              'grátis',
#              '. Com a Efí, você paga apenas',
#              'quando receber.',
#              'Receba um',
#              'resumo diário',
#              'e simplificado dos recebíveis.',
#              'Configure juros, multas e descontos para todas as suas '
#              'cobranças.',
#              'Substitua o',
#              'CNAB',
#              'e',
#              'automatize',
#              'seus arquivos com API.',
#              'Envie',
#              'lembretes automáticos',
#              '5 dias antes da data de vencimento da mensalidade.',
#              'Instituição de Pagamento autorizada pelo',
#              'Banco Central',
#              'Conte com as',
#              'soluções bancárias',
#              'de quem facilita a',
#              'gestão de cobranças',
#              'de milhares de Provedores de Internet há 16 anos, oferecendo uma',
#              'plataforma de pagamentos',
#              'completa e equipada com uma',
#              'Conta PJ',
#              'descomplicada.',
#              'Conheça a Efí Bank',
#              'Temos mais de',
#              '480',
#              'mil',
#              'clientes por',
#              'todo o Brasil',
#              'Temos mais de',
#              '350',
#              'colaboradores',
#              'por aqui',
#              '364',
#              'é o nosso',
#              'código bancário',
#              'Mais de',
#              'R$',
#              '27',
#              'bilhões',
#              'movimentados',
#              'em 2023',
#              'Vem com a gente!',
#              'Inovação é a nossa linguagem.',
#              'Tecnologia é o nosso meio.',
#              'Soluções de pagamentos são a nossa arte.',
#              'Receber pagamentos com a Efí',
#              'Abra sua Conta Grátis'],
#  'description': '',
#  'keywords': '',
#  'main_title': 'Efí Empresas:',
#  'title': 'Efí',
#  'url': 'https://sejaefi.com.br/lp/sistema-de-pagamento-para-provedores'}
# 2024-04-02 20:36:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br/lp/iniciador-de-pagamentos-open-finance> (referer: https://sejaefi.com.br/pages-sitemap.xml)
# 2024-04-02 20:36:09 [efi_crawl] INFO: Processing page: https://sejaefi.com.br/lp/iniciador-de-pagamentos-open-finance
# 2024-04-02 20:36:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sejaefi.com.br/lp/iniciador-de-pagamentos-open-finance>
#
# {'content': ['A Gerencianet agora se chama Efí.',
#              'Saiba mais!',
#              'Abrir menu',
#              'Soluções',
#              'Pelo site ou aplicativo',
#              'Boletos e Carnês',
#              'Conta Digital',
#              'Gestão de Cobranças',
#              'Link de Pagamento',
#              'Pagamento Recorrente',
#              'Por API',
#              'API Boletos e Carnês',
#              'API Pix',
#              'API Pix via Open Finance',
#              'Checkout Transparente',
#              'Split de Pagamento',
#              'Pix Automático',
#              'Novo',
#              'Segmentos',
#              'Provedor de Internet',
#              'Bet - Apostas Esportivas',
#              'Parcerias',
#              'Desenvolvedores',
#              'Efí Pay — Plataforma de pagamentos',
#              'Documentação API',
#              'Módulos e Plugins',
#              'Comunidade no Discord',
#              'Curso API 2.0 grátis',
#              'Tarifas',
#              'Blog',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Pix via Open Finance',
#              'A solução de pagamento feita para',
#              'reduzir o abandono de carrinho',
#              'no e-commerce',
#              'Revolucione a jornada de compra com um',
#              'checkout mais simples, rápido e transparente',
#              'e receba na hora com o',
#              'Pix via Open Finance.',
#              'Fale com nosso time comercial',
#              'Um novo nível para os pagamentos digitais.',
#              'Uma oportunidade para você sair na frente do mercado.',
#              'Preencha o formulário',
#              'para falar com nosso time comercial',
#              'e conhecer todo o potencial dos pagamentos via Open Finance para '
#              'o seu e-commerce.',
#              'Nome completo:',
#              'E-mail:',
#              'Telefone:',
#              'Empresa:',
#              'CNPJ:',
#              'Número de cobranças recebidas por mês:',
#              'Estou de acordo com a',
#              'Política de Privacidade Efí.',
#              'Enviar',
#              'Seus dados estão seguros',
#              'Iniciação de Pagamentos',
#              'Receba pagamentos',
#              'por Pix via Open Finance',
#              'Sua jornada de pagamento tão simples que o cliente não vai mais '
#              'precisar mudar de app manualmente.',
#              'Inicie pagamentos dentro do seu e-commerce se conectando a '
#              'diversos bancos, por meio de uma interface segura, e permita que '
#              'seus clientes autorizem um pagamento por Pix sem sair da tela de '
#              'checkout — encurtando a jornada de pagamento de 7 para 3 etapas.',
#              'Iniciação de pagamentos dentro do seu e-commerce',
#              'Conexão automática com vários bancos',
#              'Checkout rápido, fluido e com apenas 3 etapas',
#              'Jornada de compra ainda mais otimizada',
#              'Fale com nosso time comercial',
#              'API Open Finance',
#              'Construa um novo nível',
#              'de pagamentos online',
#              'Integre seu e-commerce com API Open Finance da Efí, sua '
#              'Iniciadora de Pagamento autorizada pelo Banco Central.',
#              'Oferecemos toda a infraestrutura tecnológica para conectar o seu '
#              'negócio ao ecossistema do Open Finance, de forma simples e '
#              'segura. Assim, você entrega um ambiente de pagamento desenhado '
#              'para melhorar a experiência de compra dos seus clientes no seu '
#              'e-commerce.',
#              'Developer-Friendly API',
#              'Suporte técnico de segunda a segunda',
#              'Comunidade +5000 devs e integradores',
#              'Ambiente Sandbox para testes e homologação',
#              'SDKs em todas as linguagens de programação',
#              'Certificação OpenID',
#              'Tecnologia de ponta',
#              'para escalar sua empresa.',
#              'Fale com nosso time comercial',
#              'Por que escolher a Efí?',
#              'Simplificando os recebimentos online há mais de 16 anos',
#              'Aproveite a',
#              'mais alta tecnologia da Efí Pay',
#              'a favor do seu negócio. Nascemos em 2007, somos',
#              'autorizados pelo Banco Central',
#              'e fomos uma das primeiras instituições habilitadas para atuar '
#              'como Iniciador de Pagamento.',
#              'Estamos prontos para revolucionar os pagamentos',
#              'online junto com você!',
#              '🧡',
#              'Temos mais de',
#              '480',
#              'mil',
#              'clientes',
#              'Mais de',
#              '6',
#              'bilhões',
#              'de transações',
#              'nas APIs em 2023',
#              'Processamos',
#              '283',
#              'milhões',
#              'de emissões anuais',
#              'de cobrança',
#              'Mais de',
#              'R$',
#              '27',
#              'bilhões',
#              'movimentados',
#              'em 2023',
#              'Pare de perder',
#              'vendas importantes',
#              'Dê aos clientes o que eles realmente querem. Conecte-se ao Open '
#              'Finance e simplifique o checkout no seu e-commerce!',
#              'Solicite um contato',
#              'Abra sua Conta Grátis'],
#  'description': '',
#  'keywords': '',
#  'main_title': 'A solução de pagamento feita para  reduzir o abandono de '
#                'carrinho  no e-commerce',
#  'title': 'Efí',
#  'url': 'https://sejaefi.com.br/lp/iniciador-de-pagamentos-open-finance'}
# 2024-04-02 20:36:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br/lp/open-finance-para-ecommerce> (referer: https://sejaefi.com.br/pages-sitemap.xml)
# 2024-04-02 20:36:10 [efi_crawl] INFO: Processing page: https://sejaefi.com.br/lp/open-finance-para-ecommerce
# 2024-04-02 20:36:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sejaefi.com.br/lp/open-finance-para-ecommerce>
#
# {'content': ['A Gerencianet agora se chama Efí.',
#              'Saiba mais!',
#              'Abrir menu',
#              'Soluções',
#              'Pelo site ou aplicativo',
#              'Boletos e Carnês',
#              'Conta Digital',
#              'Gestão de Cobranças',
#              'Link de Pagamento',
#              'Pagamento Recorrente',
#              'Por API',
#              'API Boletos e Carnês',
#              'API Pix',
#              'API Pix via Open Finance',
#              'Checkout Transparente',
#              'Split de Pagamento',
#              'Pix Automático',
#              'Novo',
#              'Segmentos',
#              'Provedor de Internet',
#              'Bet - Apostas Esportivas',
#              'Parcerias',
#              'Desenvolvedores',
#              'Efí Pay — Plataforma de pagamentos',
#              'Documentação API',
#              'Módulos e Plugins',
#              'Comunidade no Discord',
#              'Curso API 2.0 grátis',
#              'Tarifas',
#              'Blog',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Dê adeus ao abandono de carrinho e',
#              'venda muuuito mais no seu e-commerce',
#              'Revolucione a jornada de compra com um checkout mais simples, '
#              'rápido e transparente, feche mais vendas e receba na hora com o '
#              'Pix via Open Finance.',
#              'Quero conhecer o Pix via Open Finance',
#              'Relatório e-commerce',
#              '0',
#              '%',
#              'crescimento anual do e-commerce brasileiro até 2026,',
#              'chegando a US$ 432 bilhões.*',
#              '0',
#              '%',
#              'estimativa de representação do',
#              'Pix no total de transações no e-commerce',
#              'até 2025.*',
#              '0',
#              '%',
#              'da população adulta do Brasil usa o Pix',
#              ', enquanto apenas 37% têm cartão de crédito.*',
#              '0',
#              '%',
#              'dos consumidores desistem de concluir pedidos, sobretudo por',
#              'frete alto e checkout burocrático.**',
#              '*fonte: Relatório Americas Market Intelligence (AMI)',
#              '**fonte: Pesquisa Abandono de Carrinho 2022 da Opinion Box',
#              'Carrinho perdido?',
#              'Não com o Pix via Open Finance da Efí Pay',
#              'A nossa tecnologia te ajuda a oferecer uma melhor experiência de '
#              'compra, reduzir o abandono de carrinho e realizar uma',
#              'gestão de recebimentos muito mais eficiente.',
#              'Checkout rápido, fluido e',
#              'com apenas 3 passos',
#              'Sua jornada de pagamento tão simples que o cliente',
#              'não vai mais precisar mudar de app manualmente.',
#              'A gente conecta seu e-commerce aos bancos e o seu cliente só '
#              'precisar dar um “confirma” para transferir direto da conta '
#              'bancária. Simples assim!',
#              'Tenho interesse',
#              'Seu navegador não suporta a tag de "video"',
#              'Até então, para pagar por um produto no seu e-commerce, o '
#              'consumidor precisa emitir e pagar o boleto bancário, digitar os '
#              'dados do cartão de crédito ou copiar o código do Pix para '
#              'colá-lo na plataforma do banco ou conta digital. Esses '
#              'intervalos podem influenciar na',
#              'desistência da compra',
#              '.',
#              'Agora, imagine o seu cliente precisar apenas escolher, ainda na '
#              'tela de pagamento do seu e-commerce, por qual banco vai pagar e '
#              'autorizar a transação? Isso é a',
#              'Iniciação de Pagamento do Open Finance!🧡',
#              'Eleve o nível - e as métricas -',
#              'das vendas no seu site',
#              'Aproveite a mais alta tecnologia da Efí Pay a favor do seu '
#              'negócio!',
#              'Regulado pelo Banco Central',
#              'Seguro, regulado pelo Bacen e em conformidade com a LGPD, como '
#              'deve ser.',
#              'Conexão com vários bancos',
#              'Conexão automática com todas as instituições participantes do '
#              'Open Finance.',
#              'Implementação em 1 sprint',
#              'Documentação aberta, SDKs em todas as linguagens e suporte '
#              'técnico disponível.',
#              'Aumento da conversão e das vendas',
#              'Jornada de compra com apenas 3 etapas para parar de perder '
#              'vendas importantes.',
#              'Recebimento em tempo real',
#              'Pix + Open Finance = venda mais rápida e saldo disponível em até '
#              '10 segundos.',
#              'Vai participar do',
#              'Fórum E-commerce Brasil 2023',
#              'Encontre-se com a gente para conhecer e experimentar o Pix via '
#              'Open Finance da Efí Pay.',
#              'Palestra inédita',
#              'Conheça o case de sucesso da API Pix, cocriada com a maior '
#              'comunidade de integração de meios de pagamento do Brasil no '
#              'Discord, apresentada pelo nosso Diretor de Produtos, Danilo '
#              'Oliveira.',
#              '27 de Julho às 10h10',
#              'Palco Soluções - Fórum E-commerce Brasil 23',
#              'Imersão Open Finance',
#              'Experimente o Pix via Open Finance, na prática, em um totem '
#              'interativo no nosso estande e conheça todo seu potencial na '
#              'redução de abandono de carrinho.',
#              'Você é nosso convidado!',
#              'Use o cupom para aproveitar o maior evento de e-commerce da '
#              'América Latina com valor promocional.',
#              'F23EFI',
#              'Depoimentos',
#              'A gente facilita',
#              'a vida de quem',
#              'faz acontecer',
#              'A principal solução que o Open Finance nos trouxe foi a '
#              'facilidade na finalização do pagamento, pois 80% dos nossos '
#              'clientes compram via mobile hoje em dia e isso acaba facilitando '
#              'muito a vida do cliente, vira praticamente “um clique” e fim, '
#              'pagamento realizado. Creio que o maior beneficio que tenho com a '
#              'Efí, seja o suporte ágil e o atendimento totalmente '
#              'personalizado. Esse diferencial faz total diferença!',
#              'Fabricio de Matos',
#              'CEO do Rei dos Coins',
#              'Simule agora uma compra',
#              'no ambiente Open Finance!',
#              'Não vai participar do Fórum E-commerce Brasil? Nós pensamos em '
#              'você também!',
#              'Criamos um app que simula a iniciação de pagamento por Pix via '
#              'Open Finance para você experimentar. Baixe o app e simule — é '
#              'simples e gratuito.',
#              '1. adicione o produto no carrinho e vá para tela de checkout;',
#              '2. selecione seu banco ou fintech;',
#              '3. clique em “Pagar com o Pix via Open Finance”;',
#              '4. autorize a transação e conclua o pagamento no próprio app!',
#              'passo anterior',
#              'próximo passo',
#              'Abra sua Conta Grátis'],
#  'description': 'Dê adeus ao abandono de carrinho! Otimize o checkout do seu '
#                 'e-commerce, feche mais vendas e receba na hora. Experimente o '
#                 'Pix via Open Finance da Efí Pay.',
#  'keywords': 'open finance ecommerce',
#  'main_title': 'Dê adeus ao abandono de carrinho e  venda muuuito mais no seu '
#                'e-commerce',
#  'title': 'Pagamentos via Open Finance para e-commerce | Efí Pay',
#  'url': 'https://sejaefi.com.br/lp/open-finance-para-ecommerce'}
# 2024-04-02 20:36:11 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://sejaefi.com.br/webinars/lp-ixc-e-efi> from <GET https://sejaefi.com.br/webinars/lp-ixc-e-efi-success>
# 2024-04-02 20:36:11 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://sejaefi.com.br/webinars/lp-ixc-e-efi> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2024-04-02 20:36:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br/solicitar-cartao-de-credito> (referer: https://sejaefi.com.br/pages-sitemap.xml)
# 2024-04-02 20:36:12 [efi_crawl] INFO: Processing page: https://sejaefi.com.br/solicitar-cartao-de-credito
# 2024-04-02 20:36:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sejaefi.com.br/solicitar-cartao-de-credito>
#
# {'content': ['A Gerencianet agora se chama Efí.',
#              'Saiba mais!',
#              'Abrir menu',
#              'Soluções',
#              'Pelo site ou aplicativo',
#              'Boletos e Carnês',
#              'Conta Digital',
#              'Gestão de Cobranças',
#              'Link de Pagamento',
#              'Pagamento Recorrente',
#              'Por API',
#              'API Boletos e Carnês',
#              'API Pix',
#              'API Pix via Open Finance',
#              'Checkout Transparente',
#              'Split de Pagamento',
#              'Pix Automático',
#              'Novo',
#              'Segmentos',
#              'Provedor de Internet',
#              'Bet - Apostas Esportivas',
#              'Parcerias',
#              'Desenvolvedores',
#              'Efí Pay — Plataforma de pagamentos',
#              'Documentação API',
#              'Módulos e Plugins',
#              'Comunidade no Discord',
#              'Curso API 2.0 grátis',
#              'Tarifas',
#              'Blog',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Entre na lista de espera do',
#              'Cartão de Crédito Efí',
#              'Estamos liberando aos poucos a função crédito* para nossos '
#              'clientes e daremos prioridade, no próximo lote, para quem '
#              'estiver na lista de espera. Inscreva-se abaixo e fique mais '
#              'perto de ter o seu novo cartão de crédito preferido.',
#              'Nome completo:',
#              'E-mail:',
#              'Telefone:',
#              'CPF/CNPJ:',
#              'Declaro que autorizo a consulta ao Sistema de Informações de '
#              'Crédito (SCR) e Serasa e estou de acordo com a',
#              'Política de Privacidade Efí.',
#              '*Sujeito à análise de crédito',
#              'Enviar',
#              'Abra sua Conta Grátis'],
#  'description': '',
#  'keywords': '',
#  'main_title': 'Entre na lista de espera do  Cartão de Crédito Efí',
#  'title': 'Efí',
#  'url': 'https://sejaefi.com.br/solicitar-cartao-de-credito'}
# 2024-04-02 20:36:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br/lp/blackfriday-efibank-2023> (referer: https://sejaefi.com.br/pages-sitemap.xml)
# 2024-04-02 20:36:14 [efi_crawl] INFO: Processing page: https://sejaefi.com.br/lp/blackfriday-efibank-2023
# 2024-04-02 20:36:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sejaefi.com.br/lp/blackfriday-efibank-2023>
#
# {'content': ['A Gerencianet agora se chama Efí.',
#              'Saiba mais!',
#              'Abrir menu',
#              'Soluções',
#              'Pelo site ou aplicativo',
#              'Boletos e Carnês',
#              'Conta Digital',
#              'Gestão de Cobranças',
#              'Link de Pagamento',
#              'Pagamento Recorrente',
#              'Por API',
#              'API Boletos e Carnês',
#              'API Pix',
#              'API Pix via Open Finance',
#              'Checkout Transparente',
#              'Split de Pagamento',
#              'Pix Automático',
#              'Novo',
#              'Segmentos',
#              'Provedor de Internet',
#              'Bet - Apostas Esportivas',
#              'Parcerias',
#              'Desenvolvedores',
#              'Efí Pay — Plataforma de pagamentos',
#              'Documentação API',
#              'Módulos e Plugins',
#              'Comunidade no Discord',
#              'Curso API 2.0 grátis',
#              'Tarifas',
#              'Blog',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Dê adeus ao abandono de carrinho e',
#              'venda muuuito mais nesta Black Friday',
#              'As melhores ofertas merecem os melhores meios de pagamento. '
#              'Inove as opções do seu e-commerce e transforme cada transação em '
#              'uma oportunidade de encantar seus clientes!',
#              'Fale com nosso time comercial',
#              'Black Friday Efí',
#              'Efí Pay',
#              '67% dos brasileiros',
#              'querem comprar nesta Black Friday',
#              'Diversificar as formas de pagamento no seu e-commerce aumenta as '
#              'chances de conversão em vendas. Na Efí Pay, você encontra várias '
#              'opções em um só lugar!',
#              'Pix',
#              'Receba por Pix e',
#              'otimize todo o processo de venda',
#              'e entrega dos seus produtos.',
#              'Bolix® (boleto + Pix)',
#              'Emita boletos e carnês com',
#              'código de barras e QR Code Pix',
#              '. Pelo Pix, você recebe na hora.',
#              'Carnês',
#              'Faça vendas de alto valor no boleto parcelado e gere',
#              'várias lâminas de carnê',
#              'de uma só vez.',
#              'Links de pagamento',
#              'Gere links de pagamento para enviar ao seu cliente e receber à '
#              'vista no boleto ou em até 12 vezes no cartão de crédito,',
#              'sem precisar de site ou maquininha',
#              '.',
#              'Assinaturas',
#              'Crie planos de assinatura e receba por boleto e cartão de forma',
#              'automática e periódica',
#              '.',
#              'Botão de pagamento',
#              'Gere um botão de pagamento e',
#              'adicione ao seu site',
#              'para receber por boleto ou cartão de crédito.',
#              'Checkout transparente',
#              'Ofereça uma experiência de pagamento mais agradável,',
#              'sem redirecionamentos',
#              'para outro site.',
#              'As melhores tarifas para você vender com a Efí',
#              'Cobrada apenas quando seu cliente pagar você 🧡',
#              'Conheça nossas tarifas',
#              'Experimente a Efí Pay',
#              'Experimente a Efí Pay',
#              'Carrinho perdido?',
#              'Não com o Pix via Open Finance da Efí Pay',
#              'A nossa tecnologia te ajuda a oferecer uma melhor experiência de '
#              'compra, reduzir o abandono de carrinho e realizar uma',
#              'gestão de recebimentos muito mais eficiente.',
#              'Checkout rápido, fluido e',
#              'com apenas 3 passos',
#              'Sua jornada de pagamento tão simples que o cliente',
#              'não vai mais precisar mudar de app manualmente.',
#              'A gente conecta seu e-commerce aos bancos e o seu cliente só '
#              'precisar dar um “confirma” para transferir direto da conta '
#              'bancária. Simples assim!',
#              'Tenho interesse',
#              'Split de pagamentos',
#              'para dividir os recebimentos de forma automatizada',
#              'Faça o repasse automático de pagamentos por boleto, cartão e Pix '
#              'entre dois ou mais recebedores.',
#              'Regras de divisão por percentual, comissão ou valor fixo.',
#              'Repasses em tempo real, sem passar pela conta mestre.',
#              'Visualização dos repasses pela Conta Digital.',
#              'Mais transparência na distribuição dos pagamentos.',
#              'Módulos e plugins',
#              'para plataformas de e-commerce',
#              'Instale em poucos passos e automatize os recebimentos no seu '
#              'e-commerce com uma tecnologia que suporta um alto volume de '
#              'transações por segundo.',
#              'Disponível para Wordpress (WooCommerce), Magento (OpenMage e '
#              'Magento 2), OpenCart, PrestaShop, WHMCS e outros.',
#              'Solicite uma demonstração',
#              'Por que escolher a Efí?',
#              'Simplificando os recebimentos online há mais de 16 anos',
#              'Aproveite a',
#              'mais alta tecnologia da Efí Pay',
#              'a favor do seu e-commerce. Nascemos em 2007, somos',
#              'autorizados pelo Banco Central',
#              'e estamos prontos para revolucionar os pagamentos',
#              'online junto com você!',
#              '🧡',
#              'Temos mais de',
#              '480',
#              'mil',
#              'clientes',
#              'Mais de',
#              '6',
#              'bilhões',
#              'de transações',
#              'nas APIs em 2023',
#              'Processamos',
#              '283',
#              'milhões',
#              'de emissões anuais',
#              'de cobrança',
#              'Mais de',
#              'R$',
#              '27',
#              'bilhões',
#              'movimentados',
#              'em 2023',
#              'Pare de perder',
#              'vendas importantes',
#              'Dê aos clientes o que eles realmente querem. Use a Efí Pay e '
#              'lucre mais nesta Black Friday!',
#              'Solicite um contato',
#              'Abra sua Conta Grátis'],
#  'description': '',
#  'keywords': '',
#  'main_title': 'Dê adeus ao abandono de carrinho e  venda muuuito mais nesta '
#                'Black Friday',
#  'title': 'Efí',
#  'url': 'https://sejaefi.com.br/lp/blackfriday-efibank-2023'}
# 2024-04-02 20:36:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br/efi-pay/gestao-de-cobrancas> (referer: https://sejaefi.com.br/pages-sitemap.xml)
# 2024-04-02 20:36:15 [efi_crawl] INFO: Processing page: https://sejaefi.com.br/efi-pay/gestao-de-cobrancas
# 2024-04-02 20:36:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sejaefi.com.br/efi-pay/gestao-de-cobrancas>
#
# {'content': ['A Gerencianet agora se chama Efí.',
#              'Saiba mais!',
#              'Abrir menu',
#              'Soluções',
#              'Pelo site ou aplicativo',
#              'Boletos e Carnês',
#              'Conta Digital',
#              'Gestão de Cobranças',
#              'Link de Pagamento',
#              'Pagamento Recorrente',
#              'Por API',
#              'API Boletos e Carnês',
#              'API Pix',
#              'API Pix via Open Finance',
#              'Checkout Transparente',
#              'Split de Pagamento',
#              'Pix Automático',
#              'Novo',
#              'Segmentos',
#              'Provedor de Internet',
#              'Bet - Apostas Esportivas',
#              'Parcerias',
#              'Desenvolvedores',
#              'Efí Pay — Plataforma de pagamentos',
#              'Documentação API',
#              'Módulos e Plugins',
#              'Comunidade no Discord',
#              'Curso API 2.0 grátis',
#              'Tarifas',
#              'Blog',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Gestão de Cobranças',
#              'Para cobrar, receber e gerir com',
#              'praticidade',
#              'Inove os',
#              'meios de pagamento',
#              'do seu negócio e transforme cada transação em uma oportunidade '
#              'de',
#              'encantar seus clientes.',
#              'Quero emitir cobranças grátis',
#              'Seu negócio é único.',
#              'A forma que você vende também!',
#              'Emita suas cobranças',
#              'grátis',
#              ', receba por',
#              'boleto',
#              'e',
#              'cartão, gerencie tudo em um painel completo de pagamentos e só '
#              'pague tarifas se seu cliente pagar você.',
#              'Todas opções de pagamento estão integradas nas contas',
#              'Efí Pro',
#              'e',
#              'Efí Empresas.',
#              'Bolix (boleto + Pix)',
#              'Emita boletos e carnês com',
#              'código de barras e QR Code Pix',
#              'e deixe que seu cliente escolha como quer pagar.',
#              'Recebimento em tempo real via QR Code Pix.',
#              'Solução 2 em 1 com tarifa única.',
#              'Cancelamento automático de um código quando o outro é utilizado.',
#              'Ativação em apenas um clique, sem qualquer integração.',
#              'Carnês',
#              'Faça vendas de alto valor no boleto parcelado e gere lâminas de '
#              'carnê para até 24 parcelas de uma só vez.',
#              'Sem tarifas de emissão, baixa ou cancelamento.',
#              'Configuração de juros, multas e descontos.',
#              'Carnês registrados e aceitos mesmo após o vencimento.',
#              'Uma opção de parcelamento sem a necessidade de cartão de '
#              'crédito.',
#              'Links de pagamento',
#              'Gere links de pagamento para cobrar pela internet e receber à '
#              'vista no boleto ou em até 12 vezes no cartão.',
#              'Elimina a necessidade de site ou maquininha.',
#              'Fácil de compartilhar por WhatsApp ou redes sociais.',
#              'Tela de pagamento personalizável com cores e logo da marca.',
#              'Cadastro de produtos, serviços e preços na plataforma para maior '
#              'conveniência.',
#              'Botão de pagamento',
#              'Gere um botão de pagamento e adicione ao seu site para receber '
#              'por boleto ou cartão de crédito.',
#              'Botões personalizáveis.',
#              'Recebimento disponível para pagamentos únicos ou recorrentes.',
#              'Opção de solicitar o endereço de entrega e adicionar uma taxa de '
#              'frete.',
#              'Ideal para usuários sem conhecimentos avançados em programação.',
#              'Pagamento recorrente',
#              'Crie planos de assinaturas mensais, semestrais e até anuais para '
#              'receber pagamentos via boleto ou cartão.',
#              'Cobrança automática no boleto e na fatura do cartão.',
#              'Cadastro de clientes e planos de assinatura ilimitados.',
#              'Periodicidade personalizável.',
#              'Mais previsibilidade financeira.',
# ...
#              'Ah, e não! Não existe um app dedicado. Com a Efí, você tem tudo '
#              'no mesmo lugar, para facilitar a sua vida!',
#              'Quais APIs estão disponíveis no ecossistema de meios de '
#              'pagamentos da Efí?',
#              'Atualmente, são 6 APIs prontas para integração com e-commerces, '
#              'plataformas e sistemas de gestão:',
#              'API Pix',
#              '— automatiza o envio e recebimento de Pix, com todos os recursos '
#              'disponibilizados pelo Banco Central.',
#              'API Cobranças',
#              '— automatiza a emissão de boletos (Bolix), carnês, links de '
#              'pagamento, botão de pagamento, assinaturas, checkout '
#              'transparente e split de pagamento.',
#              'API Open Finance',
#              ': inicia pagamentos via Pix dentro de sites, apps e plataformas.',
#              'API Abertura de contas',
#              ': possibilita a abertura de contas em lote.',
#              'API Pagamento de contas',
#              ': permite a automação dos pagamentos de contas.',
#              'API Extrato',
#              ': automatiza a conciliação das movimentações da conta.',
#              'É possível usar a Efí Pay em plataformas de e-commerce?',
#              'Sim! A gente pensou em tudo. Além da integração via API, nós '
#              'disponibilizamos também módulos e plugins para plataformas de '
#              'e-commerce, que podem ser instalados em poucos passos — ideal '
#              'também para não desenvolvedores.',
#              'Disponível para Wordpress (WooCommerce), Magento (OpenMage e '
#              'Magento 2), OpenCart, PrestaShop, WHMCS, Box Billing, Joomla '
#              '(VirtueMart) e outros.',
#              'Eu tenho suporte do time de desenvolvedores para fazer a '
#              'integração?',
#              'Sim. Pode contar, que a gente ajuda você em todo o processo! '
#              'Nosso time de Consultoria Técnica está disponível, de segunda a '
#              'segunda, no Discord, para ajudar você com o que for necessário.',
#              'Quais são as tarifas para usar o ecossistema de pagamentos Efí '
#              'Pay?',
#              'Você não paga nada para abrir uma conta nem para começar a usar '
#              'a Efí Pay. A emissão, baixa e cancelamento dos meios de '
#              'pagamento também são gratuitas. A tarifa é apenas por '
#              'recebimento dos produtos que você usar — e isso varia de produto '
#              'para produto.',
#              'Confira todas as tarifas da Efí aqui',
#              'Preciso ter CNPJ para vender com a Efí Pay?',
#              'Na verdade, não! O ecossistema de pagamentos da Efí Pay está '
#              'disponível para as modalidades de conta Efí Pro (empreendedor '
#              'sem CNPJ) e Efí Empresas (conta PJ).',
#              'Portanto,',
#              'se você não tem CNPJ',
#              'mas quer vender com a Efí, basta',
#              'abrir a conta Efí Pro',
#              'e aproveitar todas as vantagens de ser Efí.',
#              'Para onde vai o saldo das vendas realizadas?',
#              'Vem para a sua',
#              'Conta Digital gratuita na Efí',
#              '! É que para usar o ecossistema de pagamentos da Efí Pay, é '
#              'necessário abrir uma conta Efí Pro (empreendedor sem CNPJ) ou '
#              'Efí Empresas (conta PJ). Dessa forma, assim que você receber dos '
#              'seus clientes, o saldo cai direto na conta — já com os descontos '
#              'das tarifas de recebimento e pronto para você usar como '
#              'preferir.',
#              'Ainda tem dúvidas? Visite nossa',
#              'Central de Ajuda.',
#              'minimizar janela',
#              'Tem muitos recebimentos por mês?',
#              'Converse com nosso time comercial e veja todas as vantagens que '
#              'podemos oferecer para sua empresa.',
#              'Sim, quero contato!',
#              'Abra sua Conta Grátis'],
#  'description': 'Melhore a experiência de compra dos seus clientes no ambiente '
#                 'digital com Efí Pay! Garanta a eficiência e segurança que seu '
#                 'negócio precisa.',
#  'keywords': 'Efí Pay, meios de pagamento, receber pagamentos',
#  'main_title': 'Um ecossistema para receber  pagamentos online  desenhado para '
#                'devs e feito para sua empresa  vender mais',
#  'title': 'Plataforma para receber pagamentos online | Efí Pay',
#  'url': 'https://sejaefi.com.br/efi-pay'}
# 2024-04-02 20:37:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sejaefi.com.br> (referer: https://sejaefi.com.br/pages-sitemap.xml)
# 2024-04-02 20:37:17 [efi_crawl] INFO: Processing page: https://sejaefi.com.br
# 2024-04-02 20:37:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sejaefi.com.br>
#
# {'content': ['A Gerencianet agora se chama Efí.',
#              'Saiba mais!',
#              'Abrir menu',
#              'Soluções',
#              'Pelo site ou aplicativo',
#              'Boletos e Carnês',
#              'Conta Digital',
#              'Gestão de Cobranças',
#              'Link de Pagamento',
#              'Pagamento Recorrente',
#              'Por API',
#              'API Boletos e Carnês',
#              'API Pix',
#              'API Pix via Open Finance',
#              'Checkout Transparente',
#              'Split de Pagamento',
#              'Pix Automático',
#              'Novo',
#              'Segmentos',
#              'Provedor de Internet',
#              'Bet - Apostas Esportivas',
#              'Parcerias',
#              'Desenvolvedores',
#              'Efí Pay — Plataforma de pagamentos',
#              'Documentação API',
#              'Módulos e Plugins',
#              'Comunidade no Discord',
#              'Curso API 2.0 grátis',
#              'Tarifas',
#              'Blog',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Abra sua conta grátis',
#              'Acessar minha conta',
#              'Efí Bank',
#              'Especialista em',
#              'automatizar',
#              'e',
#              'simplificar recebimentos',
#              'Abra sua conta grátis',
#              'Fale com o time Comercial',
#              'Plataforma de pagamentos',
#              'Meios de pagamentos modernos, eficientes e seguros sob medida',
#              'para o seu negócio',
#              'Ofereça uma experiência de pagamentos completa com a Efí! Aceite '
#              'diferentes formas de pagamento, como',
#              'Pix, boletos',
#              'e as',
#              'principais bandeiras de cartões de crédito,',
#              'com proteção antifraude e tarifas transparentes. Tudo em um só '
#              'lugar.',
#              'Boleto',
#              'Boleto com QR Code Pix: o jeito mais moderno e rápido de receber '
#              'por boletos.',
#              'Saiba mais',
#              'Pix',
#              'Recebimentos em tempo real com o meio de pagamento mais usado '
#              'pelos brasileiros.',
#              'Saiba mais',
#              'Cartão de crédito',
#              'Pagamentos seguros via cartão de crédito, à vista ou parcelado.',
#              'Pix via Open Finance',
#              'Conecte seu app ou site a todos os bancos e acelere a jornada de '
#              'pagamento do seu cliente.',
#              'Saiba mais',
#              'Como você deseja potencializar seus recebimentos?',
#              'Integrando com as APIs',
#              'da Efí Pay',
#              'Centralize,',
#              'automatize',
#              'e escale a',
#              'emissão de cobranças',
#              'e',
#              'recebimentos',
#              'no seu site ou sistema.',
#              'Explore todas as integrações',
#              'Explore todas as integrações',
#              'Gerenciando pela plataforma ou app da Efí Bank',
#              'Controle toda a',
#              'gestão de cobranças',
#              'na palma da mão e receba pagamentos com',
#              'menos esforço.',
#              'Conheça as possibilidades',
#              'Conheça as possibilidades',
#              'Conta Digital PJ',
#              'Eficiência para impulsionar o sucesso da sua empresa.',
#              'Conte com a Efí!',
#              'A',
#              'Conta Digital PJ',
#              'que é muito mais que conta, é a parceira que descomplica as',
#              'finanças do seu negócio.',
#              'Movimente seu saldo com segurança',
#              'Pague fornecedores de forma fácil',
#              'Simplifique a conciliação bancária',
#              'Financie suas compras com o cartão PJ Visa® Platinum',
#              'Abra sua conta gratuita',
#              'Conheça a Conta Efí Empresas',
#              'Programa de parcerias',
#              'Seja um parceiro Efí Bank',
#              'e cresça junto com a gente!',
#              'Integre nossas',
#              'soluções de pagamento',
#              'ao seu sistema, indique clientes e obtenha uma série de',
#              'benefícios exclusivos.',
#              'Conheça o Programa de Parcerias',
#              'Developer First',
#              'Aqui, o dev é de casa',
#              'Só um',
#              'bank',
#              'que já nasceu',
#              'tech',
#              'ajuda a superar os desafios',
#              'dos desenvolvedores na área financeira. Criamos',
#              'APIs',
#              'com',
#              'arquitetura limpa e moderna,',
#              'SDKs nas principais linguagens de programação e',
#              'garantia de 99,9% de disponibilidade.',
#              '#1 em documentação',
#              'técnica',
#              'Integre as APIs mais bem avaliadas do mercado em',
#              'apenas 3 dias.',
#              'Acesse a documentação',
#              'Maior comunidade',
#              'do Brasil',
#              'Junte-se aos',
#              '+8000 integradores',
#              'apaixonados pelas APIs da Efí no Discord.',
#              'Faça parte',
#              'Curso API 2.0',
#              'com certificado',
#              'Alcance o seu potencial máximo com as videoaulas',
#              'objetivas',
#              'e',
#              'gratuitas',
#              'da Efí.',
#              'Comece agora',
#              'Atendimento',
#              'Pode contar,',
#              'que a gente está junto!',
#              'Parceria de verdade é',
#              'não te deixar na mão.',
#              'Por isso, nosso time de atendimento está pronto para dar todo o '
#              'suporte que você precisa, de',
#              'segunda a segunda',
#              '— por',
#              'chat, telefone',
#              'ou',
#              'WhatsApp.',
#              'Veja como falar com a Efí',
#              'Ir para a Central de Ajuda',
#              'Eficiência,',
#              'isso conta muito',
#              'Somos a',
#              'Efí Bank,',
#              'a evolução da Gerencianet. Temos a solidez dos bancos '
#              'tradicionais e a inovação de uma Conta Digital equipada com um '
#              'ecossistema completo de meios de pagamento.',
#              'Mais modernos do que nunca, queremos somar ainda mais tecnologia '
#              'e atendimento humanizado para te ajudar a crescer.',
#              'Conte com a gente!',
#              'Conheça a Efí',
#              'Por que',
#              '+480 mil clientes',
#              'confiam na Efí para cuidar dos recebimentos?',
#              'Temos mais de',
#              '16',
#              'anos',
#              'de experiência',
#              'Mais de',
#              'R$',
#              '27',
#              'bilhões',
#              'movimentados',
#              'em 2023',
#              'Mais de',
#              '6',
#              'bilhões',
#              'de transações',
#              'nas APIs',
#              '364',
#              'é o nosso',
#              'código bancário',
#              'Reclame Aqui',
#              '9.0',
#              '/ 10',
#              'Google play',
#              '4.6',
#              '/ 5',
#              'App Store',
#              '4.5',
#              '/ 5',
#              'Excelente aplicativo, muita solução pra quem quer mexer com '
#              'clientes por meio de boletos, pix... PF ou PJ! O atendimento do '
#              'pessoal do app é rápido e eficiente! Recomendo!',
#              'Google Play',
#              'Excelente atendimento, rápido e eficiente, conta personalizada e '
#              'sempre com novidades pra melhorar sua gestão financeira na '
#              'empresa. Só parabenizar e agradecer aos colaboradores.',
#              'Google Play',
#              'Muito bom App fora a empresa que fornece api e ainda melhor que '
#              'tem quase tudo pronto só basta integrar ao seu sistema hoje '
#              'deixei de usar outras devido a facilidade de integração',
#              'App Store',
#              'Sou cliente desde que emitia somente boletos. Muitas '
#              'possibilidades e ferramentas fáceis de uso. Sempre com novs '
#              'funcionalidades e soluções. Top 10!',
#              'App Store',
#              'Efí é um banco que tem me ajudado bastante com meu negócio como '
#              'pessoa física... Só tenho a agradecer, resolveu os problemas que '
#              'eu tinha, com a Efí sou maisorganizada, e meus clientes estão '
#              'satisfeitos com as soluções que possibilito a eles.',
#              'Google Play',
#              'Fiquei muito agradecido pela compreensão do banco efí. Isso '
#              'demonstra que o banco está em perfeita sintonia com quem de fato '
#              'trabalha e usam seus produtos com sinceridade e compromisso '
#              'sério. Nota mil!',
#              'Reclame Aqui',
#              'Após a reclamação a empresa se dedicou e resolveu o problema. '
#              'Ofereceu um ótimo atendimento. Com certeza vou manter a '
#              'parceria.',
#              'Reclame Aqui',
#              'Quero estender meu agradecimento ao banco EFÍ, pois deram todo o '
#              'suporte e a atenção para o problema, e conseguimos resolver. E '
#              'todos os boletos que estavam indevidamente no meu nome e CPF '
#              'foram retirados.',
#              'Reclame Aqui',
#              'anterior',
#              'próximo',
#              'Efí na mídia',
#              'minimizar janela',
#              'Tem muitos recebimentos por mês?',
#              'Converse com nosso time comercial e veja todas as vantagens que '
#              'podemos oferecer para sua empresa.',
#              'Sim, quero contato!',
#              'Abra sua Conta Grátis'],
#  'description': 'Uma soma de bank e tech para facilitar sua vida financeira. '
#                 'Conta Digital PF e PJ gratuita, investimentos, gestão de '
#                 'cobranças, APIs e muito +.',
#  'keywords': 'Efí, Gerencianet',
#  'main_title': 'Efí Bank',
#  'title': 'Efí • Conta Digital + soluções de pagamentos online',
#  'url': 'https://sejaefi.com.br'}
# 2024-04-02 20:37:17 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-04-02 20:37:17 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 17306,
#  'downloader/request_count': 63,
#  'downloader/request_method_count/GET': 63,
#  'downloader/response_bytes': 3573735,
#  'downloader/response_count': 63,
#  'downloader/response_status_count/200': 62,
#  'downloader/response_status_count/302': 1,
#  'dupefilter/filtered': 1,
#  'elapsed_time_seconds': 73.93506,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 4, 2, 23, 37, 17, 849570, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 33959354,
#  'httpcompression/response_count': 62,
#  'item_scraped_count': 59,
#  'log_count/DEBUG': 124,
#  'log_count/INFO': 130,
#  'log_count/WARNING': 1,
#  'request_depth_max': 1,
#  'response_received_count': 62,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 62,
#  'scheduler/dequeued/memory': 62,
#  'scheduler/enqueued': 62,
#  'scheduler/enqueued/memory': 62,
#  'start_time': datetime.datetime(2024, 4, 2, 23, 36, 3, 914510, tzinfo=datetime.timezone.utc)}
# 2024-04-02 20:37:17 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
import json

# Carrega o arquivo JSON
with open('output-pipeline-completo.json', 'r', encoding='utf-8') as f:
    data = [json.loads(line) for line in f]

# Exibe os dados de forma amigável
for item in data:
    print("URL:", item['url'])
    print("Título:", item['title'])
    print("Título Principal:", item['main_title'])
    print("Descrição:", item['description'])
    print("Palavras-chave:", item['keywords'])
    print("Conteúdo:")
    for text in item['content']:
        print(text)
    print("-" * 80)
# Out:
# URL: https://sejaefi.com.br/lp/sistema-de-pagamento-para-provedores
# Título: Efí
# Título Principal: Efí Empresas:
# Descrição:
# Palavras-chave:
# Conteúdo:
# A Gerencianet agora se chama Efí.
# Saiba mais!
# Abra sua conta grátis
# Efí Empresas:
# a
# conta PJ
# com
# sistema de pagamento
# favorito de
# +60% dos provedores de internet
# do Brasil
# Aproveite os
# meios de pagamento
# do mais alto nível,
# automatize a emissão de cobranças em massa
# e conte com ferramentas poderosas para uma
# gestão financeira
# descomplicada — da emissão ao recebimento.
# Quero começar agora
# Provedores
# Cobranças em massa
# Otimize o operacional emitindo
# cobranças em massa
# , sem complicações e de forma
# automatizada
# .
# Pagamento identificado
# Saiba que o seu
# assinante pagou
# antes mesmo do dinheiro cair e agilize o
# religamento da internet
# .
# Régua de cobrança
# Reduza a
# inadimplência
# com uma régua de cobrança automática que
# cobra seus assinantes
# por você.
# Sistema de pagamento
# Os
# meios de pagamento
# que seus assinantes querem e
# seu provedor precisa
# Otimize a
# experiência do seu cliente,
# conte com
# soluções modernas e automatizadas para cobrar e receber e aumente a eficiência operacional
# do seu provedor— tudo isso integrado ao seu ERP.
# Saber mais
# Carnês: mensalidades descomplicadas
# Gere e envie 1 carnê com até 24 mensalidades
# de uma só vez.
# Emita boletos híbridos:
# código de barras + QR Code Pix.
# Personalize com a cor e
# logo da sua marca.
# Bolix: boletos híbridos
# Gere boletos com
# código de barras + QR Code Pix.
# Receba
# na hora
# com o Pix e em
# até 1 dia útil
# pelo código de barras.
# Deixe que seu cliente
# escolha como quer pagar.
# Pagamentos recorrentes: fidelização de clientes
# Cadastre clientes e crie
# planos de assinatura ilimitados.
# Gere 1 vez e deixe que a gente envie
# cobranças automáticas todo mês.
# Receba por
# boletos ou cartão de crédito.
# Pix: pagamento instantâneo
# Receba
# 24h/7
# dias por semana, incluindo
# feriados.
# Emita cobranças
# imediatas
# e com
# data de vencimento.
# Configure uma
# página de cobrança
# para seus clientes.
# Link de pagamento: via cartão de crédito sem site
# Receba pagamentos
# sem site ou maquininha.
# Facilite o modo de pagar do seu assinante, via
# boleto
# ou
# cartão de crédito.
# Envie as
# cobranças de forma automatizada
# por e-mail.
# Falar com um especialista
# Integre com facilidade
# Implementação simples
# para uma jornada otimizada
# Para simplificar a sua vida,
# a Efí já está conectada com os ERPs de provedores.
# Você não precisa se preocupar com integrações manuais ou burocracias para deixar toda sua gestão integrada.
# Integração automática em ERPs parceiros
# Basta configurar e começar a usar.
# Tarifa exclusiva do parceiro para recebimento com desconto.
# Troca de informações de forma automatizada.
# Todo o financeiro conectado ao sistema de gestão sem gargalos.
# Nós estamos onde você está: encontre o seu ERP de Provedores aqui
# Provedor, comece agora a emitir cobranças em massa com a Efí
# Receber pagamentos com a Efí
# O combo perfeito
# Sistema de pagamento eficiente e turbinado com uma
# conta PJ completa
# Otimize a rotina de
# pagamentos recebidos
# do seu provedor com
# alta tecnologia
# e
# recursos personalizados.
# Facilite as cobranças e controle o financeiro com inteligência e praticidade.
# Efí Empresas
# Efí Empresas
# Conta PJ que facilita a gestão do seu provedor
# Desvie da burocracia dos bancos tradicionais:
# administre todo o financeiro
# do seu provedor com facilidade.
# Adicione
# usuários secundários
# em sua conta e
# personalize
# o que cada um pode fazer.
# Pague contas
# e
# faça transferências TED e Pix
# em poucos cliques e com segurança.
# Acesse a sua conta e
# acompanhe suas cobranças
# pela
# plataforma web
# ou
# aplicativo de celular.
# Solicite um cartão de
# crédito e débito sem anuidade Visa Platinum
# e ganhe pontos com a Livelo.
# Gestão de cobranças
# Ferramentas inteligentes que potencializam a sua gestão
# Com o
# Pagamento Identificado
# , você não precisa mais esperar o dinheiro cair para religar a internet do seu assinante.
# Conte com a
# emissão
# ,
# baixa
# e o
# cancelamento
# de cobranças
# grátis
# . Com a Efí, você paga apenas
# quando receber.
# Receba um
# resumo diário
# e simplificado dos recebíveis.
# Configure juros, multas e descontos para todas as suas cobranças.
# Substitua o
# CNAB
# e
# automatize
# seus arquivos com API.
# Envie
# lembretes automáticos
# 5 dias antes da data de vencimento da mensalidade.
# Instituição de Pagamento autorizada pelo
# Banco Central
# Conte com as
# soluções bancárias
# de quem facilita a
# gestão de cobranças
# de milhares de Provedores de Internet há 16 anos, oferecendo uma
# plataforma de pagamentos
# completa e equipada com uma
# Conta PJ
# descomplicada.
# Conheça a Efí Bank
# Temos mais de
# 480
# mil
# clientes por
# todo o Brasil
# Temos mais de
# 350
# colaboradores
# por aqui
# 364
# é o nosso
# código bancário
# Mais de
# R$
# 27
# bilhões
# movimentados
# em 2023
# Vem com a gente!
# Inovação é a nossa linguagem.
# Tecnologia é o nosso meio.
# Soluções de pagamentos são a nossa arte.
# Receber pagamentos com a Efí
# Abra sua Conta Grátis
# --------------------------------------------------------------------------------
# URL: https://sejaefi.com.br/lp/iniciador-de-pagamentos-open-finance
# Título: Efí
# Título Principal: A solução de pagamento feita para  reduzir o abandono de carrinho  no e-commerce
# Descrição:
# Palavras-chave:
# Conteúdo:
# A Gerencianet agora se chama Efí.
# Saiba mais!
# Abrir menu
# Soluções
# Pelo site ou aplicativo
# Boletos e Carnês
# Conta Digital
# Gestão de Cobranças
# Link de Pagamento
# Pagamento Recorrente
# Por API
# API Boletos e Carnês
# API Pix
# API Pix via Open Finance
# Checkout Transparente
# Split de Pagamento
# Pix Automático
# Novo
# Segmentos
# Provedor de Internet
# Bet - Apostas Esportivas
# Parcerias
# Desenvolvedores
# Efí Pay — Plataforma de pagamentos
# Documentação API
# Módulos e Plugins
# Comunidade no Discord
# Curso API 2.0 grátis
# Tarifas
# Blog
# Abra sua conta grátis
# Acessar minha conta
# Abra sua conta grátis
# Acessar minha conta
# Pix via Open Finance
# A solução de pagamento feita para
# reduzir o abandono de carrinho
# no e-commerce
# Revolucione a jornada de compra com um
# checkout mais simples, rápido e transparente
# e receba na hora com o
# Pix via Open Finance.
# Fale com nosso time comercial
# Um novo nível para os pagamentos digitais.
# Uma oportunidade para você sair na frente do mercado.
# Preencha o formulário
# para falar com nosso time comercial
# e conhecer todo o potencial dos pagamentos via Open Finance para o seu e-commerce.
# Nome completo:
# E-mail:
# Telefone:
# Empresa:
# CNPJ:
# Número de cobranças recebidas por mês:
# Estou de acordo com a
# Política de Privacidade Efí.
# Enviar
# Seus dados estão seguros
# Iniciação de Pagamentos
# Receba pagamentos
# por Pix via Open Finance
# Sua jornada de pagamento tão simples que o cliente não vai mais precisar mudar de app manualmente.
# Inicie pagamentos dentro do seu e-commerce se conectando a diversos bancos, por meio de uma interface segura, e permita que seus clientes autorizem um pagamento por Pix sem sair da tela de checkout — encurtando a jornada de pagamento de 7 para 3 etapas.
# Iniciação de pagamentos dentro do seu e-commerce
# Conexão automática com vários bancos
# Checkout rápido, fluido e com apenas 3 etapas
# Jornada de compra ainda mais otimizada
# Fale com nosso time comercial
# API Open Finance
# Construa um novo nível
# de pagamentos online
# Integre seu e-commerce com API Open Finance da Efí, sua Iniciadora de Pagamento autorizada pelo Banco Central.
# Oferecemos toda a infraestrutura tecnológica para conectar o seu negócio ao ecossistema do Open Finance, de forma simples e segura. Assim, você entrega um ambiente de pagamento desenhado para melhorar a experiência de compra dos seus clientes no seu e-commerce.
# Developer-Friendly API
# Suporte técnico de segunda a segunda
# Comunidade +5000 devs e integradores
# Ambiente Sandbox para testes e homologação
# SDKs em todas as linguagens de programação
# Certificação OpenID
# Tecnologia de ponta
# para escalar sua empresa.
# Fale com nosso time comercial
# Por que escolher a Efí?
# Simplificando os recebimentos online há mais de 16 anos
# Aproveite a
# mais alta tecnologia da Efí Pay
# a favor do seu negócio. Nascemos em 2007, somos
# autorizados pelo Banco Central
# e fomos uma das primeiras instituições habilitadas para atuar como Iniciador de Pagamento.
# Estamos prontos para revolucionar os pagamentos
# online junto com você!
# 🧡
# Temos mais de
# 480
# mil
# clientes
# Mais de
# 6
# bilhões
# de transações
# nas APIs em 2023
# Processamos
# 283
# milhões
# de emissões anuais
# de cobrança
# Mais de
# R$
# 27
# bilhões
# movimentados
# em 2023
# Pare de perder
# vendas importantes
# Dê aos clientes o que eles realmente querem. Conecte-se ao Open Finance e simplifique o checkout no seu e-commerce!
# Solicite um contato
# Abra sua Conta Grátis
# --------------------------------------------------------------------------------
# URL: https://sejaefi.com.br/lp/open-finance-para-ecommerce
# Título: Pagamentos via Open Finance para e-commerce | Efí Pay
# Título Principal: Dê adeus ao abandono de carrinho e  venda muuuito mais no seu e-commerce
# Descrição: Dê adeus ao abandono de carrinho! Otimize o checkout do seu e-commerce, feche mais vendas e receba na hora. Experimente o Pix via Open Finance da Efí Pay.
# Palavras-chave: open finance ecommerce
# Conteúdo:
# A Gerencianet agora se chama Efí.
# Saiba mais!
# Abrir menu
# Soluções
# Pelo site ou aplicativo
# Boletos e Carnês
# Conta Digital
# Gestão de Cobranças
# Link de Pagamento
# Pagamento Recorrente
# Por API
# API Boletos e Carnês
# API Pix
# API Pix via Open Finance
# Checkout Transparente
# Split de Pagamento
# Pix Automático
# Novo
# Segmentos
# Provedor de Internet
# Bet - Apostas Esportivas
# Parcerias
# Desenvolvedores
# Efí Pay — Plataforma de pagamentos
# Documentação API
# Módulos e Plugins
# Comunidade no Discord
# Curso API 2.0 grátis
# Tarifas
# Blog
# Abra sua conta grátis
# Acessar minha conta
# Abra sua conta grátis
# Acessar minha conta
# Dê adeus ao abandono de carrinho e
# venda muuuito mais no seu e-commerce
# Revolucione a jornada de compra com um checkout mais simples, rápido e transparente, feche mais vendas e receba na hora com o Pix via Open Finance.
# Quero conhecer o Pix via Open Finance
# Relatório e-commerce
# 0
# %
# crescimento anual do e-commerce brasileiro até 2026,
# chegando a US$ 432 bilhões.*
# 0
# %
# estimativa de representação do
# Pix no total de transações no e-commerce
# até 2025.*
# 0
# %
# da população adulta do Brasil usa o Pix
# , enquanto apenas 37% têm cartão de crédito.*
# 0
# %
# dos consumidores desistem de concluir pedidos, sobretudo por
# frete alto e checkout burocrático.**
# *fonte: Relatório Americas Market Intelligence (AMI)
# **fonte: Pesquisa Abandono de Carrinho 2022 da Opinion Box
# Carrinho perdido?
# Não com o Pix via Open Finance da Efí Pay
# A nossa tecnologia te ajuda a oferecer uma melhor experiência de compra, reduzir o abandono de carrinho e realizar uma
# gestão de recebimentos muito mais eficiente.
# Checkout rápido, fluido e
# com apenas 3 passos
# Sua jornada de pagamento tão simples que o cliente
# não vai mais precisar mudar de app manualmente.
# A gente conecta seu e-commerce aos bancos e o seu cliente só precisar dar um “confirma” para transferir direto da conta bancária. Simples assim!
# Tenho interesse
# Seu navegador não suporta a tag de "video"
# Até então, para pagar por um produto no seu e-commerce, o consumidor precisa emitir e pagar o boleto bancário, digitar os dados do cartão de crédito ou copiar o código do Pix para colá-lo na plataforma do banco ou conta digital. Esses intervalos podem influenciar na
# desistência da compra
# .
# Agora, imagine o seu cliente precisar apenas escolher, ainda na tela de pagamento do seu e-commerce, por qual banco vai pagar e autorizar a transação? Isso é a
# Iniciação de Pagamento do Open Finance!🧡
# Eleve o nível - e as métricas -
# das vendas no seu site
# Aproveite a mais alta tecnologia da Efí Pay a favor do seu negócio!
# Regulado pelo Banco Central
# Seguro, regulado pelo Bacen e em conformidade com a LGPD, como deve ser.
# Conexão com vários bancos
# Conexão automática com todas as instituições participantes do Open Finance.
# Implementação em 1 sprint
# Documentação aberta, SDKs em todas as linguagens e suporte técnico disponível.
# Aumento da conversão e das vendas
# Jornada de compra com apenas 3 etapas para parar de perder vendas importantes.
# Recebimento em tempo real
# Pix + Open Finance = venda mais rápida e saldo disponível em até 10 segundos.
# Vai participar do
# Fórum E-commerce Brasil 2023
# Encontre-se com a gente para conhecer e experimentar o Pix via Open Finance da Efí Pay.
# Palestra inédita
# Conheça o case de sucesso da API Pix, cocriada com a maior comunidade de integração de meios de pagamento do Brasil no Discord, apresentada pelo nosso Diretor de Produtos, Danilo Oliveira.
# 27 de Julho às 10h10
# Palco Soluções - Fórum E-commerce Brasil 23
# Imersão Open Finance
# Experimente o Pix via Open Finance, na prática, em um totem interativo no nosso estande e conheça todo seu potencial na redução de abandono de carrinho.
# Você é nosso convidado!
# Use o cupom para aproveitar o maior evento de e-commerce da América Latina com valor promocional.
# F23EFI
# Depoimentos
# A gente facilita
# a vida de quem
# faz acontecer
# A principal solução que o Open Finance nos trouxe foi a facilidade na finalização do pagamento, pois 80% dos nossos clientes compram via mobile hoje em dia e isso acaba facilitando muito a vida do cliente, vira praticamente “um clique” e fim, pagamento realizado. Creio que o maior beneficio que tenho com a Efí, seja o suporte ágil e o atendimento totalmente personalizado. Esse diferencial faz total diferença!
# Fabricio de Matos
# CEO do Rei dos Coins
# Simule agora uma compra
# no ambiente Open Finance!
# Não vai participar do Fórum E-commerce Brasil? Nós pensamos em você também!
# Criamos um app que simula a iniciação de pagamento por Pix via Open Finance para você experimentar. Baixe o app e simule — é simples e gratuito.
# 1. adicione o produto no carrinho e vá para tela de checkout;
# 2. selecione seu banco ou fintech;
# 3. clique em “Pagar com o Pix via Open Finance”;
# 4. autorize a transação e conclua o pagamento no próprio app!
# passo anterior
# próximo passo
# Abra sua Conta Grátis
# --------------------------------------------------------------------------------
# URL: https://sejaefi.com.br/solicitar-cartao-de-credito
# Título: Efí
# Título Principal: Entre na lista de espera do  Cartão de Crédito Efí
# Descrição:
# Palavras-chave:
# Conteúdo:
# A Gerencianet agora se chama Efí.
# Saiba mais!
# Abrir menu
# Soluções
# Pelo site ou aplicativo
# Boletos e Carnês
# Conta Digital
# Gestão de Cobranças
# Link de Pagamento
# Pagamento Recorrente
# Por API
# API Boletos e Carnês
# API Pix
# API Pix via Open Finance
# Checkout Transparente
# Split de Pagamento
# Pix Automático
# Novo
# Segmentos
# Provedor de Internet
# Bet - Apostas Esportivas
# Parcerias
# Desenvolvedores
# Efí Pay — Plataforma de pagamentos
# Documentação API
# Módulos e Plugins
# Comunidade no Discord
# Curso API 2.0 grátis
# Tarifas
# Blog
# Abra sua conta grátis
# Acessar minha conta
# Abra sua conta grátis
# Acessar minha conta
# Entre na lista de espera do
# Cartão de Crédito Efí
# Estamos liberando aos poucos a função crédito* para nossos clientes e daremos prioridade, no próximo lote, para quem estiver na lista de espera. Inscreva-se abaixo e fique mais perto de ter o seu novo cartão de crédito preferido.
# Nome completo:
# E-mail:
# Telefone:
# CPF/CNPJ:
# Declaro que autorizo a consulta ao Sistema de Informações de Crédito (SCR) e Serasa e estou de acordo com a
# Política de Privacidade Efí.
# *Sujeito à análise de crédito
# Enviar
# Abra sua Conta Grátis
# --------------------------------------------------------------------------------
# URL: https://sejaefi.com.br/lp/blackfriday-efibank-2023
# Título: Efí
# Título Principal: Dê adeus ao abandono de carrinho e  venda muuuito mais nesta Black Friday
# Descrição:
# Palavras-chave:
# Conteúdo:
# A Gerencianet agora se chama Efí.
# Saiba mais!
# Abrir menu
# Soluções
# Pelo site ou aplicativo
# Boletos e Carnês
# Conta Digital
# Gestão de Cobranças
# Link de Pagamento
# Pagamento Recorrente
# Por API
# API Boletos e Carnês
# API Pix
# API Pix via Open Finance
# Checkout Transparente
# Split de Pagamento
# Pix Automático
# Novo
# Segmentos
# Provedor de Internet
# Bet - Apostas Esportivas
# Parcerias
# Desenvolvedores
# Efí Pay — Plataforma de pagamentos
# Documentação API
# Módulos e Plugins
# Comunidade no Discord
# Curso API 2.0 grátis
# Tarifas
# Blog
# Abra sua conta grátis
# Acessar minha conta
# Abra sua conta grátis
# Acessar minha conta
# Dê adeus ao abandono de carrinho e
# venda muuuito mais nesta Black Friday
# As melhores ofertas merecem os melhores meios de pagamento. Inove as opções do seu e-commerce e transforme cada transação em uma oportunidade de encantar seus clientes!
# Fale com nosso time comercial
# Black Friday Efí
# Efí Pay
# 67% dos brasileiros
# querem comprar nesta Black Friday
# Diversificar as formas de pagamento no seu e-commerce aumenta as chances de conversão em vendas. Na Efí Pay, você encontra várias opções em um só lugar!
# Pix
# Receba por Pix e
# otimize todo o processo de venda
# e entrega dos seus produtos.
# Bolix® (boleto + Pix)
# Emita boletos e carnês com
# código de barras e QR Code Pix
# . Pelo Pix, você recebe na hora.
# Carnês
# Faça vendas de alto valor no boleto parcelado e gere
# várias lâminas de carnê
# de uma só vez.
# Links de pagamento
# Gere links de pagamento para enviar ao seu cliente e receber à vista no boleto ou em até 12 vezes no cartão de crédito,
# sem precisar de site ou maquininha
# .
# Assinaturas
# Crie planos de assinatura e receba por boleto e cartão de forma
# automática e periódica
# .
# Botão de pagamento
# Gere um botão de pagamento e
# adicione ao seu site
# para receber por boleto ou cartão de crédito.
# Checkout transparente
# Ofereça uma experiência de pagamento mais agradável,
# sem redirecionamentos
# para outro site.
# As melhores tarifas para você vender com a Efí
# Cobrada apenas quando seu cliente pagar você 🧡
# Conheça nossas tarifas
# Experimente a Efí Pay
# Experimente a Efí Pay
# Carrinho perdido?
# Não com o Pix via Open Finance da Efí Pay
# A nossa tecnologia te ajuda a oferecer uma melhor experiência de compra, reduzir o abandono de carrinho e realizar uma
# gestão de recebimentos muito mais eficiente.
# Checkout rápido, fluido e
# com apenas 3 passos
# Sua jornada de pagamento tão simples que o cliente
# não vai mais precisar mudar de app manualmente.
# A gente conecta seu e-commerce aos bancos e o seu cliente só precisar dar um “confirma” para transferir direto da conta bancária. Simples assim!
# Tenho interesse
# Split de pagamentos
# para dividir os recebimentos de forma automatizada
# Faça o repasse automático de pagamentos por boleto, cartão e Pix entre dois ou mais recebedores.
# Regras de divisão por percentual, comissão ou valor fixo.
# Repasses em tempo real, sem passar pela conta mestre.
# Visualização dos repasses pela Conta Digital.
# Mais transparência na distribuição dos pagamentos.
# Módulos e plugins
# para plataformas de e-commerce
# Instale em poucos passos e automatize os recebimentos no seu e-commerce com uma tecnologia que suporta um alto volume de transações por segundo.
# Disponível para Wordpress (WooCommerce), Magento (OpenMage e Magento 2), OpenCart, PrestaShop, WHMCS e outros.
# Solicite uma demonstração
# Por que escolher a Efí?
# Simplificando os recebimentos online há mais de 16 anos
# Aproveite a
# mais alta tecnologia da Efí Pay
# a favor do seu e-commerce. Nascemos em 2007, somos
# autorizados pelo Banco Central
# e estamos prontos para revolucionar os pagamentos
# online junto com você!
# 🧡
# Temos mais de
# 480
# mil
# clientes
# Mais de
# 6
# bilhões
# de transações
# nas APIs em 2023
# Processamos
# 283
# milhões
# de emissões anuais
# de cobrança
# Mais de
# R$
# 27
# bilhões
# movimentados
# em 2023
# Pare de perder
# vendas importantes
# Dê aos clientes o que eles realmente querem. Use a Efí Pay e lucre mais nesta Black Friday!
# Solicite um contato
# Abra sua Conta Grátis
# --------------------------------------------------------------------------------
# URL: https://sejaefi.com.br/efi-pay/gestao-de-cobrancas
# Título: Gestão de cobranças • Cobre e receba sem complicações | Efí
# Título Principal: Para cobrar, receber e gerir com  praticidade
# Descrição: Emita cobranças grátis, receba por boleto ou cartão de crédito e conte com a régua de cobranças automática para reduzir a inadimplência. Experimente agora!
# Palavras-chave: Gestão de cobranças
# Conteúdo:
# A Gerencianet agora se chama Efí.
# Saiba mais!
# Abrir menu
# Soluções
# Pelo site ou aplicativo
# Boletos e Carnês
# Conta Digital
# Gestão de Cobranças
# Link de Pagamento
# Pagamento Recorrente
# Por API
# API Boletos e Carnês
# API Pix
# API Pix via Open Finance
# Checkout Transparente
# Split de Pagamento
# Pix Automático
# Novo
# Segmentos
# Provedor de Internet
# Bet - Apostas Esportivas
# Parcerias
# Desenvolvedores
# Efí Pay — Plataforma de pagamentos
# Documentação API
# Módulos e Plugins
# Comunidade no Discord
# Curso API 2.0 grátis
# Tarifas
# Blog
# Abra sua conta grátis
# Acessar minha conta
# Abra sua conta grátis
# Acessar minha conta
# Gestão de Cobranças
# Para cobrar, receber e gerir com
# praticidade
# Inove os
# meios de pagamento
# do seu negócio e transforme cada transação em uma oportunidade de
# encantar seus clientes.
# Quero emitir cobranças grátis
# Seu negócio é único.
# A forma que você vende também!
# Emita suas cobranças
# grátis
# , receba por
# boleto
# e
# cartão, gerencie tudo em um painel completo de pagamentos e só pague tarifas se seu cliente pagar você.
# Todas opções de pagamento estão integradas nas contas
# Efí Pro
# e
# Efí Empresas.
# Bolix (boleto + Pix)
# Emita boletos e carnês com
# código de barras e QR Code Pix
# e deixe que seu cliente escolha como quer pagar.
# Recebimento em tempo real via QR Code Pix.
# Solução 2 em 1 com tarifa única.
# Cancelamento automático de um código quando o outro é utilizado.
# Ativação em apenas um clique, sem qualquer integração.
# Carnês
# Faça vendas de alto valor no boleto parcelado e gere lâminas de carnê para até 24 parcelas de uma só vez.
# Sem tarifas de emissão, baixa ou cancelamento.
# Configuração de juros, multas e descontos.
# Carnês registrados e aceitos mesmo após o vencimento.
# Uma opção de parcelamento sem a necessidade de cartão de crédito.
# Links de pagamento
# Gere links de pagamento para cobrar pela internet e receber à vista no boleto ou em até 12 vezes no cartão.
# Elimina a necessidade de site ou maquininha.
# Fácil de compartilhar por WhatsApp ou redes sociais.
# Tela de pagamento personalizável com cores e logo da marca.
# Cadastro de produtos, serviços e preços na plataforma para maior conveniência.
# Botão de pagamento
# Gere um botão de pagamento e adicione ao seu site para receber por boleto ou cartão de crédito.
# Botões personalizáveis.
# Recebimento disponível para pagamentos únicos ou recorrentes.
# Opção de solicitar o endereço de entrega e adicionar uma taxa de frete.
# Ideal para usuários sem conhecimentos avançados em programação.
# Pagamento recorrente
# Crie planos de assinaturas mensais, semestrais e até anuais para receber pagamentos via boleto ou cartão.
# Cobrança automática no boleto e na fatura do cartão.
# Cadastro de clientes e planos de assinatura ilimitados.
# Periodicidade personalizável.
# Mais previsibilidade financeira.
# Checkout transparente
# Ofereça uma experiência de pagamento mais agradável e protegida, sem redirecionamentos para outro site.
# Compatível com as principais plataformas de e-commerce.
# Design responsivo para todos os tamanhos de tela.
# Dados transacionais criptografados.
# Agilidade na confirmação do pedido.
# Split de pagamento
# Faça o repasse automático de pagamentos por boleto, cartão e Pix entre dois ou mais recebedores.
# Regras de divisão por percentual, comissão ou valor fixo.
# Repasses em tempo real, sem passar pela conta mestre.
# Visualização dos repasses pela Conta Digital.
# Mais transparência na distribuição dos pagamentos.
# Quero vender com a Efí Pay
# Descubra as tarifas Efí
# API Cobranças
# Suas cobranças no
# automático
# Mais tempo para focar no seu core business é o que você precisa? Integre, automatize e escale suas vendas com a mais avançada tecnologia de pagamentos do mercado.
# APIs robustas, no padrão do Banco Central.
# SDKs disponíveis em todas as linguagens de programação.
# Integração simples e customizável de acordo com seu modelo de negócio.
# Emissão de cobranças automatizada.
# Suporte técnico de alto nível para apoiar seu integrador em todas as etapas.
# Faça uma demonstração gratuita
# Fale com nosso time comercial
# Começar é fácil!
# Abra sua conta em poucos minutos!
# Com a Efí, seu banco está a um clique de distância.
# Você abre sua conta PJ de forma simples,
# 100% online e sem custo
# .
# 1. Faça seu cadastro
# Informe dados básicos para iniciar o processo de abertura de conta.
# 2. Baixe o aplicativo
# Baixe grátis o app da Efí para celular na sua loja de aplicativos.
# 3. Abra sua conta Efí Pro ou Efí Empresas
# Escolha a Efí Pro se ainda não tiver CNPJ ou Efí Empresas se já tiver CNPJ.
# 4. Aproveite
# Agora é só aproveitar todas as vantagens de ser Efí!
# Quero abrir minha conta grátis
# Torne simples o que parece complexo:
# configure suas cobranças com apenas um clique
# Seu negócio, sua regras!
# Tenha o controle total sobre prazos, valores e métodos de pagamento.
# Configure os dados de exibição da cobrança.
# Personalize seus boletos e telas de pagamento com a cor e logo da sua marca.
# Escolha como você deseja receber os pagamentos via cartão — à vista ou parcelado.
# Adicione juros a partir de uma certa quantidade de parcelas via cartão.
# Configure juros, multas e descontos para pagamentos via boletos e carnês.
# Você no controle
# Reduza a inadimplência
# com uma régua de cobranças que trabalha por você
# Programe uma
# sequência de lembretes
# sobre o vencimento das cobranças. Você ativa o disparo e a gente cuida de tudo!
# Cobrança emitida e enviada
# 5 dias antes do vencimento
# 5 dias antes do vencimento
# Inadimplência identificada
# Confirmação de pagamento manual
# Confirmação de pagamento manual
# Cancelamento de cobrança, assinatura e carnê
# Relatórios completos
# para insights mais profundos
# Mantenha um
# controle detalhado
# de todas as movimentações financeiras e monitore de perto os clientes que estão inadimplentes em seu negócio.
# Consolidado
# Receba, todos os dias, na linha do tempo da Conta Digital, um resumo otimizado de suas cobranças do dia anterior.
# Visão geral
# Visualize gráficos didáticos com o panorama das suas cobranças. Os valores são divididos entre confirmados, a receber e inadimplentes.
# Gráfico “Sua evolução”
# Acompanhe um consolidado de entradas e saídas de dinheiro dos últimos 12 meses já finalizados.
# Relatórios personalizados
# Gere relatórios de acordo com as suas necessidades de busca. Você tem o poder de escolher as informações que serão exibidas.
# Da palma da mão à tela do computador:
# faça sua gestão de qualquer lugar
# Acompanhe o status de todas as suas cobranças em um dashboard simples e de onde estiver,
# pelo app
# ou
# plataforma web.
# anterior
# próximo
# Depoimentos
# Inspire-se nos
# +480 mil
# empreendedores
# que
# contam com
# a gente!
# Abra sua conta em minutos
# A principal solução que o Open Finance nos trouxe foi a facilidade na finalização do pagamento, pois 80% dos nossos clientes compram via mobile hoje em dia e isso acaba facilitando muito a vida do cliente, vira praticamente 'um clique' e fim, pagamento realizado. Creio que o maior beneficio que tenho com a Efí, seja o suporte ágil e o atendimento totalmente personalizado. Esse diferencial faz total diferença!
# Fabricio de Matos
# CEO do Rei dos Coins
# A priori, [a Efí] foi a única empresa, que encontramos no nosso espectro de busca, que fazia a integração fiel às normas do Banco Central. Integramos o Pix com o PDV, funcionou certinho, e conseguimos atingir o nosso objetivo.
# Robson Benedito
# CEO da RedeSoft
# Temos a Efí integrada ao nosso ERP onde nossos clientes aceitam o orçamento e já pagam online por Pix, cartão de crédito e boleto. É demais!
# Valério Ricardo Budke
# Systhesys Tecnologia
# Sou cliente da Efí e gosto muito! Tenho controle total [de recebimento] dos meus clientes em uma plataforma fácil e bem estruturada. O time de atendimento é ótimo, sempre à disposição para resolver qualquer dúvida ou situação. Estou indicando a Efí para novos clientes de e-commerce da DDR.
# Daniel Braun
# CEO da DDR Web Studio
# anterior
# próximo
# Atendimento 360º
# para transformar problemas em soluções
# Atendimento humanizado
# Nossos especialistas de atendimento e de suporte técnico estão aqui para ajudar você, seja por ticket, chat, telefone ou WhatsApp, de segunda a segunda, das 7h às 22h, inclusive em feriados.
# Implementação rápida
# Com apoio dos nossos consultores técnicos durante todo o processo, é possível integrar as APIs e começar a usar já na primeira semana.
# Comunidade no Discord
# Você ainda pode se conectar com a nossa comunidade no Discord que reúne +5000 devs e especialistas em integração, para te ajudar no dia a dia e trocar insights.
# Faça parte do Discord
# Conheça nossas
# Contas Digitais
# Conta Digital para receber os valores das suas vendas e concentrar a vida financeira do seu negócio,
# mesmo que não tenha CNPJ.
# Conheça a Conta Efí Pro
# Conheça a Conta Efí Pro
# Conta Digital completa para receber dos seus clientes e administrar
# todas as operações financeiras da sua empresa.
# Conheça a Conta Efí Empresas
# Conheça a Conta Efí Empresas
# Abra sua Conta Grátis
# --------------------------------------------------------------------------------
# URL: https://sejaefi.com.br/lp/formulario-efi-empresas
# Título: Abra sua Conta PJ com gestão de cobranças | Efí Empresas
# Título Principal: Efí Empresas
# Descrição: Conta Digital PJ grátis equipada com meios de pagamento, APIs de alta performance, cartão PJ Visa® Platinum e ferramentas de gestão integradas. Experimente!
# Palavras-chave: conta PJ, abrir conta PJ, Efí, Gerencianet, conta empresarial, conta digital PJ
# Conteúdo:
# A Gerencianet agora se chama Efí.
# Saiba mais!
# Abrir menu
# Soluções
# Pelo site ou aplicativo
# Boletos e Carnês
# Conta Digital
# Gestão de Cobranças
# Link de Pagamento
# Pagamento Recorrente
# Por API
# API Boletos e Carnês
# API Pix
# API Pix via Open Finance
# Checkout Transparente
# Split de Pagamento
# Pix Automático
# Novo
# Segmentos
# Provedor de Internet
# Bet - Apostas Esportivas
# Parcerias
# Desenvolvedores
# Efí Pay — Plataforma de pagamentos
# Documentação API
# Módulos e Plugins
# Comunidade no Discord
# Curso API 2.0 grátis
# Tarifas
# Blog
# Abra sua conta grátis
# Acessar minha conta
# Abra sua conta grátis
# Acessar minha conta
# Efí Empresas
# Conta PJ
# para automatizar a emissão e gestão de cobranças
# Conta Digital PJ grátis equipada com meios de pagamento, APIs de alta performance, cartão PJ Visa® Platinum e ferramentas para uma gestão 360º da sua empresa.
# O sucesso financeiro da sua empresa começa aqui
# Nome
# E-mail
# Telefone
# CNPJ
# Número de cobranças por mês
# Estou de acordo com a
# Política de Privacidade Efí
# Solicitar contato comercial
# Uma empresa de sucesso
# começa com uma conta PJ completa
# Tenha acesso ilimitado à
# Efí Pay
# —
# ecossistema de meios de pagamento.
# Emita cobranças grátis pelo app ou APIs
# e só pague pelos recebimentos.
# Programe uma régua de cobranças
# que reduz a inadimplência de clientes.
# Adicione usuários secundários
# com diferentes níveis de acesso.
# Solicite um
# cartão PJ Visa® Platinum
# personalizado com a sua marca.
# Solicite cartões corporativos
# na modalidade pré-pago.
# Faça parte do Programa de
# Parcerias da Efí
# e aumente seus ganhos com comissões.
# Pague contas, envie dinheiro, faça recargas e saque
# em qualquer caixa Banco24Horas.
# Fale com nosso time comercial
# Tecnologia integrada na conta
# Mais praticidade para receber,
# menos burocracia para empreender
# API
# Conta Digital
# Pix
# Receba por Pix
# e otimize todo o processo de venda e entrega dos seus produtos.
# API
# Pix via Open Finance
# Conecte-se aos bancos e
# inicie pagamentos
# dentro da sua própria plataforma.
# API
# Conta Digital
# Bolix®
# Emita boletos e carnês com
# código de barras e QR Code Pix.
# Pelo Pix, você recebe na hora.
# API
# Conta Digital
# Carnês
# Faça vendas de alto valor no boleto parcelado e gere
# várias lâminas de carnê
# de uma só vez.
# API
# Conta Digital
# Links de pagamento
# Receba pagamentos por
# aplicativos de mensagem ou redes sociais
# via boleto ou cartão de crédito.
# API
# Conta Digital
# Assinaturas
# Crie planos de assinatura e receba por boleto e cartão de forma
# automática e periódica.
# Conta Digital
# Botão de pagamento
# Gere um botão de pagamento e
# adicione ao seu site
# para receber por boleto ou cartão de crédito.
# API
# Checkout transparente
# Ofereça uma experiência de pagamento mais agradável,
# sem redirecionamentos
# para outro site.
# API
# Split de pagamento
# Faça o
# repasse automático
# de pagamentos por boleto, cartão e Pix entre os recebedores.
# Explore mais
# Quero emitir cobranças grátis
# Suas cobranças no automático:
# integre, automatize e escale suas vendas
# APIs robustas, no
# padrão do Banco Central.
# SDKs disponíveis em
# todas as linguagens de programação.
# Integração
# simples e customizável
# de acordo com seu modelo de negócio.
# Emissão de cobranças em escala de forma
# automatizada.
# Suporte técnico
# de alto nível para apoiar seu integrador em todas as etapas.
# Gera muitas cobranças por mês?
# Fale com nosso time comercial
# Da palma da mão à tela do computador:
# faça sua gestão de qualquer lugar
# Acompanhe o status de todas as suas cobranças em um dashboard completo e intuitivo,
# pelo app
# ou
# plataforma web.
# anterior
# próximo
# Para empresas que pensam grande,
# um cartão PJ que acompanha suas ambições
# Sem anuidade
# e tarifas escondidas
# Função débito com opção de crédito
# — sujeito a análise.
# Benefícios
# Visa® Platinum
# em todas as suas compras e viagens
# Personalizado
# com o nome do seu negócio
# Acesso grátis ao programa de
# pontos Livelo
# Pagamento por aproximação
# para agilizar suas compras
# Por que
# +480 mil clientes
# confiam na Efí Empresas para cuidar das finanças?
# Temos mais de
# 16
# anos
# de experiência
# Mais de
# R$
# 27
# bilhões
# movimentados
# em 2023
# Mais de
# 6
# bilhões
# de transações
# nas APIs
# 364
# é o nosso
# código bancário
# Reclame Aqui
# 9.0
# / 10
# Google play
# 4.6
# / 5
# App Store
# 4.5
# / 5
# Excelente aplicativo, muita solução pra quem quer mexer com clientes por meio de boletos, pix... PF ou PJ! O atendimento do pessoal do app é rápido e eficiente! Recomendo!
# Google Play
# Efí é um banco que tem me ajudado bastante com meu negócio como pessoa física... Só tenho a agradecer, resolveu os problemas que eu tinha, com a Efí sou maisorganizada, e meus clientes estão satisfeitos com as soluções que possibilito a eles.
# Google Play
# Excelente atendimento, rápido e eficiente, conta personalizada e sempre com novidades pra melhorar sua gestão financeira na empresa. Só parabenizar e agradecer aos colaboradores.
# Google Play
# Muito bom App fora a empresa que fornece api e ainda melhor que tem quase tudo pronto só basta integrar ao seu sistema hoje deixei de usar outras devido a facilidade de integração
# App Store
# Sou cliente desde que emitia somente boletos. Muitas possibilidades e ferramentas fáceis de uso. Sempre com novs funcionalidades e soluções. Top 10!
# App Store
# Fiquei muito agradecido pela compreensão do banco efí. Isso demonstra que o banco está em perfeita sintonia com quem de fato trabalha e usam seus produtos com sinceridade e compromisso sério. Nota mil!
# Reclame Aqui
# Após a reclamação a empresa se dedicou e resolveu o problema. Ofereceu um ótimo atendimento. Com certeza vou manter a parceria.
# Reclame Aqui
# Quero estender meu agradecimento ao banco EFÍ, pois deram todo o suporte e a atenção para o problema, e conseguimos resolver. E todos os boletos que estavam indevidamente no meu nome e CPF foram retirados.
# Reclame Aqui
# anterior
# próximo
# Efí
# na mídia
# Pode sonhar alto, que a gente ajuda
# sua empresa
# a chegar longe!
# Solicite um contato comercial
# Dúvidas frequentes
# sobre a Efí Empresas
# Aqui, a gente responde algumas dúvidas sobre a
# Efí Empresas.
# Se você preferir, nosso time de atendimento também está à disposição.
# É só entrar em contato com a gente!
# O que é conta PJ? E que tipo de negócio pode usar?
# A
# conta PJ da Efí
# é uma conta de pagamento
# específica para empresas
# . Com ela, é possível ter acesso a serviços inerentes e essenciais para administrar as finanças do negócio — separado das finanças pessoais dos sócios — como crédito, geração de cobranças e emissão de extrato OFX para contabilidade, por exemplo.
# Esse tipo de conta é ideal para
# empresas que possuem CNPJ
# enquadradas como EIRELI, LTDA, S/A, EI (ME e EPP), além de associações e condomínios.
# Quais são os benefícios da conta empresarial Efí?
# A conta Efí Empresas é uma conta PJ completa, que descomplica a sua vida — de verdade! Contando com os serviços bancários essenciais, aqui você tem tudo que precisa em um só lugar:
# conta completa sem pacotes, mensalidades e nem tarifas de manutenção;
# ecossistema de pagamentos completo, com dezenas de soluções de recebimentos (boleto, links de pagamento, Pix e muito mais), integrada à conta digital, para emitir, gerenciar e receber pagamentos com facilidade;
# cartão Visa Platinum Internacional exclusivo, sem anuidade e cheio de vantagens (em breve);
# atendimento personalizado com gerente de conta dedicado;
# emissão de relatórios em formato OFX e PDF;
# usuários secundários para liberar e gerenciar acessos ao seu time;
# programa de parceria com comissionamento e muito mais.
# Quais são os horários para pagamentos e transferências da Efí?
# Para que os
# pagamentos
# sejam confirmados no mesmo dia, é importante que a solicitação seja realizada até às
# 22h para boletos
# e até às
# 18h para contas de consumo e tributos
# . As solicitações também podem ser feitas nos sábados, domingos ou feriados, mas, nesses casos, o pagamento será efetuado no próximo dia útil.
# Já as
# transferências (TED)
# podem ser feitas da
# 00h às 17h (horário de Brasília) em dias úteis
# caso você queira que o saldo caia no mesmo dia. Após esse horário, são agendadas para o próximo dia útil. Transferências via Pix, como de costume, podem ser feitas a qualquer dia e horário e o saldo cai na conta em até 10 segundos.
# Ainda não tenho CNPJ. Como faço para abrir uma conta?
# Se você empreende e ainda não tem CNPJ, mas precisa de ferramentas poderosas para gerir cobranças e movimentar o dinheiro das vendas, a
# conta Efí Pro
# é a modalidade ideal para você.
# Conheça melhor a Conta Efí Pro
# Ao abrir uma conta, já posso usar o ecossistema de pagamentos Efí Pay?
# Sim! O ecossistema de pagamentos Efí Pay já vem conectado à sua Conta Digital Efí Empresas. Portanto, assim que a sua conta estiver ativa, você já pode começar a emitir cobranças pelo app ou plataforma web ou iniciar a integração das nossas APIs.
# Saiba mais sobre a Efí Pay
# Ainda tem dúvidas? Visite nossa
# Central de Ajuda.
# Abra sua Conta Grátis
# --------------------------------------------------------------------------------
# URL: https://sejaefi.com.br/efi-pay/api-open-finance
# Título: API Open Finance: iniciador de pagamentos via Pix | Efí Pay
# Título Principal: Seja parte do futuro  dos pagamentos online com o Open Finance
# Descrição: Conecte-se ao Open Finance com a API da Efí. Com ele é possível iniciar pagamentos dentro do seu site, plataforma ou aplicativo. Faça já a integração!
# Palavras-chave: API Open Finance, iniciador de pagamento
# Conteúdo:
# A Gerencianet agora se chama Efí.
# Saiba mais!
# Abrir menu
# Soluções
# Pelo site ou aplicativo
# Boletos e Carnês
# Conta Digital
# Gestão de Cobranças
# Link de Pagamento
# Pagamento Recorrente
# Por API
# API Boletos e Carnês
# API Pix
# API Pix via Open Finance
# Checkout Transparente
# Split de Pagamento
# Pix Automático
# Novo
# Segmentos
# Provedor de Internet
# Bet - Apostas Esportivas
# Parcerias
# Desenvolvedores
# Efí Pay — Plataforma de pagamentos
# Documentação API
# Módulos e Plugins
# Comunidade no Discord
# Curso API 2.0 grátis
# Tarifas
# Blog
# Abra sua conta grátis
# Acessar minha conta
# Abra sua conta grátis
# Acessar minha conta
# Seja parte do futuro
# dos pagamentos online
# com o Open Finance
# Faça parte do ecossistema do Open Finance utilizando a API Pix via Open Finance, melhore a experiência de compra dos seus clientes no ambiente digital e potencialize seus lucros — com a
# eficiência e a segurança
# que seu negócio precisa.
# Quero integrar com a Efí
# Open Finance
# Conecte seu e-commerce
# a todos os bancos do mercado
# Inicie pagamentos dentro do seu site, plataforma ou aplicativo, se conectando a diversos bancos, por meio de uma interface segura, e permita que seus clientes autorizem um pagamento sem sair da tela de checkout — encurtando a jornada de pagamento de 7 para 3 etapas.
# Redução de riscos de fraudes e abandono de carrinho
# Aumento da conversão e das vendas
# Gestão eficiente dos recebimentos
# Redução de custos operacionais
# Mais opções de meios de pagamento para seu cliente pagar
# Quero integrar com a Efí
# Estamos prontos
# para trabalhar com
# diferentes
# segmentos e modelos de
# negócios
# E-commerce
# Aplicativo de delivery
# Aplicativo de transporte
# Aplicativo de mensagens e redes sociais
# Aplicativo de serviços e assinaturas
# + Outros modelos de negócio
# Menos etapas no pagamento
# Mais conversão e vendas
# Ainda melhor do que pagar com
# Pix,
# é pagar com
# Open Finance.
# O
# Open Finance
# substitui aqueles códigos gigantes do
# Pix
# por um simples botão que direciona seu cliente — automaticamente — para o banco!
# Sem a Iniciação de Pagamento do
# Open Finance:
# após escolher os produtos a serem comprados, o pagador vai até a tela do checkout;
# 1.
# escolhe a forma de pagamento para concluir a compra;
# 2.
# ao escolher Pix, por exemplo, o pagador copia o código do
# “Pix Copia e Cola”;
# 3.
# sai do seu e-commerce e abre o aplicativo do banco;
# 4.
# vai até a funcionalidade Pix e seleciona o “Pix Copia e Cola”;
# 5.
# cola o código no ambiente do Pix no app do banco;
# 6.
# retorna a tela do checkout do e-commerce;
# 7.
# espera o retorno de pagamento aprovado.
# Com a Iniciação de Pagamento do
# Open Finance:
# após escolher os produtos a serem comprados, o pagador vai até a tela do checkout;
# 1.
# escolhe a opção de pagamento
# Pix via Open Finance;
# 2.
# ainda no app ou plataforma da loja, escolhe um banco e é redirecionado, automaticamente, para autorização do pagamento e utilização do saldo em conta;
# 3.
# realiza a autenticação com senha ou biometria e a confirmação de pagamento é exibida na hora.
# Open Finance
# Com o Open Finance, o processo é
# mais fluido,
# com
# menos telas
# e
# com alto nível de segurança.
# Isso porque as Iniciadoras de Pagamento realizam as transações diretamente no aplicativo e no e-commerce em que os clientes estão comprando.
# Tenho interesse
# Case de sucesso
# A
# Blip
# integrou a
# API Pix via Open Finance da Efí Pay
# em seu chatbot no
# WhatsApp
# .
# Como sempre aconteceu na história da Blip, queremos nos manter na vanguarda dessa revolução conversacional e financeira, liderando o caminho para o futuro das transações no WhatsApp e abrindo portas para uma nova era de interações comerciais e transações financeiras diretamente através das conversas. Estamos rompendo barreiras e trazendo a experiência de Open Finance para um ambiente de mensageria, abrindo um mundo de novas possibilidades para marcas e consumidores, sem perder a segurança e a confiabilidade
# Rodrigo Battella
# Diretor da Divisão de Serviços Financeiros e Pagamentos na Blip
# Faça uma simulação de compra
# no ambiente Open Finance!
# Baixe o app para simular uma iniciação de pagamento por Pix via Open Finance. É muito simples:
# 1. adicione o produto no carrinho e vá para tela de checkout;
# 2. selecione seu banco ou fintech;
# 3. clique em “Pagar com o Pix via Open Finance”;
# 4. autorize a transação e conclua o pagamento no próprio app!
# passo anterior
# próximo passo
# Seu navegador não suporta a tag de "video"
# API Open Finance
# Da tecnologia ao regulatório.
# Cuidamos de tudo para você.
# Para fazer parte do ecossistema do Open Finance, as organizações precisam, necessariamente, obter a
# autorização do Banco Central
# como Instituição Iniciadora de Pagamentos ou se conectar a uma API Open Finance. A Efí tem uma
# API moderna, robusta e bem documentada,
# com padronização do Banco Central, para que você não precise se preocupar com nada além do seu negócio.
# Quero integrar com a Efí
# A gente facilita a transformação dos pagamentos online
# — para você sair na frente!
# Temos mais de
# 480
# mil
# clientes
# Mais de
# 6
# bilhões
# de transações
# nas APIs em 2023
# Processamos mais de
# 283
# milhões
# de emissões anuais
# de cobrança
# Mais de
# R$
# 27
# bilhões
# movimentados
# em 2023
# Depoimentos
# Junte-se a
# +480 mil
# clientes que confiam na
# Efí Bank
# A principal solução que o Open Finance nos trouxe foi a facilidade na finalização do pagamento, pois 80% dos nossos clientes compram via mobile hoje em dia e isso acaba facilitando muito a vida do cliente, vira praticamente 'um clique' e fim, pagamento realizado. Creio que o maior beneficio que tenho com a Efí, seja o suporte ágil e o atendimento totalmente personalizado. Esse diferencial faz total diferença!
# Fabricio de Matos
# CEO do Rei dos Coins
# A priori, [a Efí] foi a única empresa, que encontramos no nosso espectro de busca, que fazia a integração fiel às normas do Banco Central. Integramos o Pix com o PDV, funcionou certinho, e conseguimos atingir o nosso objetivo.
# Robson Benedito
# CEO da RedeSoft
# Temos a Efí integrada ao nosso ERP onde nossos clientes aceitam o orçamento e já pagam online por Pix, cartão de crédito e boleto. É demais!
# Valério Ricardo Budke
# Systhesys Tecnologia
# Sou cliente da Efí e gosto muito! Tenho controle total [de recebimento] dos meus clientes em uma plataforma fácil e bem estruturada. O time de atendimento é ótimo, sempre à disposição para resolver qualquer dúvida ou situação. Estou indicando a Efí para novos clientes de e-commerce da DDR.
# Daniel Braun
# CEO da DDR Web Studio
# anterior
# próximo
# Tecnologia, estabilidade
# e muitos benefícios
# para o seu negócio
# Conte com a infraestrutura tecnológica da Efí e ofereça um ambiente de pagamento moderno, condizente com os novos tempos e desenhado para melhorar a experiência de compra dos seus clientes no seu aplicativo e/ou e-commerce.
# API Open Finance
# Know-how e experiência
# Mais de 15 anos de experiência no mercado de pagamentos e referência em APIs de recebimento — inclusive, por ser a empresa preferida dos DEVs.
# Integração fácil e rápida
# Documentação aberta e com SDKs disponíveis nas principais linguagens de programação, para seu time integrar e começar a usar em 1 sprint.
# Suporte técnico
# Equipe de desenvolvedores especialistas em integração, disponível de segunda a segunda, para te ajudar em todas as etapas.
# Sandbox
# Ambiente de testes controlável disponível para replicar e adicionar funcionalidades antes de entrar em produção.
# Estabilidade
# Suporte e processamento de milhares de requisições diárias aos endpoints das APIs da Efí.
# Interface amigável
# Interface desenhada para garantir uma boa experiência e reduzir a fricção na solicitação dos dados de pagamento.
# Quero usar a API Open Finance
# De dev para dev
# Documentação descomplicada
# + Comunidade Discord
# Desenvolvida com arquitetura limpa e moderna, nossa API Open Finance está disponível com SDKs em todas as linguagens de programação, é
# compatível com as principais plataformas
# do mercado e garante a segurança das suas transações financeiras.
# Você ainda pode se conectar com uma
# comunidade engajada
# com +5 mil especialistas em integração, para te ajudar no dia a dia, trocar insights e fazer amizades.
# Ver documentação
# Fazer parte do Discord
# Seguro e em conformidade
# com a LGPD
# — como deve ser!
# Lei Geral de Proteção de Dados
# Estamos de acordo com as diretrizes da LGPD, exigindo sempre o consentimento e a autorização dos clientes. Assim, promovemos a proteção dos dados pessoais e garantimos o compartilhamento dos dados, de forma segura e criptografada, no sistema integrado de informações criado pelo Banco Central para o Open Finance.
# Instituição autorizada pelo BC
# Somos uma Instituição de Pagamento autorizada pelo Banco Central, integrantes do Sistema de Pagamentos Brasileiro (SPB) — nosso número bancário é 364. Por isso, temos a autonomia de oferecer serviços financeiros, bem como ser o seu intermediário no escopo do Open Finance.
# Criptografia de dados
# Usamos certificados de segurança para criptografia avançada e exigimos a adesão do protocolo Mutual Transport Layer Security (mTLS) para garantir a segurança na comunicação e ompartilhamento dos dados.
# Certificação OpenID
# Recebemos a certificação “OpenID Certified”, que garante que a implementação da nossa API está em conformidade com o protocolo OpenID Connect, para promover a interoperabilidade entre as implementações.
# Quero usar a API Open Finance
# Faça parte da revolução
# em pagamentos digitais
# com quem entende
# (de verdade) do assunto!
# Com a gente, você ingressa mais rápido ao ecossistema do Open Finance,
# moderniza as operações do seu negócio,
# se destaca no mercado e oferece uma experiência de compra melhor no seu aplicativo ou e-commerce.
# Quero falar com um especialista
# Quero falar com um especialista
# Dúvidas frequentes
# ...
# API Extrato
# Receba de forma automática o extrato das movimentações (Pix e TED) para
# simplificar sua conciliação bancária
# . É possível gerar relatórios com filtros personalizáveis de extrato no formato CSV.
# EXCLUSIVO PARA PARCEIROS
# API Abertura de Contas
# Inicie a abertura de conta dos seus clientes em lote e
# dentro do seu próprio sistema
# . É assim que você vai obter as credenciais e certificados necessários para utilizar a aplicação do cliente final.
# Programa de Parceria Efí
# Qualidade e inovação andam juntas.
# Junte-se a nós!
# Faça parte do Programa de Parcerias da Efí,
# exclusivo para a conta Efí Empresas.
# Integre APIs com soluções de pagamento ao seu sistema, indique clientes e obtenha uma série de benefícios exclusivos.
# Conhecer Programa de Parceria Efí
# Falar com especialista
# Fluxo de pagamento otimizado
# Temos os maiores índices de confirmações para que você e seus clientes tenham o melhor desempenho em pagamentos.
# Integração facilitada
# Disponibilizamos uma API RESTful para integrações em diversas linguagens de programação e fornecemos 12 SDKs nas principais linguagens utilizadas, além de módulos e plugins para plataformas de e-commerce.
# Atendimento especializado
# Conte com um Executivo de Parceria dedicado durante todo o programa, atendimento exclusivo para suporte e consultoria técnica gratuita no Discord.
# Praticidade na abertura de contas
# Abra a conta de seu cliente de forma facilitada, com trocas de informações por API.
# Comissionamento
# Receba comissões conforme o volume de liquidações de seus clientes. Quanto mais eles vendem, mais você ganha!
# Condições exclusivas para clientes
# Ofereça tarifas mais atrativas para seus clientes usando o seu cupom de parceiro.
# Facilidades da Efí Pay
# Revolucione suas vendas com
# automação e inteligência
# Conquista e fidelização de clientes
# Os meios de pagamento que seu cliente quer usar, sem complicações.
# Aumento da conversão
# Jornadas de pagamento mais simples e com alto nível de aprovação.
# Proteção antifraudes
# Tecnologia com alto padrão de segurança e monitoramento interno.
# Tomada de decisão inteligente
# Dados de recebimentos em um único sistema, facilitando a conciliação bancária.
# Facilidade de integração
# SDKs nas principais linguagens de programação.
# Estabilidade
# Processamento de milhares de requisições diárias aos endpoints das APIs.
# Personalização
# Customização das cobranças com a cor e marca da sua empresa.
# Redução da inadimplência
# Relatórios para acompanhamento da carteira que dão insights profundos.
# Tecnologia de ponta
# para escalar sua empresa.
# Fale com nosso comercial
# Confira a documentação
# Depoimentos
# Por que
# +480 mil
# clientes confiam na
# Efí Pay
# para gerenciar recebimentos?
# A principal solução que o Open Finance nos trouxe foi a facilidade na finalização do pagamento, pois 80% dos nossos clientes compram via mobile hoje em dia e isso acaba facilitando muito a vida do cliente, vira praticamente 'um clique' e fim, pagamento realizado. Creio que o maior beneficio que tenho com a Efí, seja o suporte ágil e o atendimento totalmente personalizado. Esse diferencial faz total diferença!
# Fabricio de Matos
# CEO do Rei dos Coins
# A priori, [a Efí] foi a única empresa, que encontramos no nosso espectro de busca, que fazia a integração fiel às normas do Banco Central. Integramos o Pix com o PDV, funcionou certinho, e conseguimos atingir o nosso objetivo.
# Robson Benedito
# CEO da RedeSoft
# Temos a Efí integrada ao nosso ERP onde nossos clientes aceitam o orçamento e já pagam online por Pix, cartão de crédito e boleto. É demais!
# Valério Ricardo Budke
# Systhesys Tecnologia
# Sou cliente da Efí e gosto muito! Tenho controle total [de recebimento] dos meus clientes em uma plataforma fácil e bem estruturada. O time de atendimento é ótimo, sempre à disposição para resolver qualquer dúvida ou situação. Estou indicando a Efí para novos clientes de e-commerce da DDR.
# Daniel Braun
# CEO da DDR Web Studio
# anterior
# próximo
# Desde 2007 facilitando a vida de empreendedores
# Desde
# 2007
# facilitando a vida
# de empreendedores
# Instituição autorizada
# pelo
# Banco Central
# Temos mais de
# 350
# colaboradores
# espalhados pelo Brasil
# Mais de
# R$
# 27
# bilhões
# movimentados
# em 2023
# Mais de
# 6
# bilhões
# de transações
# nas APIs em 2023
# Você no controle
# Plataforma de gestão completa,
# visual e fácil de usar,
# no celular e no computador
# Acompanhe o status de todas as suas cobranças em um dashboard simples e de onde estiver, pelo
# app ou plataforma web.
# anterior
# próximo
# De dev para dev
# Faça parte da nossa
# comunidade no Discord
# Mais do que bank, somos uma empresa tech que conhece os desafios dos desenvolvedores na área financeira.
# APIs com arquitetura limpa, moderna e fácil de integrar.
# SDKs disponíveis nas principais linguagens de programação.
# Universidade Efí com cursos gratuitos no Youtube.
# Reduza o abandono de carrinho com uma Comunidade no Discord com +5 mil integradores.
# Conecte-se ao Discord
# Curso de API 2.0
# Documentação descomplicada
# para integrações de sucesso
# Na
# documentação
# você encontra a referência técnica para integrar e usar nossas soluções em suas operações.
# Documentação aberta e atualizada.
# Conteúdos didáticos e com exemplos.
# Tutoriais explicativos em vídeo.
# Informações sobre compatibilidade.
# Integrações
# Atendimento 360º
# Pode contar,
# que a gente está junto!
# Nossos especialistas de atendimento e de suporte técnico estão aqui para ajudar você, seja por ticket, chat, telefone ou WhatsApp, de
# segunda a segunda, das 07h às 22h,
# inclusive em feriados.
# Entre em contato
# Comece a simplificar seus recebimentos com a
# Efí Pay
# agora
# A
# Efí Pay
# facilita a rotina de emitir e gerenciar os seus recebimentos. Conosco, seu time otimiza o processo, economiza tempo e ganha produtividade para se dedicar ao crescimento do seu negócio.
# Experimente a Efí Pay
# Descubra as tarifas Efí
# Conheça nossas
# Contas Digitais
# Conta Digital para receber os valores das suas vendas e concentrar a vida financeira do seu negócio,
# mesmo que não tenha CNPJ.
# Conheça a Conta Efí Pro
# Conheça a Conta Efí Pro
# Conta Digital completa para receber dos seus clientes e administrar
# todas as operações financeiras da sua empresa.
# Conheça a Conta Efí Empresas
# Conheça a Conta Efí Empresas
# Dúvidas frequentes
# sobre a Efí Pay
# Aqui, a gente responde algumas dúvidas sobre a
# Efí Pay.
# Se você preferir, nosso time de atendimento também está à disposição.
# É só entrar em contato com a gente!
# Como contratar as soluções da Efí Pay? Existe um aplicativo dedicado?
# É bem simples! Você não precisa contratar um pacote de serviços, por exemplo. Para usar as soluções da Efí Pay, basta abrir uma
# conta Efí Pro
# (empreendedor sem CNPJ) ou
# Efí Empresas
# (conta PJ) para começar a
# emitir cobranças manualmente
# pelo app ou plataforma web ou
# iniciar a integração das nossas APIs
# para emitir cobranças de forma automatizada.
# Confira a documentação das APIs da Efí
# Ah, e não! Não existe um app dedicado. Com a Efí, você tem tudo no mesmo lugar, para facilitar a sua vida!
# Quais APIs estão disponíveis no ecossistema de meios de pagamentos da Efí?
# Atualmente, são 6 APIs prontas para integração com e-commerces, plataformas e sistemas de gestão:
# API Pix
# — automatiza o envio e recebimento de Pix, com todos os recursos disponibilizados pelo Banco Central.
# API Cobranças
# — automatiza a emissão de boletos (Bolix), carnês, links de pagamento, botão de pagamento, assinaturas, checkout transparente e split de pagamento.
# API Open Finance
# : inicia pagamentos via Pix dentro de sites, apps e plataformas.
# API Abertura de contas
# : possibilita a abertura de contas em lote.
# API Pagamento de contas
# : permite a automação dos pagamentos de contas.
# API Extrato
# : automatiza a conciliação das movimentações da conta.
# É possível usar a Efí Pay em plataformas de e-commerce?
# Sim! A gente pensou em tudo. Além da integração via API, nós disponibilizamos também módulos e plugins para plataformas de e-commerce, que podem ser instalados em poucos passos — ideal também para não desenvolvedores.
# Disponível para Wordpress (WooCommerce), Magento (OpenMage e Magento 2), OpenCart, PrestaShop, WHMCS, Box Billing, Joomla (VirtueMart) e outros.
# Eu tenho suporte do time de desenvolvedores para fazer a integração?
# Sim. Pode contar, que a gente ajuda você em todo o processo! Nosso time de Consultoria Técnica está disponível, de segunda a segunda, no Discord, para ajudar você com o que for necessário.
# Quais são as tarifas para usar o ecossistema de pagamentos Efí Pay?
# Você não paga nada para abrir uma conta nem para começar a usar a Efí Pay. A emissão, baixa e cancelamento dos meios de pagamento também são gratuitas. A tarifa é apenas por recebimento dos produtos que você usar — e isso varia de produto para produto.
# Confira todas as tarifas da Efí aqui
# Preciso ter CNPJ para vender com a Efí Pay?
# Na verdade, não! O ecossistema de pagamentos da Efí Pay está disponível para as modalidades de conta Efí Pro (empreendedor sem CNPJ) e Efí Empresas (conta PJ).
# Portanto,
# se você não tem CNPJ
# mas quer vender com a Efí, basta
# abrir a conta Efí Pro
# e aproveitar todas as vantagens de ser Efí.
# Para onde vai o saldo das vendas realizadas?
# Vem para a sua
# Conta Digital gratuita na Efí
# ! É que para usar o ecossistema de pagamentos da Efí Pay, é necessário abrir uma conta Efí Pro (empreendedor sem CNPJ) ou Efí Empresas (conta PJ). Dessa forma, assim que você receber dos seus clientes, o saldo cai direto na conta — já com os descontos das tarifas de recebimento e pronto para você usar como preferir.
# Ainda tem dúvidas? Visite nossa
# Central de Ajuda.
# minimizar janela
# Tem muitos recebimentos por mês?
# Converse com nosso time comercial e veja todas as vantagens que podemos oferecer para sua empresa.
# Sim, quero contato!
# Abra sua Conta Grátis
# --------------------------------------------------------------------------------
# URL: https://sejaefi.com.br
# Título: Efí • Conta Digital + soluções de pagamentos online
# Título Principal: Efí Bank
# Descrição: Uma soma de bank e tech para facilitar sua vida financeira. Conta Digital PF e PJ gratuita, investimentos, gestão de cobranças, APIs e muito +.
# Palavras-chave: Efí, Gerencianet
# Conteúdo:
# A Gerencianet agora se chama Efí.
# Saiba mais!
# Abrir menu
# Soluções
# Pelo site ou aplicativo
# Boletos e Carnês
# Conta Digital
# Gestão de Cobranças
# Link de Pagamento
# Pagamento Recorrente
# Por API
# API Boletos e Carnês
# API Pix
# API Pix via Open Finance
# Checkout Transparente
# Split de Pagamento
# Pix Automático
# Novo
# Segmentos
# Provedor de Internet
# Bet - Apostas Esportivas
# Parcerias
# Desenvolvedores
# Efí Pay — Plataforma de pagamentos
# Documentação API
# Módulos e Plugins
# Comunidade no Discord
# Curso API 2.0 grátis
# Tarifas
# Blog
# Abra sua conta grátis
# Acessar minha conta
# Abra sua conta grátis
# Acessar minha conta
# Efí Bank
# Especialista em
# automatizar
# e
# simplificar recebimentos
# Abra sua conta grátis
# Fale com o time Comercial
# Plataforma de pagamentos
# Meios de pagamentos modernos, eficientes e seguros sob medida
# para o seu negócio
# Ofereça uma experiência de pagamentos completa com a Efí! Aceite diferentes formas de pagamento, como
# Pix, boletos
# e as
# principais bandeiras de cartões de crédito,
# com proteção antifraude e tarifas transparentes. Tudo em um só lugar.
# Boleto
# Boleto com QR Code Pix: o jeito mais moderno e rápido de receber por boletos.
# Saiba mais
# Pix
# Recebimentos em tempo real com o meio de pagamento mais usado pelos brasileiros.
# Saiba mais
# Cartão de crédito
# Pagamentos seguros via cartão de crédito, à vista ou parcelado.
# Pix via Open Finance
# Conecte seu app ou site a todos os bancos e acelere a jornada de pagamento do seu cliente.
# Saiba mais
# Como você deseja potencializar seus recebimentos?
# Integrando com as APIs
# da Efí Pay
# Centralize,
# automatize
# e escale a
# emissão de cobranças
# e
# recebimentos
# no seu site ou sistema.
# Explore todas as integrações
# Explore todas as integrações
# Gerenciando pela plataforma ou app da Efí Bank
# Controle toda a
# gestão de cobranças
# na palma da mão e receba pagamentos com
# menos esforço.
# Conheça as possibilidades
# Conheça as possibilidades
# Conta Digital PJ
# Eficiência para impulsionar o sucesso da sua empresa.
# Conte com a Efí!
# A
# Conta Digital PJ
# que é muito mais que conta, é a parceira que descomplica as
# finanças do seu negócio.
# Movimente seu saldo com segurança
# Pague fornecedores de forma fácil
# Simplifique a conciliação bancária
# Financie suas compras com o cartão PJ Visa® Platinum
# Abra sua conta gratuita
# Conheça a Conta Efí Empresas
# Programa de parcerias
# Seja um parceiro Efí Bank
# e cresça junto com a gente!
# Integre nossas
# soluções de pagamento
# ao seu sistema, indique clientes e obtenha uma série de
# benefícios exclusivos.
# Conheça o Programa de Parcerias
# Developer First
# Aqui, o dev é de casa
# Só um
# bank
# que já nasceu
# tech
# ajuda a superar os desafios
# dos desenvolvedores na área financeira. Criamos
# APIs
# com
# arquitetura limpa e moderna,
# SDKs nas principais linguagens de programação e
# garantia de 99,9% de disponibilidade.
# #1 em documentação
# técnica
# Integre as APIs mais bem avaliadas do mercado em
# apenas 3 dias.
# Acesse a documentação
# Maior comunidade
# do Brasil
# Junte-se aos
# +8000 integradores
# apaixonados pelas APIs da Efí no Discord.
# Faça parte
# Curso API 2.0
# com certificado
# Alcance o seu potencial máximo com as videoaulas
# objetivas
# e
# gratuitas
# da Efí.
# Comece agora
# Atendimento
# Pode contar,
# que a gente está junto!
# Parceria de verdade é
# não te deixar na mão.
# Por isso, nosso time de atendimento está pronto para dar todo o suporte que você precisa, de
# segunda a segunda
# — por
# chat, telefone
# ou
# WhatsApp.
# Veja como falar com a Efí
# Ir para a Central de Ajuda
# Eficiência,
# isso conta muito
# Somos a
# Efí Bank,
# a evolução da Gerencianet. Temos a solidez dos bancos tradicionais e a inovação de uma Conta Digital equipada com um ecossistema completo de meios de pagamento.
# Mais modernos do que nunca, queremos somar ainda mais tecnologia e atendimento humanizado para te ajudar a crescer.
# Conte com a gente!
# Conheça a Efí
# Por que
# +480 mil clientes
# confiam na Efí para cuidar dos recebimentos?
# Temos mais de
# 16
# anos
# de experiência
# Mais de
# R$
# 27
# bilhões
# movimentados
# em 2023
# Mais de
# 6
# bilhões
# de transações
# nas APIs
# 364
# é o nosso
# código bancário
# Reclame Aqui
# 9.0
# / 10
# Google play
# 4.6
# / 5
# App Store
# 4.5
# / 5
# Excelente aplicativo, muita solução pra quem quer mexer com clientes por meio de boletos, pix... PF ou PJ! O atendimento do pessoal do app é rápido e eficiente! Recomendo!
# Google Play
# Excelente atendimento, rápido e eficiente, conta personalizada e sempre com novidades pra melhorar sua gestão financeira na empresa. Só parabenizar e agradecer aos colaboradores.
# Google Play
# Muito bom App fora a empresa que fornece api e ainda melhor que tem quase tudo pronto só basta integrar ao seu sistema hoje deixei de usar outras devido a facilidade de integração
# App Store
# Sou cliente desde que emitia somente boletos. Muitas possibilidades e ferramentas fáceis de uso. Sempre com novs funcionalidades e soluções. Top 10!
# App Store
# Efí é um banco que tem me ajudado bastante com meu negócio como pessoa física... Só tenho a agradecer, resolveu os problemas que eu tinha, com a Efí sou maisorganizada, e meus clientes estão satisfeitos com as soluções que possibilito a eles.
# Google Play
# Fiquei muito agradecido pela compreensão do banco efí. Isso demonstra que o banco está em perfeita sintonia com quem de fato trabalha e usam seus produtos com sinceridade e compromisso sério. Nota mil!
# Reclame Aqui
# Após a reclamação a empresa se dedicou e resolveu o problema. Ofereceu um ótimo atendimento. Com certeza vou manter a parceria.
# Reclame Aqui
# Quero estender meu agradecimento ao banco EFÍ, pois deram todo o suporte e a atenção para o problema, e conseguimos resolver. E todos os boletos que estavam indevidamente no meu nome e CPF foram retirados.
# Reclame Aqui
# anterior
# próximo
# Efí na mídia
# minimizar janela
# Tem muitos recebimentos por mês?
# Converse com nosso time comercial e veja todas as vantagens que podemos oferecer para sua empresa.
# Sim, quero contato!
# Abra sua Conta Grátis
# --------------------------------------------------------------------------------

# %%
import json
from pprint import pprint

# Carrega o arquivo JSON
with open('tfidf_index.json', 'r', encoding='utf-8') as f:
    tfidf_index = json.load(f)

# Exibe o índice invertido TF-IDF de forma amigável
for doc_id, terms in tfidf_index.items():
    print(f"Documento ID: {doc_id}")
    pprint(terms)
    print("-" * 80)
# Out:
# Documento ID: https://sejaefi.com.br/lp/sistema-de-pagamento-para-provedores
# {'Brasil': 0.0037370960556902238,
#  'Erps': 0.016271107035316222,
#  'Gere': 0.01432175555402697,
#  'Internet': -0.005855561360926195,
#  'abrir': -0.01324791991780752,
#  'acer': 0.005707527336584398,
#  'acompanhar': 0.002793412896342496,
#  'adicione': 0.00658407328270918,
#  'administre': 0.01098931718595031,
#  'agilizar': 0.009606230299162901,
#  'alto': 0.0017857417864912775,
#  'ano': 0.0015208525394815244,
#  'anuidade': 0.004742764377631748,
#  'api': -0.009005313022509651,
#  'aplicativo': -0.0023404362863563306,
#  'aproveitar': 0.0023750889685077376,
#  'arquivo': 0.010248208148319261,
#  'arte': 0.016271107035316222,
#  'assinante': 0.04803115149581451,
#  'assinatura': 0.00251052587700147,
#  'aumente': 0.009606230299162901,
#  'automatizado': 0.01432175555402697,
#  'automatizar': 0.0008289946170954184,
#  'automático': -0.020351172945087353,
#  'autorizar': 0.0014103260095550878,
#  'baixo': 0.008533424763998432,
#  'banco': -0.004166558294337794,
#  'bancário': -0.00016160690688828163,
#  'bank': -0.0006113229590636858,
#  'barra': 0.00765687881787365,
#  'barro': 0.007879239479656129,
#  'bastar': 0.008533424763998432,
#  'bilhão': 0.0008928708932456387,
#  'boleto': -0.04145627239113807,
#  'bolix': 0.0,
#  'burocracia': 0.016150405491416817,
#  'cadastre': 0.012938668667239563,
#  'cair': 0.01316814656541836,
#  'cancelamento': 0.006915769780242601,
#  'carnê': -0.009830086383831529,
#  'cartão': -0.02101820290639293,
#  'celular': 0.004128180860757302,
#  'central': -0.00016027125128649923,
#  'chamar': 0.0,
#  'cliente': -0.04461000179658517,
#  'clique': 0.005707527336584398,
#  'cnab': 0.008075202745708408,
#  'cobrança': -0.12115013356637933,
#  'cobrar': 0.011964654806245225,
#  'coder': -0.0007821696101341577,
#  'colaborador': 0.004742764377631748,
#  'combo': 0.011865863132075093,
#  'comecer': 0.016271107035316222,
#  'começar': 0.0015914849853612821,
#  'completo': -0.004375596627380159,
#  'complicação': 0.012938668667239563,
#  'conectado': 0.012938668667239563,
#  'conectar': 0.005707527336584398,
#  'configurar': 0.008256361721514604,
#  'configure': 0.011865863132075093,
#  'conhecer': -0.0006825493330307079,
#  'conta': -0.092814849638338,
#  'contar': -0.003208628290661205,
#  'conte': 0.00897345252425952,
#  'controle': 0.0016339799308766878,
#  'cor': 0.005707527336584398,
#  'criar': 0.006273791931086241,
#  'crédito': -0.0131660863633084,
#  'código': -0.004869151853473302,
#  'data': 0.006187983071351666,
#  'deixar': 0.014899254896860045,
#  'descomplicar': 0.009754904743897558,
#  'desconto': 0.00033159784683816734,
#  'desvie': 0.01432175555402697,
#  'dia': -0.006249837441506691,
#  'dinheiro': 0.0015914849853612821,
#  'diário': 0.010248208148319261,
#  'débito': 0.0016339799308766878,
#  'eficiente': 0.004742764377631748,
#  'eficiência': 0.007272058107904725,
#  'efí': -0.11836771690922837,
#  'emissão': -0.0024657374732255702,
#  'emita': 0.010248208148319261,
#  'emitar': 0.003414623143842526,
#  'emitir': 0.0017857417864912775,
#  'empresa': -0.018982068785288107,
#  'encontre': 0.011865863132075093,
#  'enviar': -0.0009537873296033089,
#  'equipar': 0.01098931718595031,
#  'erp': 0.01807993140932212,
#  'erps': 0.016271107035316222,
#  'escolha': 0.006915769780242601,
#  'especialista': 0.00025089304408928005,
#  'esperar': 0.012938668667239563,
#  'estar': 0.0017498335442375557,
#  'exclusivo': 0.000700537553756701,
#  'experiência': 0.0015208525394815244,
#  'facilidade': 0.010895177545569991,
#  'facilitar': 0.003968008326881319,
#  'falar': 0.00251052587700147,
#  'favorito': 0.012938668667239563,
#  'fazer': -0.002390257377873382,
#  'feriado': 0.006273791931086241,
#  'ferramenta': 0.005200986395921771,
#  'ferramento': 0.010248208148319261,
#  'fidelização': 0.01432175555402697,
#  'financeiro': -0.017159151070582333,
#  'ganhar': 0.007272058107904725,
#  'gargalo': 0.016271107035316222,
#  'gente': -0.004166558294337794,
#  'gerencianet': 0.0,
#  'gerir': 0.00423030080941667,
#  'gestão': -0.04191494108956164,
#  'grátis': -0.021666236280007252,
#  'hora': 0.0016339799308766878,
#  'há': 0.016271107035316222,
#  'híbrido': 0.023731726264150186,
#  'identificar': 0.02197863437190062,
#  'ilimitar': 0.011865863132075093,
#  'imediato': 0.00903996570466106,
#  'implementação': 0.008533424763998432,
#  'inadimplência': 0.004128180860757302,
#  'incluir': 0.012938668667239563,
#  'informação': 0.0037581758552951462,
#  'inovação': 0.008533424763998432,
#  'instantâneo': 0.004529053980656585,
#  'instituição': -0.0012172879633683255,
#  'integrar': 0.00239323122515985,
#  'integração': -0.0019146987991378451,
#  'integre': 0.0054475887727849955,
#  'inteligente': 0.009606230299162901,
#  'inteligência': 0.012938668667239563,
#  'jornada': 0.0026498890350459526,
#  'juro': 0.00251052587700147,
#  'lembrete': 0.00903996570466106,
#  'linguagem': 0.004966418298953348,
#  'link': 0.003414623143842526,
#  'livelo': 0.006915769780242601,
#  'manual': 0.0059823274031226125,
#  'maquininha': 0.005200986395921771,
#  'marca': 0.008075202745708408,
#  'massa': 0.03615986281864424,
#  'meio': 0.005299778070091905,
#  'mensalidade': 0.011818859219484194,
#  'milhar': 0.008533424763998432,
#  'moderno': 0.004128180860757302,
#  'modo': 0.016271107035316222,
#  'movimentar': 0.0023750889685077376,
#  'multa': 0.003093991535675833,
#  'oferecer': 0.0010932203951714461,
#  'operacional': 0.019212460598325803,
#  'otimizar': 0.010243869431527577,
#  'otimize': 0.016271107035316222,
#  'pagamento': -0.19394163764448927,
#  'pagar': -0.011450467492663974,
#  'parceiro': 0.006187983071351666,
#  'perfeito': 0.008533424763998432,
#  'personalizar': 0.003589846837739775,
#  'pix': -0.045151440518247876,
#  'pj': 0.0020624140452614923,
#  'plano': 0.004742764377631748,
#  'plataforma': -0.006906279823952132,
#  'platinum': 0.0054475887727849955,
#  'poderoso': 0.009606230299162901,
#  'potencializar': 0.008075202745708408,
#  'pouco': 0.006915769780242601,
#  'praticidade': 0.004529053980656585,
#  'precisar': -0.006407468266490206,
#  'preocupar': 0.012938668667239563,
#  'provedor': -0.02406578145059087,
#  'página': 0.011865863132075093,
#  'qr': -0.0007821696101341577,
#  'receba': 0.008075202745708408,
#  'receber': -0.05811047114566873,
#  'recebimento': -0.008377138908388931,
#  'recebívei': 0.012938668667239563,
#  'recorrente': -0.0006825493330307079,
#  'recurso': 0.004128180860757302,
#  'reduzar': 0.008533424763998432,
#  'religamento': 0.016271107035316222,
#  'religar': 0.016271107035316222,
#  'resumo': 0.01098931718595031,
#  'rotina': 0.005200986395921771,
#  'régua': 0.01807993140932212,
#  'saber': -0.002178150474023561,
#  'secundário': 0.007272058107904725,
#  'segurança': 0.001196615612579925,
#  'semana': 0.009606230299162901,
#  'simples': 0.0016339799308766878,
#  'simplificar': 0.007166662824331881,
#  'site': -0.0037343334110467724,
#  'solicitar': 0.00251052587700147,
#  'solução': -0.013068305449076207,
#  'substituar': 0.016271107035316222,
#  'tarifa': -0.004581252295609212,
#  'tecnologia': -0.0015054717374186532,
#  'ted': 0.007272058107904725,
#  'tradicional': 0.00765687881787365,
#  'transferência': 0.004966418298953348,
#  'troca': 0.01098931718595031,
#  'turbinar': 0.01432175555402697,
#  'usuário': 0.00658407328270918,
#  'vencimento': 0.00423030080941667,
#  'via': -0.005450513992650512,
#  'vida': 0.0017498335442375557,
#  'visar': 0.0037581758552951462,
#  'web': 0.003939619739828064,
#  'útil': 0.004529053980656585}
# --------------------------------------------------------------------------------
# Documento ID: https://sejaefi.com.br/lp/iniciador-de-pagamentos-open-finance
# {'Api': 0.0006033035048620838,
#  'Finance': 0.0006199163604254195,
#  'Internet': -0.0017600531258275265,
#  'Open': -0.04344541604897684,
#  'Pix': -0.00965453689977263,
#  'abandono': 0.007916111230078089,
#  'abrir': -0.023892202395121073,
#  'abro': 0.0006199163604254195,
#  'acessar': -0.007306274652099591,
#  'acordo': 0.006549702108319531,
#  'alto': 0.0010735095132664327,
#  'ambiente': 0.015086112389201597,
#  'ano': 0.0018285394694344337,
#  'anual': 0.012321545056938764,
#  'api': -0.07579038012008123,
#  'apis': 9.881175352196554e-05,
#  'aplicativo': -0.002813934957006455,
#  'aposto': 0.0006199163604254195,
#  'app': -0.002376294368938846,
#  'aproveitar': 0.002855598297396586,
#  'atuar': 0.015556318397605946,
#  'automático': -0.012234231134618986,
#  'autorizar': 0.0033913041617047194,
#  'autorizer': 0.015556318397605946,
#  'banco': -0.010019007228003017,
#  'bet': 0.0006199163604254195,
#  'bilhão': 0.0021470190265328653,
#  'blog': 0.0003016517524310419,
#  'boleto': -0.019937351808917265,
#  'carnê': -0.011818832184028658,
#  'carrinho': 0.006549702108319531,
#  'central': -0.0003853921418218709,
#  'certificação': 0.010868860500401735,
#  'chamar': 0.0,
#  'checkout': 0.015597981737996076,
#  'checkoutr': -0.0003853921418218709,
#  'cliente': -0.044695955557272224,
#  'cnpj': 0.0,
#  'cobrança': -0.02731130178664042,
#  'comercial': 0.00898631190270019,
#  'completo': -0.0026304164696389393,
#  'compra': 0.004697253539920225,
#  'comunidade': -0.003227414829871356,
#  'conectar': 0.01372445879779832,
#  'conexão': 0.009205958347501266,
#  'conhecer': -0.0008206373483837412,
#  'construa': 0.01956294949910852,
#  'conta': -0.06974526273401122,
#  'contar': -0.0038577727425290784,
#  'contato': -0.000988195364992136,
#  'curso': 0.00019934205821485202,
#  'dado': -0.000988195364992136,
#  'desenhar': 0.008314913955436189,
#  'desenvolvedor': -9.715097292705946e-05,
#  'devsr': 0.01956294949910852,
#  'digital': -0.01387950537947743,
#  'discord': -0.0017600531258275265,
#  'diverso': 0.014266471280182769,
#  'documentação': -0.001386998090350237,
#  'dê': 0.009708914283857508,
#  'ecossistema': 0.005199327245998693,
#  'efí': -0.08538896572411386,
#  'emissão': -0.000988195364992136,
#  'empresa': -0.015214914479151931,
#  'encurtar': 0.017219220550506415,
#  'entregar': 0.01321258944900384,
#  'enviar': -0.0002866875210368327,
#  'escalar': 0.010868860500401735,
#  'escolher': 0.0071926248546214065,
#  'esportiva': 0.0006199163604254195,
#  'estar': 0.0021038461109908185,
#  'etapa': 0.014385249709242813,
#  'experiência': 0.0018285394694344337,
#  'falar': 0.01207374294604175,
#  'fazer': -0.002873835460102101,
#  'finance': -0.00227505025962358,
#  'financer': 0.02173772100080347,
#  'fluido': 0.012321545056938764,
#  'formulário': 0.003536425093098225,
#  'frente': 0.01321258944900384,
#  'gerencianet': 0.0,
#  'gestão': -0.007199263209437507,
#  'grátis': -0.034732771840011625,
#  'habilitar': 0.01956294949910852,
#  'haver': 0.008743283736671575,
#  'homologação': 0.014266471280182769,
#  'hora': 0.001964553905331509,
#  'importante': 0.009708914283857508,
#  'infraestrutura': 0.017219220550506415,
#  'iniciador': 0.014266471280182769,
#  'iniciadora': 0.014266471280182769,
#  'iniciar': 0.007916111230078089,
#  'iniciação': 0.02173772100080347,
#  'instituição': -0.0014635600946856166,
#  'integrador': 0.009708914283857508,
#  'integre': 0.006549702108319531,
#  'interface': 0.011549687296103372,
#  'jornada': 0.012743975012475333,
#  'junto': 0.003536425093098225,
#  'linguagem': 0.005971185006834083,
#  'linkr': 0.0006199163604254195,
#  'manualmente': 0.014266471280182769,
#  'melhorar': 0.010868860500401735,
#  'menu': 0.0004058049634291824,
#  'mercado': 0.003719943580465741,
#  'milhão': 0.014266471280182769,
#  'movimentar': 0.002855598297396586,
#  'mudar': 0.011549687296103372,
#  'módulo': 0.0,
#  'nascer': 0.009205958347501266,
#  'negócio': -0.008303504065792158,
#  'nome': 0.0006199163604254195,
#  'oferecer': 0.0013143921514200045,
#  'online': 0.011404566364709866,
#  'onliner': 0.00686222939889916,
#  'openidr': 0.015556318397605946,
#  'oportunidade': 0.011549687296103372,
#  'otimizado': 0.01956294949910852,
#  'pagamento': -0.26061113633832766,
#  'parcerio': 0.0005118693487944799,
#  'pare': 0.017219220550506415,
#  'pay': -0.0075127210960303,
#  'perder': 0.010868860500401735,
#  'permitir': 0.004518500450297054,
#  'pix': -0.054286125016159294,
#  'plataforma': -0.004151752032896079,
#  'plugim': 0.0,
#  'política': 0.0016956520808523597,
#  'ponta': 0.010259840178680195,
#  'potencial': 0.008743283736671575,
#  'precisar': -0.002567925625105901,
#  'preenchar': 0.014266471280182769,
#  'primeiro': 0.015556318397605946,
#  'privacidade': 0.003185993753118833,
#  'processar': 0.011549687296103372,
#  'programação': 0.00625320907717762,
#  'pronto': 0.007916111230078089,
#  'provedor': -0.0026304164696389393,
#  'realmente': 0.014266471280182769,
#  'receber': -0.02328897494855317,
#  'recebimento': -0.005035967898684675,
#  'recorrente': -0.0008206373483837412,
#  'reduzir': 0.004518500450297054,
#  'revolucionar': 0.014266471280182769,
#  'revolucione': 0.012321545056938764,
#  'rápido': 0.0021470190265328653,
#  'saber': -0.0013094083774476898,
#  'sair': 0.01841191669500253,
#  'sandbox': 0.01321258944900384,
#  'sdks': 0.01956294949910852,
#  'segmentos': 0.0006199163604254195,
#  'seguro': -0.00113752512981179,
#  'simples': 0.005893661715994526,
#  'simplificar': 0.004308282853933616,
#  'simplifique': 0.010259840178680195,
#  'site': -0.0022449171950801403,
#  'solicitar': 0.0030184357365104376,
#  'solução': -0.010474788182689213,
#  'split': -0.00047020600840434913,
#  'suporte': 0.002855598297396586,
#  'tarifa': -0.005508095245587953,
#  'tecnologia': -0.001810046944410866,
#  'tecnológico': 0.01321258944900384,
#  'tela': 0.005199327245998693,
#  'telefone': 0.0014387054763966727,
#  'teste': 0.008743283736671575,
#  'time': -0.0011467500841473308,
#  'transação': 0.0021038461109908185,
#  'transparente': -0.0014700020287311748,
#  'técnico': 0.004518500450297054,
#  'venda': -0.002873835460102101,
#  'ver': 0.0005118693487944799,
#  'via': -0.013106438271344582}
# --------------------------------------------------------------------------------
# Documento ID: https://sejaefi.com.br/lp/open-finance-para-ecommerce
# {'América': 0.01348362654719432,
#  'Api': 0.00020791136721342728,
#  'Banco': 0.001968201216930715,
#  'Brasil': 0.007742191031708829,
#  'Finance': 0.00042727302929720153,
#  'Fórum': 0.01348362654719432,
#  'Internet': -0.0012131043456898888,
#  'Matos': 0.00983306586243673,
#  'Open': -0.04658025571962014,
#  'Pix': -0.01330864449132004,
#  'Real': 0.011868227710109999,
#  'abandono': 0.02182449789328302,
#  'aberto': 0.009106685158078344,
#  'abrir': -0.016467533921736836,
#  'abro': 0.00042727302929720153,
#  'acabar': 0.008492539023308392,
#  'acessar': -0.005035798863797726,
#  'acontecer': 0.007960541443131009,
#  'adicione': 0.005456124473320755,
#  'adulto': 0.01348362654719432,
#  'ajudar': 0.0018590419572171114,
#  'alto': 0.0014798178947816162,
#  'ambiente': 0.005198998891099355,
#  'americo': 0.01348362654719432,
#  'ami': 0.01348362654719432,
#  'anterior': 0.002829647864220101,
#  'anual': 0.008492539023308392,
#  'api': -0.0447754209246695,
#  'aplicativo': -0.0019394850500482738,
#  'aposto': 0.00042727302929720153,
#  'app': -0.0065513773040067,
#  'apresentar': 0.008492539023308392,
#  'aproveitar': 0.00393640243386143,
#  'atendimento': -0.0009025005948145432,
#  'aumento': 0.009106685158078344,
#  'automático': -0.008432358511111892,
#  'autorizar': 0.00233743274890405,
#  'bacen': 0.00983306586243673,
#  'baixar': 0.006691801478515334,
#  'banco': -0.008631913597831286,
#  'bancário': -0.00013392126148510986,
#  'beneficio': 0.00983306586243673,
#  'bet': 0.00042727302929720153,
#  'bilhão': 0.0007399089473908081,
#  'blog': 0.00020791136721342728,
#  'boleto': -0.02061252109328299,
#  'bom': -0.0005065943246424169,
#  'box': 0.011868227710109999,
#  'brasileiro': 0.006691801478515334,
#  'burocrático': 0.0074912863209940245,
#  'carnê': -0.00814604768062533,
#  'carrinho': 0.027086019077432962,
#  'cartão': -0.008708737459222569,
#  'case': 0.009106685158078344,
#  'central': -0.0001328144233768599,
#  'ceo': 0.004514336512905494,
#  'chamar': 0.0,
#  'checkout': 0.014334400216060141,
#  'checkoutr': -0.0001328144233768599,
#  'chegar': 0.007071523310405075,
#  'cliente': -0.030806375742661735,
#  'clique': 0.009459487537924739,
#  'cobrança': -0.006274708112999725,
#  'cocriar': 0.01348362654719432,
#  'coim': 0.01348362654719432,
#  'compr': 0.00983306586243673,
#  'compra': 0.005395915421023898,
#  'comunidade': -0.002224473169592608,
#  'conclua': 0.011868227710109999,
#  'concluir': 0.011868227710109999,
#  'conectar': 0.004729743768962369,
#  'conexão': 0.01269028521209338,
#  'confirmar': 0.007071523310405075,
#  'conformidade': 0.00983306586243673,
#  'conhecer': -0.002262474283193422,
#  'consumidor': 0.02144416799032533,
#  'conta': -0.06730001049473114,
#  'contar': -0.002658942965966257,
#  'conversão': 0.006691801478515334,
#  'convidado': 0.01348362654719432,
#  'copiar': 0.011868227710109999,
#  'crer': 0.00983306586243673,
#  'crescimento': 0.006691801478515334,
#  'criar': 0.005198998891099355,
#  'crédito': -0.005455270843761248,
#  'cupom': 0.004729743768962369,
#  'curso': 0.00013739512378951952,
#  'código': -0.0010087485911578155,
#  'dado': -0.0006811067655125081,
#  'danilo': 0.01348362654719432,
#  'depoimento': 0.007960541443131009,
#  'desenvolvedor': -6.696063074255493e-05,
#  'desister': 0.01348362654719432,
#  'desistência': 0.01348362654719432,
#  'dia': -0.001726382719566257,
#  'diferencial': 0.00983306586243673,
#  'diferença': 0.00634514260604669,
#  'digital': -0.009566352313345001,
#  'digitar': 0.01348362654719432,
#  'direto': 0.0009916177187913322,
#  'diretor': 0.011868227710109999,
#  'discord': -0.0024262086913797777,
#  'disponível': 0.002520616161053044,
#  'documentação': -0.0019119575269369803,
#  'dê': 0.006691801478515334,
#  'eficiente': 0.0039302589264836795,
#  'efí': -0.05885374928395099,
#  'elever': 0.010722083995162664,
#  'emitir': 0.0007399089473908081,
#  'escolher': 0.004957466533264954,
#  'esportiva': 0.00042727302929720153,
#  'estande': 0.01348362654719432,
#  'estimativo': 0.01348362654719432,
#  'etapa': 0.004957466533264954,
#  'evento': 0.007960541443131009,
#  'experimentar': 0.01205249471270265,
#  'experimente': 0.007960541443131009,
#  'experiência': 0.001260308080526522,
#  'fabricio': 0.00983306586243673,
#  'facilidade': 0.004514336512905494,
#  'facilitar': 0.0016441150039667616,
#  'fechar': 0.009106685158078344,
#  'finalização': 0.009106685158078344,
#  'finance': -0.002613437549235587,
#  'financer': 0.0074912863209940245,
#  'financir': 0.013383602957030668,
#  'fintech': 0.011868227710109999,
#  'fluido': 0.008492539023308392,
#  'fonte': 0.016985078046616784,
#  'frete': 0.011868227710109999,
#  'fórum': 0.023736455420219998,
#  'gente': -0.005179148158698772,
#  'gerencianet': 0.0,
#  'gestão': -0.009924083946077201,
#  'gratuito': 0.0015484382063417658,
#  'grátis': -0.02393932082996817,
#  'hoje': 0.002969453919245082,
#  'hora': 0.0013540550821607613,
#  'imagine': 0.01348362654719432,
#  'imersão': 0.01348362654719432,
#  'implementação': 0.007071523310405075,
#  'importante': 0.006691801478515334,
#  'influenciar': 0.01348362654719432,
#  'iniciação': 0.014982572641988049,
#  'instituição': -0.0010087485911578155,
#  'integração': -0.0007933413351009398,
#  'intelligence': 0.01348362654719432,
#  'interativo': 0.01348362654719432,
#  'interesse': 0.0032647048043196705,
#  'intervalo': 0.01348362654719432,
#  'inédito': 0.01348362654719432,
#  'ir': 0.0018590419572171114,
#  'jornada': 0.006587771943699898,
#  'julho': 0.01348362654719432,
#  'latino': 0.01348362654719432,
#  'lgpd': 0.010722083995162664,
#  'linguagem': 0.004115597634192416,
#  'linkr': 0.00042727302929720153,
#  'manualmente': 0.00983306586243673,
#  'market': 0.01348362654719432,
#  'meio': 0.0021959239812332993,
#  'menu': 0.0002796982417260899,
#  'mobile': 0.009106685158078344,
#  'mudar': 0.007960541443131009,
#  'muuuito': 0.011868227710109999,
#  'métrica': 0.010722083995162664,
#  'módulo': 0.0,
#  'navegador': 0.00634514260604669,
#  'negócio': -0.0028615661421953053,
#  'oferecer': 0.000905935626277533,
#  'oliveira': 0.011868227710109999,
#  'opinion': 0.01348362654719432,
#  'pagamento': -0.11344699497554375,
#  'pagar': -0.007591066895535002,
#  'palco': 0.01348362654719432,
#  'palestrar': 0.01348362654719432,
#  'parar': 0.010722083995162664,
#  'parcerio': 0.00035280237984639456,
#  'participante': 0.008492539023308392,
#  'participar': 0.016985078046616784,
#  'passo': 0.015596996673298065,
#  'pay': -0.01035618127181866,
#  'pedido': 0.011868227710109999,
#  'pensar': 0.006691801478515334,
#  'perder': 0.014982572641988049,
#  'personalizar': 0.0009916177187913322,
#  'pesquisa': 0.01348362654719432,
#  'pix': -0.08231593299263039,
#  'plataforma': -0.005723132284390611,
#  'plugim': 0.0,
#  'população': 0.01348362654719432,
#  'potencial': 0.006026247356351325,
#  'praticamente': 0.00983306586243673,
#  'precisar': -0.00707969933296129,
#  'principal': 0.0035836000540150352,
#  'produto': 0.010262887876942454,
#  'promocional': 0.011868227710109999,
#  'provedor': -0.0018129962121415798,
#  'prática': 0.008492539023308392,
#  'realizar': 0.0071672001080300704,
#  'receber': -0.0053505878699863195,
#  'recebimento': -0.006942011525676883,
#  'recorrente': -0.0005656185707983555,
#  'reduzir': 0.0031143449318780493,
#  'redução': 0.00983306586243673,
#  'regular': 0.01966613172487346,
#  'rei': 0.00983306586243673,
#  'relatório': 0.0043918479624665985,
#  'representação': 0.01348362654719432,
#  'revolucione': 0.008492539023308392,
#  'rápido': 0.0022197268421724247,
#  'saber': -0.0009025005948145432,
#  'saldo': 0.004115597634192416,
#  'sdk': 0.005198998891099355,
#  'segmentos': 0.00042727302929720153,
#  'segundo': 0.003420962625647485,
#  'seguro': -0.0002613437549235587,
#  'selecione': 0.010722083995162664,
#  'ser': -0.0001328144233768599,
#  'simples': 0.005416220328643045,
#  'simular': 0.011868227710109999,
#  'simule': 0.01966613172487346,
#  'site': -0.0030945870497917478,
#  'sobretudo': 0.01348362654719432,
#  'solução': -0.010829512085290243,
#  'split': -0.0003240862129639538,
#  'sprint': 0.00983306586243673,
#  'sucesso': 0.004729743768962369,
#  'suporta': 0.006026247356351325,
#  'suporte': 0.00393640243386143,
#  'tag': 0.00634514260604669,
#  'tarifa': -0.0037964162449669954,
#  'tecnologia': -0.0012475622365859754,
#  'tela': 0.0071672001080300704,
#  'total': 0.01039799778219871,
#  'totalmente': 0.007960541443131009,
#  'totem': 0.01348362654719432,
#  'transação': 0.004350183791251932,
#  'transferir': 0.00983306586243673,
#  'transparente': -0.0010131886492848337,
#  'trazer': 0.007071523310405075,
#  'técnico': 0.0031143449318780493,
#  'usar': 0.0025639451769743954,
#  'venda': -0.00990385527086979,
#  'vendar': 0.00983306586243673,
#  'ver': 0.002116814279078367,
#  'via': -0.006775140899230915,
#  'vida': 0.0029001225275012876,
#  'video': 0.00634514260604669,
#  'vira': 0.00983306586243673,
#  'ágil': 0.005730996471276737}
# --------------------------------------------------------------------------------
# Documento ID: https://sejaefi.com.br/solicitar-cartao-de-credito
# {'Api': 0.0006212589663163124,
#  'Finance': 0.001276732504209495,
#  'Internet': -0.0036248713186685963,
#  'Open': -0.009941874307503958,
#  'Pix': -0.019883748615007916,
#  'abaixo': 0.023786855978879563,
#  'abra': 0.029382137279424035,
#  'abrir': -0.03280437312980909,
#  'abro': 0.001276732504209495,
#  'acessar': -0.015047446604919395,
#  'acordo': 0.013489267437372368,
#  'análise': 0.021130385129900876,
#  'api': -0.11149435170726234,
#  'aplicativo': -0.005795366042406151,
#  'aposto': 0.001276732504209495,
#  'automático': -0.012598345156482647,
#  'autorizar': 0.0034922358331840263,
#  'bet': 0.001276732504209495,
#  'blog': 0.0006212589663163124,
#  'boleto': -0.041061450749317704,
#  'carnê': -0.024341166283773308,
#  'cartão': -0.02602253693172458,
#  'chamar': 0.0,
#  'checkoutr': -0.0003968621460427599,
#  'cliente': -0.018410476931924036,
#  'cnpj': 0.0,
#  'cobrança': -0.018749425432892035,
#  'completo': -0.005417405348184958,
#  'comunidade': -0.0033234688426651464,
#  'consulta': 0.035463394705209636,
#  'conta': -0.14364202920218974,
#  'contar': -0.007945174814970602,
#  'cpf': 0.019995740132230343,
#  'crédito': -0.04075217207690694,
#  'curso': 0.0004105497151329691,
#  'darer': 0.04029036027792588,
#  'declaro': 0.035463394705209636,
#  'desenvolvedor': -0.000200084741861682,
#  'digital': -0.014292585896723782,
#  'discord': -0.0036248713186685963,
#  'documentação': -0.002856555590840369,
#  'efí': -0.11724040531961666,
#  'enviar': -0.000590439775468715,
#  'espera': 0.07092678941041927,
#  'esportiva': 0.001276732504209495,
#  'estar': 0.008665842314319322,
#  'ficar': 0.02238467698297024,
#  'função': 0.018007001029097414,
#  'gerencianet': 0.0,
#  'gestão': -0.014827053990865341,
#  'grátis': -0.07153297057526203,
#  'informação': 0.009305959260730837,
#  'liberar': 0.023786855978879563,
#  'linkr': 0.001276732504209495,
#  'lista': 0.07092678941041927,
#  'lote': 0.015535103829356404,
#  'menu': 0.00083576498420534,
#  'módulo': 0.0,
#  'nome': 0.001276732504209495,
#  'pagamento': -0.11299680848754556,
#  'parcerio': 0.0010542071112076788,
#  'pay': -0.007736313985793107,
#  'pix': -0.022360713399513232,
#  'plataforma': -0.008550632162988353,
#  'plugim': 0.0,
#  'política': 0.0034922358331840263,
#  'pouco': 0.01712476326536263,
#  'preferido': 0.035463394705209636,
#  'prioridade': 0.035463394705209636,
#  'privacidade': 0.006561629991542359,
#  'provedor': -0.005417405348184958,
#  'recorrente': -0.0016901221579808002,
#  'saber': -0.0026967577297434563,
#  'scr': 0.04029036027792588,
#  'segmentos': 0.001276732504209495,
#  'serasa': 0.03203860812840272,
#  'site': -0.004623460413676956,
#  'solução': -0.010786537830983534,
#  'split': -0.0009684004696899095,
#  'sujeitar': 0.029382137279424035,
#  'tarifa': -0.011344053303413284,
#  'telefone': 0.0029630481835312425,
#  'transparente': -0.0015137520891100788,
#  'via': -0.006748255419472062}
# --------------------------------------------------------------------------------
# Documento ID: https://sejaefi.com.br/lp/blackfriday-efibank-2023
# {'Api': 0.0002521050877805326,
#  'Finance': 0.0005180943495342879,
#  'Internet': -0.001470962274242329,
#  'Open': -0.008068767553916256,
#  'Pix': -0.008068767553916256,
#  'abandono': 0.013231760800033908,
#  'abrir': -0.019967879296405536,
#  'abro': 0.0005180943495342879,
#  'acessar': -0.00610621021648903,
#  'adicione': 0.006615880400016954,
#  'agradável': 0.010297716400243509,
#  'ajudar': 0.002254200634113502,
#  'alto': 0.0026915528376100415,
#  'ano': 0.0015281996531988262,
#  'anual': 0.010297716400243509,
#  'api': -0.04524408475077313,
#  'apis': 8.258180366811613e-05,
#  'aplicativo': -0.0023517427418459744,
#  'aposto': 0.0005180943495342879,
#  'app': -0.0019859851489199055,
#  'aproveitar': 0.0023865628282589823,
#  'assinatura': 0.0050453080426696205,
#  'aumentar': 0.01439094277892565,
#  'automatizar': 0.0003331997688035691,
#  'automático': -0.015337115842674528,
#  'autorizar': 0.001417139178683373,
#  'banco': -0.004186686595276623,
#  'bancário': -8.119380829169704e-05,
#  'barro': 0.003958651719247523,
#  'bet': 0.0005180943495342879,
#  'bilhão': 0.0017943685584066941,
#  'black': 0.04769274456949989,
#  'blog': 0.0002521050877805326,
#  'boleto': -0.07498177962918885,
#  'bolix': 0.0,
#  'bom': -0.0024571048402946207,
#  'botão': 0.012608200209332735,
#  'brasileiro': 0.008114213386992022,
#  'carnê': -0.019755149447700078,
#  'carnês': 0.009083637036567633,
#  'carrinho': 0.016421716880279404,
#  'cartão': -0.021119740118501106,
#  'central': -0.00016104550853909098,
#  'chamar': 0.0,
#  'chance': 0.013001174312975018,
#  'checkout': 0.004345331466462675,
#  'checkoutr': -0.00032209101707818196,
#  'cliente': -0.05229642722691465,
#  'cobrança': -0.015216924989013825,
#  'cobrar': 0.006011227535504846,
#  'coder': -0.00039297410364228213,
#  'comercial': 0.0018775748299119962,
#  'comissão': 0.008574649038220646,
#  'compra': 0.0013085746576589356,
#  'comprar': 0.011923186142374972,
#  'comunidade': -0.0013486540231104943,
#  'conectar': 0.005735099932413308,
#  'confirmar': 0.008574649038220646,
#  'conhecer': -0.000685846672803803,
#  'conta': -0.09326323055446523,
#  'contar': -0.0032241289104228527,
#  'contato': -0.0008258830828195146,
#  'conversão': 0.008114213386992022,
#  'crie': 0.009083637036567633,
#  'crédito': -0.006614845322628374,
#  'curso': 0.00016659988440178455,
#  'código': -0.0012231685815488487,
#  'demonstração': 0.006011227535504846,
#  'desenvolvedor': -8.119380829169704e-05,
#  'digital': -0.011599779858210606,
#  'direto': 0.0012023963643315186,
#  'discord': -0.001470962274242329,
#  'disponível': 0.0015281996531988262,
#  'distribuição': 0.013001174312975018,
#  'diversificar': 0.016349711417129344,
#  'dividir': 0.013001174312975018,
#  'divisão': 0.011042405674771324,
#  'documentação': -0.0011591819788917442,
#  'dê': 0.016228426773984044,
#  'eficiente': 0.004765676282837698,
#  'efí': -0.14272744995431594,
#  'emissão': -0.0008258830828195146,
#  'emitar': 0.0034311189078224413,
#  'encantar': 0.01439094277892565,
#  'encontrar': 0.008574649038220646,
#  'entrega': 0.010297716400243509,
#  'enviar': -0.0002395987494655655,
#  'escolher': 0.006011227535504846,
#  'esportiva': 0.0005180943495342879,
#  'estar': 0.0017582868463836307,
#  'experimentar': 0.0073071888234018485,
#  'experimente': 0.009652637208820692,
#  'experiência': 0.0030563993063976525,
#  'falar': 0.0025226540213348103,
#  'fazer': -0.004803609029929115,
#  'finance': -0.00031689508447252764,
#  'fixo': 0.007693868570617,
#  'fluido': 0.010297716400243509,
#  'forma': 0.013001174312975018,
#  'friday': 0.04769274456949989,
#  'gente': -0.0020933432976383117,
#  'gerencianet': 0.0,
#  'gerir': 0.00637610556781643,
#  'gestão': -0.012033551065050132,
#  'grátis': -0.029027872117497636,
#  'haver': 0.0073071888234018485,
#  'hora': 0.0016418735537311645,
#  'importante': 0.008114213386992022,
#  'inovar': 0.013001174312975018,
#  'instalar': 0.01439094277892565,
#  'interesse': 0.003958651719247523,
#  'jornada': 0.0026626904313505223,
#  'junto': 0.002955563000512043,
#  'link': 0.0068622378156448826,
#  'linkr': 0.0005180943495342879,
#  'lucre': 0.016349711417129344,
#  'lâmina': 0.009652637208820692,
#  'magento': 0.023846372284749943,
#  'manualmente': 0.011923186142374972,
#  'maquininha': 0.00522611193406632,
#  'meio': 0.0026626904313505223,
#  'menu': 0.00033915100808332637,
#  'merecer': 0.01439094277892565,
#  'mestre': 0.013001174312975018,
#  'milhão': 0.011923186142374972,
#  'movimentar': 0.0023865628282589823,
#  'mudar': 0.009652637208820692,
#  'muuuito': 0.01439094277892565,
#  'módulo': 0.0,
#  'nascer': 0.007693868570617,
#  'oferecer': 0.0021970033062382686,
#  'oferta': 0.009652637208820692,
#  'online': 0.004765676282837698,
#  'onliner': 0.005735099932413308,
#  'opencart': 0.01439094277892565,
#  'openmage': 0.01439094277892565,
#  'oportunidade': 0.009652637208820692,
#  'opção': 0.0053253808627010445,
#  'otimizar': 0.0034311189078224413,
#  'outro': 0.008114213386992022,
#  'pagamento': -0.18341510942905948,
#  'pagar': -0.002301156752148895,
#  'parcelar': 0.003776331294209615,
#  'parcerio': 0.00042779419005529,
#  'pare': 0.01439094277892565,
#  'passar': 0.008114213386992022,
#  'passo': 0.012608200209332735,
#  'pay': -0.025114990330690666,
#  'percentual': 0.013001174312975018,
#  'perder': 0.018167274073135266,
#  'periódico': 0.010297716400243509,
#  'pix': -0.07259130147088354,
#  'plano': 0.004765676282837698,
#  'plataforma': -0.006939643494599242,
#  'plugim': 0.0,
#  'pouco': 0.0069491792960891825,
#  'precisar': -0.006438422219468419,
#  'prestashop': 0.01439094277892565,
#  'processar': 0.009652637208820692,
#  'processo': 0.0010985016531191343,
#  'produto': 0.004148123763466274,
#  'pronto': 0.006615880400016954,
#  'provedor': -0.0021983673876692584,
#  'qr': -0.00039297410364228213,
#  'real': 0.004550933468485844,
#  'realizar': 0.004345331466462675,
#  'realmente': 0.011923186142374972,
#  'recebedor': 0.009652637208820692,
#  'receber': -0.032439554477453295,
#  'recebimento': -0.01683521635695553,
#  'recorrente': -0.000685846672803803,
#  'redirecionamento': 0.011042405674771324,
#  'reduzir': 0.003776331294209615,
#  'regra': 0.008574649038220646,
#  'repasse': 0.013898358592178365,
#  'repasses': 0.013001174312975018,
#  'revolucionar': 0.011923186142374972,
#  'rápido': 0.0008971842792033471,
#  'saber': -0.001094336470040823,
#  'segmentos': 0.0005180943495342879,
#  'simples': 0.003283747107462329,
#  'simplificar': 0.0036006421919348576,
#  'site': -0.007504747338142306,
#  'solicitar': 0.0050453080426696205,
#  'solução': -0.004377145786486072,
#  'split': -0.0007859482072845643,
#  'suporta': 0.0073071888234018485,
#  'tarifa': -0.013810151847633564,
#  'tecnologia': -0.0022691168216165208,
#  'time': -0.0002395987494655655,
#  'transação': 0.0052748605391508925,
#  'transferir': 0.011923186142374972,
#  'transforme': 0.013001174312975018,
#  'transparente': -0.0012285524201473103,
#  'transparência': 0.008114213386992022,
#  'usar': 0.003108938354688759,
#  'venda': -0.012009022574822788,
#  'vender': 0.0054739056267598014,
#  'ver': 0.00042779419005529,
#  'via': -0.0027384224890611266,
#  'vista': 0.0069491792960891825,
#  'visualização': 0.009083637036567633,
#  'volume': 0.007693868570617,
#  'várias': 0.016228426773984044,
#  'whmcs': 0.01439094277892565,
#  'woocommerce': 0.01439094277892565,
#  'wordpress': 0.01439094277892565}
# --------------------------------------------------------------------------------
# Documento ID: https://sejaefi.com.br/efi-pay/gestao-de-cobrancas
# {'Api': 0.00013278817600654007,
#  'Banco': 0.0025140890862575542,
#  'Business': 0.00757996222706771,
#  'Central': 0.003660254743741631,
#  'Daniel': 0.00628015147957155,
#  'Finance': 0.00027288939021271653,
#  'Internet': -0.0015495633117972628,
#  'Matos': 0.00628015147957155,
#  'Open': -0.004249961536032227,
#  'Pix': -0.004249961536032227,
#  'Real': 0.00757996222706771,
#  'Ricardo': 0.006847946775536461,
#  'abertura': 0.002184889615871549,
#  'abrir': -0.02804648695067648,
#  'abro': 0.00027288939021271653,
#  'acabar': 0.0054239880276091765,
#  'aceitar': 0.0009261205526753477,
#  'aceito': 0.008611680059404006,
#  'acessar': -0.003216248129295749,
#  'acompanhar': 0.0029568950760266626,
#  'acordo': 0.0057664044007088,
#  'adicionar': 0.00757996222706771,
#  'adicione': 0.006969400726735417,
#  'administrar': 0.0033204802078013696,
#  'agilidader': 0.00757996222706771,
#  'agradável': 0.0054239880276091765,
#  'ajudar': 0.002374654103111934,
#  'alto': 0.0009451254238936024,
#  'anterior': 0.0054216917093072164,
#  'anual': 0.0054239880276091765,
#  'api': -0.028597024560030646,
#  'apis': 8.699457180305365e-05,
#  'aplicativo': -0.0037161125768100513,
#  'apoiar': 0.005084213491668915,
#  'aposto': 0.00027288939021271653,
#  'app': -0.0020921064927553203,
#  'aproveitar': 0.0025140890862575542,
#  'assinatura': 0.003986178491727525,
#  'atendimento': -0.0028820311615578922,
#  'atingir': 0.006847946775536461,
#  'ativar': 0.008611680059404006,
#  'ativação': 0.008611680059404006,
#  'automatizar': 0.00017550216830111657,
#  'automático': -0.013463880319905119,
#  'avançado': 0.00757996222706771,
#  'avançar': 0.006847946775536461,
#  'baixar': 0.0042738986542171726,
#  'baixe': 0.0054239880276091765,
#  'baixo': 0.0045164181957040046,
#  'banco': -0.0011026006682217063,
#  'barro': 0.0020850913635731233,
#  'benedito': 0.006847946775536461,
#  'beneficio': 0.00628015147957155,
#  'bet': 0.00027288939021271653,
#  'blog': 0.00013278817600654007,
#  'boleto': -0.06143545302951351,
#  'bolix': 0.0,
#  'bom': -0.0003235500648479558,
#  'botão': 0.009961440623404108,
#  'braun': 0.00628015147957155,
#  'budke': 0.006847946775536461,
#  'busca': 0.0125603029591431,
#  'básico': 0.00628015147957155,
#  'cadastro': 0.012821695962651517,
#  'cancelamento': 0.010980764231224892,
#  'carnê': -0.0182094221054182,
#  'carnês': 0.004784511110863868,
#  'cartão': -0.027810344812530082,
#  'celular': 0.002184889615871549,
#  'central': -8.482549686410136e-05,
#  'ceo': 0.008649606601063198,
#  'certinho': 0.006847946775536461,
#  'certo': 0.00757996222706771,
#  'chamar': 0.0,
#  'chat': 0.0031662190835865228,
#  'checkoutr': -0.00016965099372820273,
#  'cliente': -0.04722076526050745,
#  'clique': 0.01208311130798529,
#  'cnpj': 0.0,
#  'cobrança': -0.06812768325234053,
#  'cobrar': 0.0063324381671730455,
#  'coder': -0.00041397271986744227,
#  'coin': 0.006847946775536461,
#  'comercial': 0.0009889516279689141,
#  'começar': 0.0008423126640080068,
#  'comissão': 0.0045164181957040046,
#  'compartilhar': 0.004052495659332619,
#  'compatível': 0.005816228943200164,
#  'completo': -0.003473756101126233,
#  'complexo': 0.00757996222706771,
#  'compr': 0.00628015147957155,
#  'computador': 0.0045164181957040046,
#  'comunidade': -0.0021310792578921552,
#  'concentrar': 0.005816228943200164,
#  'conectar': 0.0030207778269963226,
#  'configurar': 0.004369779231743098,
#  'configuração': 0.003660254743741631,
#  'configure': 0.00628015147957155,
#  'confirmar': 0.0045164181957040046,
#  'confirmação': 0.009961440623404108,
#  'conhecer': -0.0014449899365942722,
#  'conhecimento': 0.008611680059404006,
#  'conheça': 0.00757996222706771,
#  'conseguir': 0.003660254743741631,
#  'consolidado': 0.008611680059404006,
#  'consolidar': 0.008611680059404006,
#  'consultor': 0.0054239880276091765,
#  'conta': -0.12280845244767367,
#  'contar': -0.005094615911889546,
#  'conto': 0.005816228943200164,
#  'controle': 0.003459214510151156,
#  'conveniência': 0.008611680059404006,
#  'cor': 0.006041555653992645,
#  'core': 0.00757996222706771,
#  'crer': 0.00628015147957155,
#  'criar': 0.0033204802078013696,
#  'criptografar': 0.008611680059404006,
#  'crédito': -0.0052262327549010435,
#  'cuidar': 0.003660254743741631,
#  'curso': 8.775108415055829e-05,
#  'custo': 0.0027526849118364592,
#  'customizável': 0.006847946775536461,
#  'código': -0.0012885287347613828,
#  'dado': -0.00043500711995837034,
#  'dar': 0.008547797308434345,
#  'dashboard': 0.005084213491668915,
#  'ddr': 0.009569022221727737,
#  'deixar': 0.0026285369114053348,
#  'demonstração': 0.0031662190835865228,
#  'depoimento': 0.005084213491668915,
#  'desconto': 0.00017550216830111657,
#  'descubrar': 0.005816228943200164,
#  'desejar': 0.0042738986542171726,
#  'desenvolvedor': -4.2766204367382416e-05,
#  'design': 0.0054239880276091765,
#  'detalhar': 0.00628015147957155,
#  'devs': 0.004784511110863868,
#  'dia': -0.007718204677551944,
#  'didático': 0.00757996222706771,
#  'diferencial': 0.00628015147957155,
#  'diferença': 0.004052495659332619,
#  'digital': -0.018329423134729735,
#  'dinheiro': 0.0004211563320040034,
#  'discord': -0.0030991266235945256,
#  'disparo': 0.00757996222706771,
#  'disponível': 0.0016098591766521989,
#  'disposição': 0.003848824647440669,
#  'distribuição': 0.006847946775536461,
#  'distância': 0.00628015147957155,
#  'dividir': 0.006847946775536461,
#  'divisão': 0.005816228943200164,
#  'documentação': -0.0006105615003322928,
#  'durante': 0.005816228943200164,
#  'dúvida': 0.0012570445431287771,
#  'efí': -0.13782459862000737,
#  'eliminar': 0.00757996222706771,
#  'emissão': -0.0008700142399167407,
#  'emitar': 0.0036144611395381443,
#  'emitir': 0.0009451254238936024,
#  'empreendedor': 0.0026285369114053348,
#  'empresa': -0.02344180844052543,
#  'encantar': 0.00757996222706771,
#  'encontrar': 0.0045164181957040046,
#  'endereço': 0.008611680059404006,
#  'entrada': 0.006847946775536461,
#  'entrega': 0.0054239880276091765,
#  'enviar': -0.00012620086803911466,
#  'erp': 0.004784511110863868,
#  'escalar': 0.004784511110863868,
#  'escolha': 0.010980764231224892,
#  'escolher': 0.0031662190835865228,
#  'especialista': 0.00026557635201308015,
#  'espectro': 0.006847946775536461,
#  'esportiva': 0.00027288939021271653,
#  'estar': 0.0009261205526753477,
#  'estruturar': 0.00628015147957155,
#  'etapa': 0.0031662190835865228,
#  'evolução': 0.003848824647440669,
#  'exibir': 0.006847946775536461,
#  'exibição': 0.00757996222706771,
#  'experiência': 0.0008049295883260994,
#  'fabricio': 0.00628015147957155,
#  'facilidade': 0.0028832022003544,
#  'facilitar': 0.0005250290915975283,
#  'falar': 0.001328726163909175,
#  'fatura': 0.0018072305697690721,
#  'fazer': -0.007590435642712418,
#  'feriado': 0.0033204802078013696,
#  'fiel': 0.006847946775536461,
#  'finalizar': 0.00757996222706771,
#  'finalização': 0.005816228943200164,
#  'financeiro': -0.009081688098425255,
#  'financir': 0.0042738986542171726,
#  'fixo': 0.004052495659332619,
#  'focar': 0.0054239880276091765,
#  'frete': 0.00757996222706771,
#  'funcionar': 0.0045164181957040046,
#  'fácil': 0.0031601205937104807,
#  'gente': -0.0022052013364434126,
#  'gerencianet': 0.0,
#  'gerenciar': 0.0018965214598740856,
#  'gerir': 0.00559734458243427,
#  'gestão': -0.00950742393307396,
#  'gostar': 0.005816228943200164,
#  'gratuito': 0.0009889516279689141,
#  'gráfico': 0.013695893551072922,
#  'grátis': -0.030578979787898277,
#  'hoje': 0.0018965214598740856,
#  'humanizar': 0.005816228943200164,
#  'ideal': 0.0018072305697690721,
#  'identificar': 0.005816228943200164,
#  'ilimitar': 0.00628015147957155,
#  'implementação': 0.0045164181957040046,
#  'inadimplente': 0.008547797308434345,
#  'inadimplência': 0.004369779231743098,
#  'indicar': 0.004052495659332619,
#  'informação': 0.0019890599946600267,
#  'informe': 0.0054239880276091765,
#  'inovar': 0.006847946775536461,
#  'insights': 0.009569022221727737,
#  'integrador': 0.0042738986542171726,
#  'integrar': 0.002533293103477093,
#  'integração': -0.002026754962955073,
#  'integre': 0.0028832022003544,
#  'juro': 0.003986178491727525,
#  'lembrete': 0.004784511110863868,
#  'linguagem': 0.0026285369114053348,
#  'linha': 0.008611680059404006,
#  'link': 0.0036144611395381443,
#  'linkr': 0.00027288939021271653,
#  'loja': 0.003660254743741631,
#  'lâmina': 0.005084213491668915,
#  'manter': 0.0026285369114053348,
#  'manual': 0.0063324381671730455,
#  'maquininha': 0.0027526849118364592,
#  'marca': 0.008547797308434345,
#  'meio': 0.0014024857997189776,
#  'mensal': 0.005816228943200164,
#  'menu': 0.00017863679051717193,
#  'mercado': 0.0016375324158284306,
#  'mestre': 0.006847946775536461,
#  'minuto': 0.007697649294881338,
#  'mobile': 0.005816228943200164,
#  'modelo': 0.0031662190835865228,
#  'monitore': 0.008611680059404006,
#  'movimentação': 0.0027526849118364592,
#  'multa': 0.0032750648316568613,
#  'mão': 0.0027526849118364592,
#  'método': 0.005084213491668915,
#  'módulo': 0.0,
#  'necessidade': 0.010454101090103125,
#  'negócio': -0.010965696209023231,
#  'norma': 0.006847946775536461,
#  'objetivo': 0.003848824647440669,
#  'oferecer': 0.0005786001073680937,
#  'online': 0.0025101653703496277,
#  'onliner': 0.0030207778269963226,
#  'operação': 0.0030207778269963226,
#  'oportunidade': 0.005084213491668915,
#  'opção': 0.004207457399156932,
#  'orçamento': 0.0054239880276091765,
#  'otimizar': 0.0018072305697690721,
#  'outro': 0.008547797308434345,
#  'padrão': 0.003848824647440669,
#  'pagamento': -0.16906392720273994,
#  'pagar': -0.003636178990036804,
#  'paguir': 0.005084213491668915,
#  'painel': 0.0034847003633677086,
#  'palma': 0.0054239880276091765,
#  'panorama': 0.006847946775536461,
#  'parcela': 0.007320509487483262,
#  'parcelamento': 0.0034847003633677086,
#  'parcelar': 0.003978119989320053,
#  'parcerio': 0.000225326710792481,
#  'passar': 0.0042738986542171726,
#  'pay': -0.003307126589346672,
#  'pdv': 0.005816228943200164,
#  'pedido': 0.00757996222706771,
#  'percentual': 0.006847946775536461,
#  'periodicidade': 0.004784511110863868,
#  'personalizar': 0.0018999698276078196,
#  'personalizável': 0.01744868682960049,
#  'pix': -0.03345572386492056,
#  'pj': 0.00027288939021271653,
#  'plano': 0.005020330740699255,
#  'plataforma': -0.009138080174186025,
#  'plugim': 0.0,
#  'pouco': 0.003660254743741631,
#  'praticamente': 0.00628015147957155,
#  'praticidade': 0.002397056559736819,
#  'prazo': 0.005084213491668915,
#  'precisar': -0.0011304100079982723,
#  'previsibilidade': 0.005816228943200164,
#  'preço': 0.008611680059404006,
#  'principal': 0.004577524750930147,
#  'priori': 0.006847946775536461,
#  'pro': -0.0012321860812966622,
#  'problema': 0.0030207778269963226,
#  'processo': 0.0011572002147361873,
#  'produto': 0.002184889615871549,
#  'profundo': 0.00757996222706771,
#  'programação': 0.0055053698236729185,
#  'programe': 0.00757996222706771,
#  'protegido': 0.00757996222706771,
#  'provedor': -0.001157918700375411,
#  'qr': -0.00041397271986744227,
#  'quantidade': 0.008611680059404006,
#  'real': 0.002397056559736819,
#  'realizar': 0.0022887623754650737,
#  'recebedor': 0.005084213491668915,
#  'receber': -0.03417296578540881,
#  'recebimento': -0.006650553026507243,
#  'recorrente': -0.001083742452445704,
#  'rede': 0.0028832022003544,
#  'redesoft': 0.006847946775536461,
#  'redirecionamento': 0.005816228943200164,
#  'reduzar': 0.0045164181957040046,
#  'registrar': 0.005816228943200164,
#  'regra': 0.009032836391408009,
#  'rei': 0.00628015147957155,
#  'relatório': 0.004207457399156932,
#  'repasse': 0.007320509487483262,
#  'repasses': 0.006847946775536461,
#  'resolver': 0.0028832022003544,
#  'responsivo': 0.008611680059404006,
#  'resumo': 0.005816228943200164,
#  'reunir': 0.006847946775536461,
#  'robson': 0.006847946775536461,
#  'robusta': 0.003660254743741631,
#  'rápido': 0.0004725627119468012,
#  'régua': 0.004784511110863868,
#  'saber': -0.0005764062323115785,
#  'saída': 0.006847946775536461,
#  'sdk': 0.0033204802078013696,
#  'segmentos': 0.00027288939021271653,
#  'semana': 0.005084213491668915,
#  'semestral': 0.008611680059404006,
#  'sequência': 0.008611680059404006,
#  'ser': -0.0002544764905923041,
#  'serviço': 0.0010533735312368271,
#  'simples': 0.003459214510151156,
#  'site': -0.003952882185739077,
#  'situação': 0.005816228943200164,
#  'social': 0.003660254743741631,
#  'solicitar': 0.001328726163909175,
#  'solução': -0.009222078145573711,
#  'split': -0.00041397271986744227,
#  'status': 0.003848824647440669,
#  'studio': 0.00628015147957155,
#  'suporte': 0.003771133629386331,
#  'systhesy': 0.006847946775536461,
#  'tamanho': 0.008611680059404006,
#  'tarifa': -0.0121234157441058,
#  'taxa': 0.004784511110863868,
#  'tecnologia': -0.0007967891129340455,
#  'tela': 0.009155049501860295,
#  'telefone': 0.0006333232758692733,
#  'ter': 0.0039558065118756565,
#  'ticket': 0.0042738986542171726,
#  'time': -0.0002524017360782293,
#  'torne': 0.008611680059404006,
#  'total': 0.009961440623404108,
#  'totalmente': 0.005084213491668915,
#  'trabalhar': 0.0034847003633677086,
#  'transacional': 0.008611680059404006,
#  'transação': 0.0009261205526753477,
#  'transformar': 0.004052495659332619,
#  'transforme': 0.006847946775536461,
#  'transparente': -0.0006471001296959116,
#  'transparência': 0.0042738986542171726,
#  'trazer': 0.0045164181957040046,
#  'trocar': 0.0054239880276091765,
#  'técnico': 0.005967179983980079,
#  'usuário': 0.0034847003633677086,
#  'utilizar': 0.0045164181957040046,
#  'valor': 0.010980764231224892,
#  'valério': 0.006847946775536461,
#  'vantagem': 0.0009261205526753477,
#  'vencimento': 0.004477875665947417,
#  'venda': -0.003795217821356209,
#  'vender': 0.0057664044007088,
#  'via': -0.010096626429133773,
#  'vida': 0.0018522411053506953,
#  'vira': 0.00628015147957155,
#  'vista': 0.007320509487483262,
#  'visualizar': 0.00757996222706771,
#  'visualização': 0.004784511110863868,
#  'visão': 0.0054239880276091765,
#  'web': 0.004170182727146247,
#  'whatsapp': 0.004577524750930147,
#  'ágil': 0.003660254743741631,
#  'último': 0.006847946775536461,
#  'único': 0.01208311130798529}
# --------------------------------------------------------------------------------
# Documento ID: https://sejaefi.com.br/lp/formulario-efi-empresas
# {'Api': 0.0001402842827165867,
#  'Banco': 0.003984020205238786,
#  'Central': 0.0038668820276625297,
#  'Cnpj': 0.011460361800271003,
#  'Finance': 0.00028829443643440216,
#  'Finanças': 0.0018181184468913014,
#  'Internet': -0.0008185193300219412,
#  'Open': -0.004489878719517918,
#  'Pix': -0.004489878719517918,
#  'abrir': -0.01851859773456965,
#  'abro': 0.00028829443643440216,
#  'acessar': -0.0033978105236914767,
#  'acesso': 0.013259341270798435,
#  'acompanhar': 0.003123816572253974,
#  'acordo': 0.0060919272297810705,
#  'adicione': 0.007362834638728546,
#  'administrar': 0.0035079266711449952,
#  'agendar': 0.0066346761598699445,
#  'agilizar': 0.005371225543617967,
#  'agradecer': 0.010109208960051077,
#  'agradecimento': 0.0066346761598699445,
#  'agradecir': 0.0066346761598699445,
#  'agradável': 0.005730180900135501,
#  'ajuda': 0.003681417319364273,
#  'ajudar': 0.0025087071573198657,
#  'alto': 0.0019969585569364822,
#  'ambição': 0.00909782328856391,
#  'ano': 0.0008503691618606373,
#  'anterior': 0.0038185033006411045,
#  'anuidade': 0.005303736508319374,
#  'análise': 0.004771377287396973,
#  'api': -0.07049320301491425,
#  'apis': 0.00022976388923790376,
#  'aplicativo': -0.003925893125500941,
#  'apoiar': 0.005371225543617967,
#  'aposto': 0.00028829443643440216,
#  'app': -0.008840837114546677,
#  'aproximação': 0.003681417319364273,
#  'assinatura': 0.0028074697979371278,
#  'associação': 0.00800786332053121,
#  'atendimento': -0.0030447264690651927,
#  'atenção': 0.006144564448058238,
#  'ativo': 0.005730180900135501,
#  'aumente': 0.005371225543617967,
#  'automatizar': 0.00027811432315459194,
#  'automático': -0.011379150463919812,
#  'banco': -0.003494532762992988,
#  'bancário': -9.036085116334027e-05,
#  'barro': 0.0022027981340974126,
#  'bastar': 0.004771377287396973,
#  'benefício': 0.004007166310379116,
#  'bet': 0.00028829443643440216,
#  'bilhão': 0.0009984792784682411,
#  'blog': 0.0001402842827165867,
#  'boleto': -0.06026761319657921,
#  'bolix': 0.0,
#  'bom': -0.0006836299757271325,
#  'botão': 0.0070158533422899905,
#  'brasília': 0.00800786332053121,
#  'burocracia': 0.004515167126632659,
#  'cair': 0.007362834638728546,
#  'caixa': 0.002908078414924001,
#  'carnê': -0.01099278477331698,
# ...
#  'ordem': 0.005068254393193652,
#  'orçamento': 0.00401436402043391,
#  'otimizar': 0.006687774142365775,
#  'outro': 0.003163167930522314,
#  'pacote': 0.00802872804086782,
#  'padrão': 0.0056971302690929666,
#  'pagamento': -0.21450241611195092,
#  'pagar': -0.0035882444270796334,
#  'pagos': 0.005068254393193652,
#  'parceiro': 0.002423918039248863,
#  'parcelar': 0.002944258297180378,
#  'parceria': 0.0012468130958762586,
#  'parcerio': 0.00016676722663172322,
#  'passo': 0.0024575305492767195,
#  'pay': -0.02325264994599962,
#  'pdv': 0.012913999856935957,
#  'pecer': 0.0037628924712351853,
#  'pensar': 0.003163167930522314,
#  'periódico': 0.00401436402043391,
#  'permitir': 0.002944258297180378,
#  'personalizar': 0.0004687307860953378,
#  'personalização': 0.004304666618978652,
#  'personalizável': 0.004304666618978652,
#  'pix': -0.07782033589887091,
#  'pj': 0.0006059069511502688,
#  'planilha': 0.00401436402043391,
#  'plano': 0.0018578060085638485,
#  'plataforma': -0.01623170851279145,
#  'plataformo': 0.010136508786387303,
#  'plugim': 0.0,
#  'poder': 0.0028485651345464833,
#  'ponta': 0.003342659794560591,
#  'possibilito': 0.005068254393193652,
#  'pouco': 0.0027090020984754442,
#  'praticamente': 0.004648021716519056,
#  'praticidade': 0.003548185416107607,
#  'precisar': -0.0025098934075893837,
#  'preciso': 0.003342659794560591,
#  'preferir': 0.0059986093940403735,
#  'prestashop': 0.0056100285409371176,
#  'principal': 0.006775771100246884,
#  'priori': 0.005068254393193652,
#  'pro': -0.0012767397023152988,
#  'processamento': 0.00401436402043391,
#  'processo': 0.0012846883739867842,
#  'produtividade': 0.005068254393193652,
#  'produto': 0.004851195587782592,
#  'profundo': 0.0056100285409371176,
#  'programa': 0.0025602096092079175,
#  'programação': 0.006111893617806375,
#  'pronta': 0.006373616315152117,
#  'pronto': 0.002579072020345592,
#  'proteção': 0.003342659794560591,
#  'provedor': -0.0008569906765490329,
#  'prático': 0.0035410788447636536,
#  'qr': -0.00030638658928042336,
#  'qualidade': 0.0029993046970201867,
#  'rapidamente': 0.0056100285409371176,
#  'rapidez': 0.005068254393193652,
#  'realizar': 0.005081828325185163,
#  'receba': 0.009489503791566942,
#  'recebedor': 0.007525784942470371,
#  'receber': -0.030350227239922402,
#  'recebimento': -0.019688642858134438,
#  'recorrente': -0.0005347279143894057,
#  'recurso': 0.0016170651959275305,
#  'redesoft': 0.005068254393193652,
#  'redirecionamento': 0.004304666618978652,
#  'reduzar': 0.006685319589121182,
#  'redução': 0.004648021716519056,
#  'referência': 0.0056100285409371176,
#  'rei': 0.004648021716519056,
#  'relatório': 0.002075995929527526,
#  'repasse': 0.0054180041969508885,
#  'requisição': 0.009296043433038113,
#  'resolver': 0.0021338954138216174,
#  'responder': 0.0037628924712351853,
#  'restful': 0.006373616315152117,
#  'resumo': 0.004304666618978652,
#  'revolucione': 0.00401436402043391,
#  'robson': 0.005068254393193652,
#  'robusta': 0.0027090020984754442,
#  'rotina': 0.00407459574520425,
#  'rápido': 0.000349749803757237,
#  'saber': -0.0008532114851165737,
#  'sair': 0.0029993046970201867,
#  'saldo': 0.0038908286485208905,
#  'screen': 0.0056100285409371176,
#  'sdk': 0.007372591647830159,
#  'segmentos': 0.0002019689837167563,
#  'segundo': 0.0016170651959275305,
#  'segurança': 0.0018749231443813512,
#  'ser': -0.0002511218099253622,
#  'serviço': 0.0023388463151190566,
#  'simples': 0.0025602096092079175,
#  'simplificar': 0.0028072803530339568,
#  'simplifique': 0.003342659794560591,
#  'sistema': 0.0027090020984754442,
#  'site': -0.005119764073902166,
#  'situação': 0.004304666618978652,
#  'software': 0.00401436402043391,
#  'solicitar': 0.0009834074998423836,
#  'solução': -0.017063449676132145,
#  'split': -0.00045957988392063504,
#  'status': 0.00854569540363945,
#  'studio': 0.004648021716519056,
#  'sucesso': 0.0044714338456103755,
#  'suporta': 0.0056971302690929666,
#  'suporte': 0.003721420003386888,
#  'systhesy': 0.005068254393193652,
#  'série': 0.0037628924712351853,
#  'tag': 0.0059986093940403735,
#  'tarifa': -0.016150855550622303,
#  'taxa': 0.0035410788447636536,
#  'tech': 0.004304666618978652,
#  'tecnologia': -0.0020639989168376263,
#  'ted': 0.0028485651345464833,
#  'tela': 0.003387885550123442,
#  'telefone': 0.0004687307860953378,
#  'ter': 0.0021958078519309786,
#  'terminal': 0.006373616315152117,
#  'ticket': 0.003163167930522314,
#  'time': -0.0005604174140042041,
#  'tomar': 0.005068254393193652,
#  'tornar': 0.005158144040691184,
#  'total': 0.004915061098553439,
#  'totalmente': 0.0037628924712351853,
#  'touch': 0.0056100285409371176,
#  'transação': 0.00068543385536989,
#  'transparente': -0.0007183908219505459,
#  'trazer': 0.003342659794560591,
#  'troca': 0.004304666618978652,
#  'tutorial': 0.006373616315152117,
#  'técnico': 0.005888516594360756,
#  'universidade': 0.004648021716519056,
#  'universo': 0.006373616315152117,
#  'usar': 0.0012119590196244315,
#  'utilizar': 0.006685319589121182,
#  'valor': 0.0027090020984754442,
#  'valério': 0.005068254393193652,
#  'vantagem': 0.00137086771073978,
#  'variar': 0.0056100285409371176,
#  'vencer': 0.00401436402043391,
#  'vencimento': 0.0008285334918631519,
#  'venda': -0.006554076727276166,
#  'vender': 0.010669477069108087,
#  'ver': 0.0008338361331586161,
#  'verdade': 0.0029993046970201867,
#  'verificar': 0.00401436402043391,
#  'via': -0.004270082525315655,
#  'vida': 0.00342716927684945,
#  'video': 0.0059986093940403735,
#  'vira': 0.004648021716519056,
#  'virtual': 0.0028485651345464833,
#  'virtuemart': 0.006373616315152117,
#  'visitir': 0.003342659794560591,
#  'vista': 0.0027090020984754442,
#  'visual': 0.00401436402043391,
#  'visualização': 0.0035410788447636536,
#  'volume': 0.0059986093940403735,
#  'várias': 0.003163167930522314,
#  'vídeo': 0.0028485651345464833,
#  'web': 0.004629609637764053,
#  'whatsapp': 0.001693942775061721,
#  'whmcs': 0.0056100285409371176,
#  'woocommerce': 0.0056100285409371176,
#  'wordpress': 0.0056100285409371176,
#  'youtube': 0.005068254393193652,
#  'ágil': 0.0054180041969508885,
#  'índice': 0.0056100285409371176,
#  'único': 0.006707150768415563}
# --------------------------------------------------------------------------------
# Documento ID: https://sejaefi.com.br
# {'Api': 0.00018183189258038414,
#  'Banco': 0.003442637668638393,
#  'Brasil': 0.00135420902366475,
#  'Finance': 0.00037367780611009615,
#  'Finanças': 0.0023565855827301883,
#  'Gerencianet': 0.0027236953933846356,
#  'Internet': -0.0010609379469273942,
#  'Open': -0.005819633740977927,
#  'Pix': -0.005819633740977927,
#  'abra': 0.008599649935441182,
#  'abrir': -0.019202559880863862,
#  'abro': 0.00037367780611009615,
#  'aceitar': 0.0012681720459979497,
#  'acelerir': 0.011792300569149039,
#  'acer': 0.0041364658049113405,
#  'acessar': -0.004404130713634945,
#  'agradecer': 0.013103225551006969,
#  'agradecimento': 0.008599649935441182,
#  'agradecir': 0.008599649935441182,
#  'ajudar': 0.0065034081012055045,
#  'alcance': 0.008599649935441182,
#  'ano': 0.0011022206557914878,
#  'anterior': 0.002474709456164618,
#  'antifraude': 0.007427272804356816,
#  'apaixonar': 0.011792300569149039,
#  'api': -0.04568549045565872,
#  'apis': 0.00029781242786237005,
#  'aplicativo': -0.0033924093906767716,
#  'aposto': 0.00037367780611009615,
#  'app': -0.010026803068937084,
#  'arquitetura': 0.008599649935441182,
#  'atendimento': -0.004735769671744607,
#  'atenção': 0.007964383187030188,
#  'automatizar': 0.00024032178446807946,
#  'automático': -0.0036873205336046774,
#  'avaliar': 0.011792300569149039,
#  'banco': -0.0060393318830819585,
#  'bancário': -0.00011712277572391142,
#  'bandeira': 0.007427272804356816,
#  'bank': -0.0022152469596732863,
#  'bastar': 0.006184502964849038,
#  'benefício': 0.002596978863172528,
#  'bet': 0.00037367780611009615,
#  'bilhão': 0.001294196137944898,
#  'blog': 0.00018183189258038414,
#  'boleto': -0.05408093513324771,
#  'bom': -0.0008860987838693145,
#  'brasileiro': 0.005852411746018637,
#  'carnê': -0.007124243790372676,
#  'cartão': -0.015232704545399755,
#  'casa': 0.007964383187030188,
#  'central': -0.0001161547744515395,
#  'centralizar': 0.005852411746018637,
#  'certificar': 0.005549236216438045,
#  'chamar': 0.0,
#  'chat': 0.004335624041287468,
#  'checkoutr': -0.0001161547744515395,
#  'cliente': -0.03233059363654953,
#  'cobrança': -0.016462910136197887,
#  'coder': -0.00028343428381168086,
#  'colaborador': 0.003437264775426493,
#  'comercial': 0.0027084180473295,
#  'começar': 0.000576705360549036,
#  'completo': -0.00317116410625461,
#  'compra': 0.0009438151712034832,
#  'compreensão': 0.008599649935441182,
#  'compromisso': 0.006962006627964751,
#  'comunidade': -0.0019454451761942322,
#  'conciliação': 0.0027236953933846356,
#  'conectir': 0.011792300569149039,
#  'confer': 0.003134089245845902,
#  'conhecer': -0.0019786795995872784,
#  'conhedir': 0.011792300569149039,
#  'conseguir': 0.005012125833764672,
#  'conta': -0.08408313904518425,
#  'contar': -0.01162708509507893,
#  'contato': -0.0005956717705353294,
#  'conte': 0.0032517040506027522,
#  'conto': 0.007964383187030188,
#  'controle': 0.0011842084516458225,
#  'conversar': 0.0019204770706953245,
#  'cpf': 0.005852411746018637,
#  'crescer': 0.006962006627964751,
#  'cresça': 0.011792300569149039,
#  'criamos': 0.011792300569149039,
#  'crédito': -0.007156478998871465,
#  'cuidar': 0.005012125833764672,
#  'curso': 0.00024032178446807946,
#  'código': -0.0008822156668313996,
#  'dar': 0.005852411746018637,
#  'dedicar': 0.005012125833764672,
#  'deixar': 0.0035993554222379666,
#  'deixeir': 0.008599649935441182,
#  'demonstrar': 0.007427272804356816,
#  'desafio': 0.007427272804356816,
#  'descomplicar': 0.0023565855827301883,
#  'desejar': 0.005852411746018637,
#  'desenvolvedor': -0.00011712277572391142,
#  'dev': 0.005549236216438045,
#  'developer': 0.010379530157622333,
#  'devido': 0.007427272804356816,
#  'dia': -0.0015098329707704896,
#  'diferentes': 0.010379530157622333,
#  'digital': -0.016732783488847356,
#  'discord': -0.0021218758938547884,
#  'disponibilidade': 0.010379530157622333,
#  'documentação': -0.0025081951529330074,
#  'ecossistema': 0.003134089245845902,
#  'eficiente': 0.01031179432627948,
#  'eficiência': 0.010540683529227754,
#  'efí': -0.1715713248579756,
#  'emissão': -0.0005956717705353294,
#  'emitia': 0.008599649935441182,
#  'empresa': -0.027514078796793913,
#  'equipar': 0.007964383187030188,
#  'escalar': 0.006551612775503484,
#  'esforço': 0.009377153598556896,
#  'especialista': 0.00018183189258038414,
#  'esportiva': 0.00037367780611009615,
#  'estar': 0.0012681720459979497,
#  'estender': 0.008599649935441182,
#  'evolução': 0.005270341764613877,
#  'excelente': 0.010024251667529344,
#  'exclusivo': 0.0005077066591686194,
#  'experiência': 0.0022044413115829757,
#  'explore': 0.014854545608713632,
#  'facilidade': 0.003948078274352888,
#  'falar': 0.003638950400113629,
#  'fato': 0.008599649935441182,
#  'fazer': -0.0017323119672392456,
#  'ferramenta': 0.0037693559942568932,
#  'finance': -0.00022856195988088233,
#  'financeiro': -0.006217950213730183,
#  'financiar': 0.009377153598556896,
#  'fiquei': 0.008599649935441182,
#  'first': 0.010379530157622333,
#  'forma': 0.009377153598556896,
#  'fornecedor': 0.005852411746018637,
#  'fornecer': 0.006551612775503484,
#  'funcionalidade': 0.004546859657372606,
#  'fácil': 0.002884848764990056,
#  'físico': 0.002596978863172528,
#  'garantia': 0.011792300569149039,
#  'gente': -0.004529498912311469,
#  'gerencianet': 0.0,
#  'gerenciar': 0.002596978863172528,
#  'gestão': -0.013018876674906156,
#  'google': 0.016545863219645362,
#  'gratuita': 0.008599649935441182,
#  'gratuito': 0.00135420902366475,
#  'grátis': -0.026170598990949524,
#  'hoje': 0.002596978863172528,
#  'humanizar': 0.007964383187030188,
#  'impulsionar': 0.009377153598556896,
#  'indevidamente': 0.008599649935441182,
#  'indique': 0.007964383187030188,
#  'inovação': 0.006184502964849038,
#  'integrador': 0.005852411746018637,
#  'integrar': 0.001734467229384142,
#  'integração': -0.0020814844088188423,
#  'integre': 0.007896156548705777,
#  'ir': 0.0016258520253013761,
#  'janela': 0.007427272804356816,
#  'jeito': 0.007427272804356816,
#  'jornada': 0.0019204770706953245,
#  'junto': 0.0042634253735609265,
#  'limpa': 0.008599649935441182,
#  'linguagem': 0.0035993554222379666,
#  'linkr': 0.00037367780611009615,
#  'maisorganizar': 0.008599649935441182,
#  'manter': 0.0035993554222379666,
#  'medida': 0.010379530157622333,
#  'meio': 0.003840954141390649,
#  'melhorar': 0.006551612775503484,
#  'menu': 0.0002446141417186361,
#  'mercado': 0.0022423353289915443,
#  'mexer': 0.007964383187030188,
#  'minimizar': 0.006551612775503484,
#  'moderno': 0.01196740932456472,
#  'movimentar': 0.0017213188343191965,
#  'movimente': 0.011792300569149039,
#  'muito': 0.010540683529227754,
#  'mão': 0.0075387119885137865,
#  'mídia': 0.009377153598556896,
#  'módulo': 0.0,
#  'nascer': 0.005549236216438045,
#  'negócio': -0.007507872143111725,
#  'nome': 0.00037367780611009615,
#  'nota': 0.005270341764613877,
#  'novidade': 0.007427272804356816,
#  'novs': 0.008599649935441182,
#  'objetivo': 0.005270341764613877,
#  'obtenha': 0.007427272804356816,
#  'oferecer': 0.0023768973051811236,
#  'pagamento': -0.115752828206754,
#  'paguir': 0.006962006627964751,
#  'palma': 0.007427272804356816,
#  'parabenizar': 0.008599649935441182,
#  'parceiro': 0.004484670657983089,
#  'parcelar': 0.0027236953933846356,
#  'parceria': 0.002306821442196144,
#  'parcerio': 0.0003085484227924914,
#  'pay': -0.004528574040464257,
#  'perfeito': 0.006184502964849038,
#  'personalizar': 0.000867233614692071,
#  'pessoa': -0.0003906526066923558,
#  'pessoal': 0.0035993554222379666,
#  'pf': 0.005012125833764672,
#  'pix': -0.039267594262559824,
#  'pj': 0.0014947112244403846,
#  'plataforma': -0.007507872143111725,
#  'platinum': 0.003948078274352888,
#  'play': 0.015811025293841634,
#  'playr': 0.008599649935441182,
#  'plugim': 0.0,
#  'poder': 0.005270341764613877,
#  'possibilidade': 0.01364057897211782,
#  'possibilitar': 0.007964383187030188,
#  'potencial': 0.005270341764613877,
#  'potencializar': 0.005852411746018637,
#  'pra': 0.010540683529227754,
#  'precisar': -0.001547913355900073,
#  'principal': 0.006268178491691804,
#  'problema': 0.012409397414734022,
#  'produto': 0.00299185233114118,
#  'programa': 0.002368416903291645,
#  'programação': 0.0037693559942568932,
#  'pronto': 0.009543465106644665,
#  'proteção': 0.006184502964849038,
#  'provedor': -0.001585582053127305,
#  'qr': -0.00028343428381168086,
#  'quase': 0.008599649935441182,
#  'querer': 0.005012125833764672,
#  'real': 0.003282380585284215,
#  'receber': -0.009358867981648545,
#  'recebimento': -0.018213709682350848,
#  'reclamação': 0.008599649935441182,
#  'reclame': 0.017342496165149872,
#  'recomendar': 0.006551612775503484,
#  'recorrente': -0.0004946698998968196,
#  'resolver': 0.011844234823058667,
#  'retirar': 0.006551612775503484,
#  'rápido': 0.001941294206917347,
#  'saber': -0.003157179781163071,
#  'saldo': 0.0035993554222379666,
#  'satisfeito': 0.008599649935441182,
#  'sdk': 0.004546859657372606,
#  'segmentos': 0.00037367780611009615,
#  'segurança': 0.000867233614692071,
#  'seguro': -0.00045712391976176467,
#  'ser': -0.0001161547744515395,
#  'simplificar': 0.002596978863172528,
#  'simplifique': 0.006184502964849038,
#  'sinceridade': 0.008599649935441182,
#  'sintonia': 0.008599649935441182,
#  'site': -0.004059623777862694,
#  'solidez': 0.007427272804356816,
#  'solução': -0.015785177313634442,
#  'somar': 0.008599649935441182,
#  'split': -0.00028343428381168086,
#  'store': 0.015811025293841634,
#  'sucesso': 0.0041364658049113405,
#  'superar': 0.007964383187030188,
#  'suporte': 0.003442637668638393,
#  'série': 0.006962006627964751,
#  'sério': 0.007427272804356816,
#  'tarifa': -0.0066404214459004594,
#  'tech': 0.007964383187030188,
#  'tecnologia': -0.0005455367968346339,
#  'telefone': 0.000867233614692071,
#  'ter': 0.00135420902366475,
#  'time': -0.0005184349248017986,
#  'top': 0.008599649935441182,
#  'trabalhar': 0.004771732553322332,
#  'tradicional': 0.005549236216438045,
#  'transação': 0.0012681720459979497,
#  'transparente': -0.0008860987838693145,
#  'técnico': 0.0027236953933846356,
#  'usar': 0.004484670657983089,
#  'uso': 0.005270341764613877,
#  'vantagem': 0.0012681720459979497,
#  'verdade': 0.005549236216438045,
#  'via': -0.0059252974414876645,
#  'videoaula': 0.011792300569149039,
#  'visar': 0.0027236953933846356,
#  'vista': 0.005012125833764672,
#  'whatsapp': 0.003134089245845902}
# --------------------------------------------------------------------------------
